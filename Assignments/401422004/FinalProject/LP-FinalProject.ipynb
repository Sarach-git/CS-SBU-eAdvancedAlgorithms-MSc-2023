# %% [markdown]
# # Final Project
#
# # Using linear programming for diet planing

# %% [markdown]
# ## Meshkat Ahmadi
# # Student ID 401422004

# %% [markdown]
# Here I wrote the utility functions to get calculated needed nutritions based on the weight
# and I calculate the ideal weight based on BMI

# %%
import pandas as pd
from pulp import *
import re

patt=re.compile(r'[^A-Za-z0-9]+')
def convert_dict(food_dict):
    converted_dict = {}
    for nutrient in food_dict:
        for food in food_dict[nutrient]:
            new_food_name = re.sub(patt, '_', food)
            if new_food_name not in converted_dict:
                converted_dict[new_food_name] = {}
            if nutrient in ['Calories', 'Protein', 'TotalFat', 'Carbohydrate']:
                converted_dict[new_food_name][nutrient] = food_dict[nutrient][food]
    return converted_dict


def calculate_ideal_weight(height, gender):
    # Calculate ideal weight based on height and gender
    if gender.lower() == 'male':
        ideal_weight = 50 + 2.3 * ((height * 100) - 152.4) / 2.54
    elif gender.lower() == 'female':
        ideal_weight = 45.5 + 2.3 * ((height * 100) - 152.4) / 2.54
    else:
        raise ValueError("Invalid gender. Please enter 'male' or 'female'.")

    return ideal_weight

def calculate_nutrient_ranges(weight):
    
    # Calculate recommended nutrient ranges based on weight
    calories_range = (weight * 25, weight * 30)  # kilocalories
    protein_range = (weight * 0.8, weight * 1.2)  # grams
    fat_range = (weight * 0.5, weight * 0.7)  # grams
    carbohydrate_range = (weight * 3, weight * 4)  # grams
    sodium_range = (weight * 1.5, weight * 2.3)  # grams
    saturated_fat_range = (weight * 0.08, weight * 0.1)  # grams
    cholesterol_range = (weight * 0.15, weight * 0.2)  # grams
    sugar_range = (weight * 0.5, weight * 1)  # grams
    calcium_range = (weight * 0.015, weight * 0.03)  # grams
    iron_range = (weight * 0.005, weight * 0.01)  # grams
    potassium_range = (weight * 0.3, weight * 0.4)  # grams
    vitamin_c_range = (weight * 30, weight * 40)  # milligrams
    vitamin_e_range = (weight * 5, weight * 10)  # milligrams
    vitamin_d_range = (weight * 5, weight * 10)  # micrograms

    nutrient_ranges = {
        'Calories': (calories_range, 'kilocalories'),
        'Protein': (protein_range, 'grams'),
        'TotalFat': (fat_range, 'grams'),
        'Carbohydrate': (carbohydrate_range, 'grams'),
    }    

    return nutrient_ranges

# %% [markdown]
# # Create a food dictionary of Values

# %%
import pandas as pd
# parsing the food item
df = pd.read_csv('USDA.csv')
# removing the NAN records
df=df.dropna(subset=['Calories','Protein','Carbohydrate','TotalFat'], how='all')
# Create a list of the food items
food_items = list(df['Description'])
food_dict = dict()
for prop in df.columns[2::].tolist():
    food_dict[prop]=dict(zip(food_items,df[prop]))
food_nutrient = convert_dict(food_dict)

# %%
food_nutrient
# Out:
# {'BUTTER_WITH_SALT': {'Calories': 717.0,
#   'Protein': 0.85,
#   'TotalFat': 81.11,
#   'Carbohydrate': 0.06},
#  'BUTTER_WHIPPED_WITH_SALT': {'Calories': 717.0,
#   'Protein': 0.85,
#   'TotalFat': 81.11,
#   'Carbohydrate': 0.06},
#  'BUTTER_OIL_ANHYDROUS': {'Calories': 876.0,
#   'Protein': 0.28,
#   'TotalFat': 99.48,
#   'Carbohydrate': 0.0},
#  'CHEESE_BLUE': {'Calories': 353.0,
#   'Protein': 21.4,
#   'TotalFat': 28.74,
#   'Carbohydrate': 2.34},
#  'CHEESE_BRICK': {'Calories': 371.0,
#   'Protein': 23.24,
#   'TotalFat': 29.68,
#   'Carbohydrate': 2.79},
#  'CHEESE_BRIE': {'Calories': 334.0,
#   'Protein': 20.75,
#   'TotalFat': 27.68,
#   'Carbohydrate': 0.45},
#  'CHEESE_CAMEMBERT': {'Calories': 300.0,
#   'Protein': 19.8,
#   'TotalFat': 24.26,
#   'Carbohydrate': 0.46},
#  'CHEESE_CARAWAY': {'Calories': 376.0,
#   'Protein': 25.18,
#   'TotalFat': 29.2,
#   'Carbohydrate': 3.06},
#  'CHEESE_CHEDDAR': {'Calories': 403.0,
#   'Protein': 24.9,
#   'TotalFat': 33.14,
#   'Carbohydrate': 1.28},
#  'CHEESE_CHESHIRE': {'Calories': 387.0,
#   'Protein': 23.37,
#   'TotalFat': 30.6,
#   'Carbohydrate': 4.78},
#  'CHEESE_COLBY': {'Calories': 394.0,
#   'Protein': 23.76,
#   'TotalFat': 32.11,
#   'Carbohydrate': 2.57},
#  'CHEESE_COTTAGE_CRMD_LRG_OR_SML_CURD': {'Calories': 98.0,
#   'Protein': 11.12,
#   'TotalFat': 4.3,
#   'Carbohydrate': 3.38},
#  'CHEESE_COTTAGE_CRMD_W_FRUIT': {'Calories': 97.0,
#   'Protein': 10.69,
#   'TotalFat': 3.85,
#   'Carbohydrate': 4.61},
#  'CHEESE_COTTAGE_NONFAT_UNCRMD_DRY_LRG_OR_SML_CURD': {'Calories': 72.0,
#   'Protein': 10.34,
#   'TotalFat': 0.29,
#   'Carbohydrate': 6.66},
#  'CHEESE_COTTAGE_LOWFAT_2_MILKFAT': {'Calories': 86.0,
#   'Protein': 11.83,
#   'TotalFat': 2.45,
#   'Carbohydrate': 3.66},
#  'CHEESE_COTTAGE_LOWFAT_1_MILKFAT': {'Calories': 72.0,
#   'Protein': 12.39,
#   'TotalFat': 1.02,
#   'Carbohydrate': 2.72},
#  'CHEESE_CREAM': {'Calories': 342.0,
#   'Protein': 5.93,
#   'TotalFat': 34.24,
#   'Carbohydrate': 4.07},
#  'CHEESE_EDAM': {'Calories': 357.0,
#   'Protein': 24.99,
#   'TotalFat': 27.8,
#   'Carbohydrate': 1.43},
#  'CHEESE_FETA': {'Calories': 264.0,
#   'Protein': 14.21,
#   'TotalFat': 21.28,
#   'Carbohydrate': 4.09},
#  'CHEESE_FONTINA': {'Calories': 389.0,
#   'Protein': 25.6,
#   'TotalFat': 31.14,
#   'Carbohydrate': 1.55},
#  'CHEESE_GJETOST': {'Calories': 466.0,
#   'Protein': 9.65,
#   'TotalFat': 29.51,
#   'Carbohydrate': 42.65},
#  'CHEESE_GOUDA': {'Calories': 356.0,
#   'Protein': 24.94,
#   'TotalFat': 27.44,
#   'Carbohydrate': 2.22},
#  'CHEESE_GRUYERE': {'Calories': 413.0,
#   'Protein': 29.81,
#   'TotalFat': 32.34,
#   'Carbohydrate': 0.36},
#  'CHEESE_LIMBURGER': {'Calories': 327.0,
#   'Protein': 20.05,
#   'TotalFat': 27.25,
#   'Carbohydrate': 0.49},
#  'CHEESE_MONTEREY': {'Calories': 373.0,
#   'Protein': 24.48,
#   'TotalFat': 30.28,
#   'Carbohydrate': 0.68},
#  'CHEESE_MOZZARELLA_WHL_MILK': {'Calories': 300.0,
#   'Protein': 22.17,
#   'TotalFat': 22.35,
#   'Carbohydrate': 2.19},
#  'CHEESE_MOZZARELLA_WHL_MILK_LO_MOIST': {'Calories': 318.0,
#   'Protein': 21.6,
#   'TotalFat': 24.64,
#   'Carbohydrate': 2.47},
#  'CHEESE_MOZZARELLA_PART_SKIM_MILK': {'Calories': 254.0,
#   'Protein': 24.26,
#   'TotalFat': 15.92,
#   'Carbohydrate': 2.77},
#  'CHEESE_MOZZARELLA_PART_SKIM_MILK_LO_MOIST': {'Calories': 302.0,
#   'Protein': 25.96,
#   'TotalFat': 20.03,
#   'Carbohydrate': 3.83},
#  'CHEESE_MUENSTER': {'Calories': 368.0,
#   'Protein': 23.41,
#   'TotalFat': 30.04,
#   'Carbohydrate': 1.12},
#  'CHEESE_NEUFCHATEL': {'Calories': 253.0,
#   'Protein': 9.15,
#   'TotalFat': 22.78,
#   'Carbohydrate': 3.59},
#  'CHEESE_PARMESAN_GRATED': {'Calories': 431.0,
#   'Protein': 38.46,
#   'TotalFat': 28.61,
#   'Carbohydrate': 4.06},
#  'CHEESE_PARMESAN_HARD': {'Calories': 392.0,
#   'Protein': 35.75,
#   'TotalFat': 25.83,
#   'Carbohydrate': 3.22},
#  'CHEESE_PORT_DE_SALUT': {'Calories': 352.0,
#   'Protein': 23.78,
#   'TotalFat': 28.2,
#   'Carbohydrate': 0.57},
#  'CHEESE_PROVOLONE': {'Calories': 351.0,
#   'Protein': 25.58,
#   'TotalFat': 26.62,
#   'Carbohydrate': 2.14},
#  'CHEESE_RICOTTA_WHOLE_MILK': {'Calories': 174.0,
#   'Protein': 11.26,
#   'TotalFat': 12.98,
#   'Carbohydrate': 3.04},
#  'CHEESE_RICOTTA_PART_SKIM_MILK': {'Calories': 138.0,
#   'Protein': 11.39,
#   'TotalFat': 7.91,
#   'Carbohydrate': 5.14},
#  'CHEESE_ROMANO': {'Calories': 387.0,
#   'Protein': 31.8,
#   'TotalFat': 26.94,
#   'Carbohydrate': 3.63},
#  'CHEESE_ROQUEFORT': {'Calories': 369.0,
#   'Protein': 21.54,
#   'TotalFat': 30.64,
#   'Carbohydrate': 2.0},
#  'CHEESE_SWISS': {'Calories': 380.0,
#   'Protein': 26.93,
#   'TotalFat': 27.8,
#   'Carbohydrate': 5.38},
#  'CHEESE_TILSIT': {'Calories': 340.0,
#   'Protein': 24.41,
#   'TotalFat': 25.98,
#   'Carbohydrate': 1.88},
#  'CHEESE_PAST_PROCESS_AMERICAN_FORT_W_VITAMIN_D': {'Calories': 371.0,
#   'Protein': 18.13,
#   'TotalFat': 31.79,
#   'Carbohydrate': 3.7},
#  'CHEESE_PAST_PROCESS_PIMENTO': {'Calories': 375.0,
#   'Protein': 22.13,
#   'TotalFat': 31.2,
#   'Carbohydrate': 1.73},
#  'CHEESE_PAST_PROCESS_SWISS': {'Calories': 334.0,
#   'Protein': 24.73,
#   'TotalFat': 25.01,
#   'Carbohydrate': 2.1},
#  'CHEESE_FD_COLD_PK_AMERICAN': {'Calories': 331.0,
#   'Protein': 19.66,
#   'TotalFat': 24.46,
#   'Carbohydrate': 8.32},
#  'CHEESE_FD_PAST_PROCESS_AMERICAN_VITAMIN_D_FORT': {'Calories': 330.0,
#   'Protein': 16.86,
#   'TotalFat': 25.63,
#   'Carbohydrate': 8.56},
#  'CHEESE_FD_PAST_PROCESS_SWISS': {'Calories': 323.0,
#   'Protein': 21.92,
#   'TotalFat': 24.14,
#   'Carbohydrate': 4.5},
#  'CHEESE_SPRD_PAST_PROCESS_AMERICAN': {'Calories': 290.0,
#   'Protein': 16.41,
#   'TotalFat': 21.23,
#   'Carbohydrate': 8.73},
#  'CREAM_FLUID_HALF_AND_HALF': {'Calories': 130.0,
#   'Protein': 2.96,
#   'TotalFat': 11.5,
#   'Carbohydrate': 4.3},
#  'CREAM_FLUID_LT_COFFEE_CRM_OR_TABLE_CRM_': {'Calories': 195.0,
#   'Protein': 2.7,
#   'TotalFat': 19.31,
#   'Carbohydrate': 3.66},
#  'CREAM_FLUID_LT_WHIPPING': {'Calories': 292.0,
#   'Protein': 2.17,
#   'TotalFat': 30.91,
#   'Carbohydrate': 2.96},
#  'CREAM_FLUID_HVY_WHIPPING': {'Calories': 345.0,
#   'Protein': 2.05,
#   'TotalFat': 37.0,
#   'Carbohydrate': 2.79},
#  'CREAM_WHIPPED_CRM_TOPPING_PRESSURIZED': {'Calories': 257.0,
#   'Protein': 3.2,
#   'TotalFat': 22.22,
#   'Carbohydrate': 12.49},
#  'CREAM_SOUR_RED_FAT_CULTURED': {'Calories': 135.0,
#   'Protein': 2.94,
#   'TotalFat': 12.0,
#   'Carbohydrate': 4.26},
#  'CREAM_SOUR_CULTURED': {'Calories': 193.0,
#   'Protein': 2.07,
#   'TotalFat': 19.73,
#   'Carbohydrate': 2.88},
#  'EGGNOG': {'Calories': 88.0,
#   'Protein': 4.55,
#   'TotalFat': 4.19,
#   'Carbohydrate': 8.05},
#  'SOUR_DRSNG_NON_BUTTERFAT_CULTURED_FILLED_CREAM_TYPE': {'Calories': 178.0,
#   'Protein': 3.25,
#   'TotalFat': 16.57,
#   'Carbohydrate': 4.68},
#  'MILK_FILLED_FLUID_W_BLEND_OF_HYDR_VEG_OILS': {'Calories': 63.0,
#   'Protein': 3.33,
#   'TotalFat': 3.46,
#   'Carbohydrate': 4.74},
#  'MILK_FILLED_FLUID_W_LAURIC_ACID_OIL': {'Calories': 63.0,
#   'Protein': 3.33,
#   'TotalFat': 3.4,
#   'Carbohydrate': 4.74},
#  'CREAM_SUB_LIQ_W_HYDR_VEG_OIL_SOY_PROT': {'Calories': 136.0,
#   'Protein': 1.0,
#   'TotalFat': 9.97,
#   'Carbohydrate': 11.38},
#  'CREAM_SUB_LIQ_W_LAURIC_ACID_OIL_NA_CASEINATE': {'Calories': 136.0,
#   'Protein': 1.0,
#   'TotalFat': 9.97,
#   'Carbohydrate': 11.38},
#  'CREAM_SUBSTITUTE_POWDERED': {'Calories': 545.0,
#   'Protein': 4.79,
#   'TotalFat': 35.48,
#   'Carbohydrate': 54.88},
#  'DESSERT_TOPPING_POWDERED': {'Calories': 577.0,
#   'Protein': 4.9,
#   'TotalFat': 39.92,
#   'Carbohydrate': 52.54},
#  'DESSERT_TOPPING_PDR_1_5_OZ_PREP_W_1_2_CUP_MILK': {'Calories': 194.0,
#   'Protein': 3.61,
#   'TotalFat': 12.72,
#   'Carbohydrate': 17.13},
#  'DESSERT_TOPPING_PRESSURIZED': {'Calories': 264.0,
#   'Protein': 0.98,
#   'TotalFat': 22.3,
#   'Carbohydrate': 16.07},
#  'DESSERT_TOPPING_SEMI_SOLID_FRZ': {'Calories': 318.0,
#   'Protein': 1.25,
#   'TotalFat': 25.31,
#   'Carbohydrate': 23.05},
#  'SOUR_CRM_IMITN_CULTURED': {'Calories': 208.0,
#   'Protein': 2.4,
#   'TotalFat': 19.52,
#   'Carbohydrate': 6.63},
#  'MILK_SUBSTITUTES_FLUID_W_LAURIC_ACID_OIL': {'Calories': 61.0,
#   'Protein': 1.75,
#   'TotalFat': 3.41,
#   'Carbohydrate': 6.16},
#  'MILK_WHL_3_25_MILKFAT_W_ADDED_VITAMIN_D': {'Calories': 61.0,
#   'Protein': 3.15,
#   'TotalFat': 3.25,
#   'Carbohydrate': 4.8},
#  'MILK_PRODUCER_FLUID_3_7_MILKFAT': {'Calories': 64.0,
#   'Protein': 3.28,
#   'TotalFat': 3.66,
#   'Carbohydrate': 4.65},
#  'MILK_RED_FAT_FLUID_2_MILKFAT_W_ADDED_VIT_A_VITAMIN_D': {'Calories': 50.0,
#   'Protein': 3.3,
#   'TotalFat': 1.98,
#   'Carbohydrate': 4.8},
#  'MILK_RED_FAT_FLUID_2_MILKFAT_W_ADDED_NFMS_VIT_A_VIT_D': {'Calories': 51.0,
#   'Protein': 3.48,
#   'TotalFat': 1.92,
#   'Carbohydrate': 4.97},
#  'MILK_RED_FAT_FLUID_2_MILKFAT_PROT_FORT_W_ADDED_VIT_A_D': {'Calories': 56.0,
#   'Protein': 3.95,
#   'TotalFat': 1.98,
#   'Carbohydrate': 5.49},
#  'MILK_LOWFAT_FLUID_1_MILKFAT_W_ADDED_VIT_A_VITAMIN_D': {'Calories': 42.0,
#   'Protein': 3.37,
#   'TotalFat': 0.97,
#   'Carbohydrate': 4.99},
#  'MILK_LOWFAT_FLUID_1_MILKFAT_W_ADD_NONFAT_MILK_SOL_VIT_A_D': {'Calories': 43.0,
#   'Protein': 3.48,
#   'TotalFat': 0.97,
#   'Carbohydrate': 4.97},
#  'MILK_LOWFAT_FLUID_1_MILKFAT_PROT_FORT_W_ADDED_VIT_A_D': {'Calories': 48.0,
#   'Protein': 3.93,
#   'TotalFat': 1.17,
#   'Carbohydrate': 5.52},
#  'MILK_NONFAT_FLUID_W_ADDED_VIT_A_VIT_D_FAT_FREE_OR_SKIM_': {'Calories': 34.0,
#   'Protein': 3.37,
#   'TotalFat': 0.08,
#   'Carbohydrate': 4.96},
#  'MILK_NONFAT_FLUID_W_ADDED_NONFAT_MILK_SOL_VIT_A_VIT_D': {'Calories': 37.0,
#   'Protein': 3.57,
#   'TotalFat': 0.25,
#   'Carbohydrate': 5.02},
#  'MILK_NONFAT_FLUID_PROT_FORT_W_ADD_VIT_A_D_FAT_FREE_SKIM_': {'Calories': 41.0,
#   'Protein': 3.96,
#   'TotalFat': 0.25,
#   'Carbohydrate': 5.56},
#  'MILK_BTTRMLK_FLUID_CULTURED_LOWFAT': {'Calories': 40.0,
#   'Protein': 3.31,
#   'TotalFat': 0.88,
#   'Carbohydrate': 4.79},
#  'MILK_LO_NA_FLUID': {'Calories': 61.0,
#   'Protein': 3.1,
#   'TotalFat': 3.46,
#   'Carbohydrate': 4.46},
#  'MILK_DRY_WHL_W_ADDED_VITAMIN_D': {'Calories': 496.0,
#   'Protein': 26.32,
#   'TotalFat': 26.71,
#   'Carbohydrate': 38.42},
#  'MILK_DRY_NONFAT_REG_WO_ADDED_VIT_A_VITAMIN_D': {'Calories': 362.0,
#   'Protein': 36.16,
#   'TotalFat': 0.77,
#   'Carbohydrate': 51.98},
#  'MILK_DRY_NONFAT_INST_W_ADDED_VIT_A_VITAMIN_D': {'Calories': 358.0,
#   'Protein': 35.1,
#   'TotalFat': 0.72,
#   'Carbohydrate': 52.19},
#  'MILK_DRY_NONFAT_CA_RED': {'Calories': 354.0,
#   'Protein': 35.5,
#   'TotalFat': 0.2,
#   'Carbohydrate': 51.8},
#  'MILK_BUTTERMILK_DRIED': {'Calories': 387.0,
#   'Protein': 34.3,
#   'TotalFat': 5.78,
#   'Carbohydrate': 49.0},
#  'MILK_CND_COND_SWTND': {'Calories': 321.0,
#   'Protein': 7.91,
#   'TotalFat': 8.7,
#   'Carbohydrate': 54.4},
#  'MILK_CND_EVAP_W_ADDED_VITAMIN_D_WO_ADDED_VIT_A': {'Calories': 134.0,
#   'Protein': 6.81,
#   'TotalFat': 7.56,
#   'Carbohydrate': 10.04},
#  'MILK_CND_EVAP_NONFAT_W_ADDED_VIT_A_VITAMIN_D': {'Calories': 78.0,
#   'Protein': 7.55,
#   'TotalFat': 0.2,
#   'Carbohydrate': 11.35},
#  'MILK_CHOC_FLUID_COMM_WHL_W_ADDED_VIT_A_VITAMIN_D': {'Calories': 83.0,
#   'Protein': 3.17,
#   'TotalFat': 3.39,
#   'Carbohydrate': 10.34},
#  'MILK_CHOC_FLUID_COMM_RED_FAT': {'Calories': 76.0,
#   'Protein': 2.99,
#   'TotalFat': 1.9,
#   'Carbohydrate': 12.13},
#  'MILK_CHOC_FLUID_COMM_LOWFAT_W_ADDED_VIT_A_VITAMIN_D': {'Calories': 63.0,
#   'Protein': 3.24,
#   'TotalFat': 1.0,
#   'Carbohydrate': 10.44},
#  'MILK_CHOC_BEV_HOT_COCOA_HOMEMADE': {'Calories': 77.0,
#   'Protein': 3.52,
#   'TotalFat': 2.34,
#   'Carbohydrate': 10.74},
#  'MILK_GOAT_FLUID_W_ADDED_VITAMIN_D': {'Calories': 69.0,
#   'Protein': 3.56,
#   'TotalFat': 4.14,
#   'Carbohydrate': 4.45},
#  'MILK_HUMAN_MATURE_FLUID': {'Calories': 70.0,
#   'Protein': 1.03,
#   'TotalFat': 4.38,
#   'Carbohydrate': 6.89},
#  'MILK_INDIAN_BUFFALO_FLUID': {'Calories': 97.0,
#   'Protein': 3.75,
#   'TotalFat': 6.89,
#   'Carbohydrate': 5.18},
#  'MILK_SHEEP_FLUID': {'Calories': 108.0,
#   'Protein': 5.98,
#   'TotalFat': 7.0,
#   'Carbohydrate': 5.36},
#  'MILK_SHAKES_THICK_CHOC': {'Calories': 119.0,
#   'Protein': 3.05,
#   'TotalFat': 2.7,
#   'Carbohydrate': 21.15},
#  'MILK_SHAKES_THICK_VANILLA': {'Calories': 112.0,
#   'Protein': 3.86,
#   'TotalFat': 3.03,
#   'Carbohydrate': 17.75},
#  'WHEY_ACID_FLUID': {'Calories': 24.0,
#   'Protein': 0.76,
#   'TotalFat': 0.09,
#   'Carbohydrate': 5.12},
#  'WHEY_ACID_DRIED': {'Calories': 339.0,
#   'Protein': 11.73,
#   'TotalFat': 0.54,
#   'Carbohydrate': 73.45},
#  'WHEY_SWEET_FLUID': {'Calories': 27.0,
#   'Protein': 0.85,
#   'TotalFat': 0.36,
#   'Carbohydrate': 5.14},
#  'WHEY_SWEET_DRIED': {'Calories': 353.0,
#   'Protein': 12.93,
#   'TotalFat': 1.07,
#   'Carbohydrate': 74.46},
#  'YOGURT_PLN_WHL_MILK_8_GRAMS_PROT_PER_8_OZ': {'Calories': 61.0,
#   'Protein': 3.47,
#   'TotalFat': 3.25,
#   'Carbohydrate': 4.66},
#  'YOGURT_PLN_LOFAT_12_GRAMS_PROT_PER_8_OZ': {'Calories': 63.0,
#   'Protein': 5.25,
#   'TotalFat': 1.55,
#   'Carbohydrate': 7.04},
#  'YOGURT_PLN_SKIM_MILK_13_GRAMS_PROT_PER_8_OZ': {'Calories': 56.0,
#   'Protein': 5.73,
#   'TotalFat': 0.18,
#   'Carbohydrate': 7.68},
#  'YOGURT_VANILLA_LOFAT_11_GRAMS_PROT_PER_8_OZ': {'Calories': 85.0,
#   'Protein': 4.93,
#   'TotalFat': 1.25,
#   'Carbohydrate': 13.8},
#  'YOGURT_FRUIT_LOFAT_9_GRAMS_PROT_PER_8_OZ': {'Calories': 99.0,
#   'Protein': 3.98,
#   'TotalFat': 1.15,
#   'Carbohydrate': 18.64},
#  'YOGURT_FRUIT_LOFAT_10_GRAMS_PROT_PER_8_OZ': {'Calories': 102.0,
#   'Protein': 4.37,
#   'TotalFat': 1.08,
#   'Carbohydrate': 19.05},
#  'YOGURT_FRUIT_LOFAT_11_GRAMS_PROT_PER_8_OZ': {'Calories': 105.0,
#   'Protein': 4.86,
#   'TotalFat': 1.41,
#   'Carbohydrate': 18.6},
#  'EGG_WHL_RAW_FRSH': {'Calories': 143.0,
#   'Protein': 12.56,
#   'TotalFat': 9.51,
#   'Carbohydrate': 0.72},
#  'EGG_WHITE_RAW_FRESH': {'Calories': 52.0,
#   'Protein': 10.9,
#   'TotalFat': 0.17,
#   'Carbohydrate': 0.73},
#  'EGG_YOLK_RAW_FRSH': {'Calories': 322.0,
#   'Protein': 15.86,
#   'TotalFat': 26.54,
#   'Carbohydrate': 3.59},
#  'EGG_YOLK_RAW_FROZEN': {'Calories': 303.0,
#   'Protein': 15.5,
#   'TotalFat': 25.6,
#   'Carbohydrate': 1.15},
#  'EGG_YOLK_RAW_FRZ_SUGARED': {'Calories': 307.0,
#   'Protein': 13.8,
#   'TotalFat': 22.75,
#   'Carbohydrate': 10.8},
#  'EGG_WHL_CKD_FRIED': {'Calories': 196.0,
#   'Protein': 13.61,
#   'TotalFat': 14.84,
#   'Carbohydrate': 0.83},
#  'EGG_WHL_CKD_HARD_BOILED': {'Calories': 155.0,
#   'Protein': 12.58,
#   'TotalFat': 10.61,
#   'Carbohydrate': 1.12},
#  'EGG_WHOLE_COOKED_OMELET': {'Calories': 154.0,
#   'Protein': 10.57,
#   'TotalFat': 11.66,
#   'Carbohydrate': 0.64},
#  'EGG_WHL_CKD_POACHED': {'Calories': 143.0,
#   'Protein': 12.51,
#   'TotalFat': 9.47,
#   'Carbohydrate': 0.71},
#  'EGG_WHL_CKD_SCRMBLD': {'Calories': 149.0,
#   'Protein': 9.99,
#   'TotalFat': 10.98,
#   'Carbohydrate': 1.61},
#  'EGG_WHOLE_DRIED': {'Calories': 594.0,
#   'Protein': 47.35,
#   'TotalFat': 40.95,
#   'Carbohydrate': 4.95},
#  'EGG_WHL_DRIED_STABILIZED_GLUCOSE_RED': {'Calories': 615.0,
#   'Protein': 48.17,
#   'TotalFat': 43.95,
#   'Carbohydrate': 2.38},
#  'EGG_WHITE_DRIED_FLAKES_GLUCOSE_RED': {'Calories': 351.0,
#   'Protein': 76.92,
#   'TotalFat': 0.04,
#   'Carbohydrate': 4.17},
#  'EGG_WHITE_DRIED_PDR_GLUCOSE_RED': {'Calories': 376.0,
#   'Protein': 82.4,
#   'TotalFat': 0.04,
#   'Carbohydrate': 4.47},
#  'EGG_YOLK_DRIED': {'Calories': 666.0,
#   'Protein': 34.25,
#   'TotalFat': 55.8,
#   'Carbohydrate': 3.6},
#  'EGG_DUCK_WHOLE_FRESH_RAW': {'Calories': 185.0,
#   'Protein': 12.81,
#   'TotalFat': 13.77,
#   'Carbohydrate': 1.45},
#  'EGG_GOOSE_WHOLE_FRESH_RAW': {'Calories': 185.0,
#   'Protein': 13.87,
#   'TotalFat': 13.27,
#   'Carbohydrate': 1.35},
#  'EGG_QUAIL_WHOLE_FRESH_RAW': {'Calories': 158.0,
#   'Protein': 13.05,
#   'TotalFat': 11.09,
#   'Carbohydrate': 0.41},
#  'EGG_TURKEY_WHL_FRSH_RAW': {'Calories': 171.0,
#   'Protein': 13.68,
#   'TotalFat': 11.88,
#   'Carbohydrate': 1.15},
#  'EGG_SUBSTITUTE_POWDER': {'Calories': 444.0,
#   'Protein': 55.5,
#   'TotalFat': 13.0,
#   'Carbohydrate': 21.8},
#  'BUTTER_WITHOUT_SALT': {'Calories': 717.0,
#   'Protein': 0.85,
#   'TotalFat': 81.11,
#   'Carbohydrate': 0.06},
#  'CHEESE_PARMESAN_SHREDDED': {'Calories': 415.0,
#   'Protein': 37.86,
#   'TotalFat': 27.34,
#   'Carbohydrate': 3.41},
#  'MILK_NONFAT_FLUID_WO_ADDED_VIT_A_VIT_D_FAT_FREE_OR_SKIM_': {'Calories': 34.0,
#   'Protein': 3.37,
#   'TotalFat': 0.08,
#   'Carbohydrate': 4.96},
#  'MILK_RED_FAT_FLUID_2_MILKFAT_W_NONFAT_MILK_SOL_WO_VIT_A': {'Calories': 56.0,
#   'Protein': 3.95,
#   'TotalFat': 1.98,
#   'Carbohydrate': 5.49},
#  'MILK_CND_EVAP_W_VIT_A': {'Calories': 134.0,
#   'Protein': 6.81,
#   'TotalFat': 7.56,
#   'Carbohydrate': 10.04},
#  'MILK_DRY_NONFAT_REG_W_ADDED_VIT_A_VITAMIN_D': {'Calories': 362.0,
#   'Protein': 36.16,
#   'TotalFat': 0.77,
#   'Carbohydrate': 51.98},
#  'MILK_DRY_NONFAT_INST_WO_ADDED_VIT_A_VITAMIN_D': {'Calories': 358.0,
#   'Protein': 35.1,
#   'TotalFat': 0.72,
#   'Carbohydrate': 52.19},
#  'CHEESE_GOAT_HARD_TYPE': {'Calories': 452.0,
#   'Protein': 30.52,
#   'TotalFat': 35.59,
#   'Carbohydrate': 2.17},
#  'CHEESE_GOAT_SEMISOFT_TYPE': {'Calories': 364.0,
#   'Protein': 21.58,
#   'TotalFat': 29.84,
#   'Carbohydrate': 2.54},
#  'CHEESE_GOAT_SOFT_TYPE': {'Calories': 268.0,
#   'Protein': 18.52,
#   'TotalFat': 21.08,
#   'Carbohydrate': 0.89},
#  'EGG_YOLK_RAW_FRZ_SALTED': {'Calories': 274.0,
#   'Protein': 14.0,
#   'TotalFat': 23.0,
#   'Carbohydrate': 1.6},
#  'CHEESE_SUB_MOZZARELLA': {'Calories': 248.0,
#   'Protein': 11.47,
#   'TotalFat': 12.22,
#   'Carbohydrate': 23.67},
#  'CHEESE_FONDUE': {'Calories': 229.0,
#   'Protein': 14.23,
#   'TotalFat': 13.47,
#   'Carbohydrate': 3.77},
#  'CHEESE_SAU_PREP_FROM_RECIPE': {'Calories': 197.0,
#   'Protein': 10.33,
#   'TotalFat': 14.92,
#   'Carbohydrate': 5.48},
#  'CHEESE_MEXICAN_QUESO_ANEJO': {'Calories': 373.0,
#   'Protein': 21.44,
#   'TotalFat': 29.98,
#   'Carbohydrate': 4.63},
#  'CHEESE_MEXICAN_QUESO_ASADERO': {'Calories': 356.0,
#   'Protein': 22.6,
#   'TotalFat': 28.26,
#   'Carbohydrate': 2.87},
#  'CHEESE_MEXICAN_QUESO_CHIHUAHUA': {'Calories': 374.0,
#   'Protein': 21.56,
#   'TotalFat': 29.68,
#   'Carbohydrate': 5.56},
#  'CHEESE_LOFAT_CHEDDAR_OR_COLBY': {'Calories': 173.0,
#   'Protein': 24.35,
#   'TotalFat': 7.0,
#   'Carbohydrate': 1.91},
#  'CHEESE_LOW_SODIUM_CHEDDAR_OR_COLBY': {'Calories': 398.0,
#   'Protein': 24.35,
#   'TotalFat': 32.62,
#   'Carbohydrate': 1.91},
#  'EGG_WHOLE_RAW_FROZEN': {'Calories': 148.0,
#   'Protein': 11.95,
#   'TotalFat': 10.2,
#   'Carbohydrate': 1.05},
#  'EGG_WHITE_RAW_FROZEN': {'Calories': 47.0,
#   'Protein': 9.8,
#   'TotalFat': 0.0,
#   'Carbohydrate': 1.05},
#  'EGG_WHITE_DRIED': {'Calories': 382.0,
#   'Protein': 81.1,
#   'TotalFat': 0.0,
#   'Carbohydrate': 7.8},
#  'MILK_RED_FAT_FLUID_2_MILKFAT_WO_ADDED_VIT_A_VIT_D': {'Calories': 50.0,
#   'Protein': 3.3,
#   'TotalFat': 1.98,
#   'Carbohydrate': 4.8},
#  'MILK_FLUID_1_FAT_WO_ADDED_VIT_A_VIT_D': {'Calories': 42.0,
#   'Protein': 3.37,
#   'TotalFat': 0.97,
#   'Carbohydrate': 4.99},
#  'SOUR_CREAM_REDUCED_FAT': {'Calories': 181.0,
#   'Protein': 7.0,
#   'TotalFat': 14.1,
#   'Carbohydrate': 7.0},
#  'SOUR_CREAM_LIGHT': {'Calories': 138.0,
#   'Protein': 3.5,
#   'TotalFat': 10.6,
#   'Carbohydrate': 7.1},
#  'SOUR_CREAM_FAT_FREE': {'Calories': 74.0,
#   'Protein': 3.1,
#   'TotalFat': 0.0,
#   'Carbohydrate': 15.6},
#  'USDA_COMMODITY_CHS_CHEDDAR_RED_FAT': {'Calories': 282.0,
#   'Protein': 27.2,
#   'TotalFat': 18.3,
#   'Carbohydrate': 2.0},
#  'YOGURT_VAN_OR_LEM_FLAV_NONFAT_MILK_SWTND_W_LOW_CALORIE_SWTNR': {'Calories': 43.0,
#   'Protein': 3.86,
#   'TotalFat': 0.18,
#   'Carbohydrate': 7.5},
#  'PARMESAN_CHS_TOPPING_FAT_FREE': {'Calories': 370.0,
#   'Protein': 40.0,
#   'TotalFat': 5.0,
#   'Carbohydrate': 40.0},
#  'CHEESE_CREAM_FAT_FREE': {'Calories': 105.0,
#   'Protein': 15.69,
#   'TotalFat': 1.0,
#   'Carbohydrate': 7.66},
#  'YOGURT_CHOC_NONFAT_MILK': {'Calories': 112.0,
#   'Protein': 3.53,
#   'TotalFat': 0.0,
#   'Carbohydrate': 23.53},
#  'KRAFT_CHEEZ_WHIZ_PAST_PROCESS_CHS_SAU': {'Calories': 276.0,
#   'Protein': 12.0,
#   'TotalFat': 21.0,
#   'Carbohydrate': 9.2},
#  'KRAFT_CHEEZ_WHIZ_LT_PAST_PROCESS_CHS_PRODUCT': {'Calories': 215.0,
#   'Protein': 16.3,
#   'TotalFat': 9.5,
#   'Carbohydrate': 16.2},
#  'KRAFT_FREE_SINGLES_AMERICAN_NONFAT_PAST_PROCESS_CHS_PRODUCT': {'Calories': 148.0,
#   'Protein': 22.7,
#   'TotalFat': 1.0,
#   'Carbohydrate': 11.7},
#  'KRAFT_VELVEETA_PAST_PROCESS_CHS_SPRD': {'Calories': 303.0,
#   'Protein': 16.3,
#   'TotalFat': 22.0,
#   'Carbohydrate': 9.8},
#  'KRAFT_VELVEETA_LT_RED_FAT_PAST_PROCESS_CHS_PRODUCT': {'Calories': 222.0,
#   'Protein': 19.6,
#   'TotalFat': 10.6,
#   'Carbohydrate': 11.8},
#  'KRAFT_BREAKSTONE_S_RED_FAT_SOUR_CRM': {'Calories': 152.0,
#   'Protein': 4.5,
#   'TotalFat': 12.0,
#   'Carbohydrate': 6.5},
#  'KRAFT_BREAKSTONE_S_FREE_FAT_FREE_SOUR_CRM': {'Calories': 91.0,
#   'Protein': 4.7,
#   'TotalFat': 1.3,
#   'Carbohydrate': 15.1},
#  'KRAFT_BREYERS_LOWFAT_STRAWBERRY_YOGURT_1_MILKFAT_': {'Calories': 96.0,
#   'Protein': 3.8,
#   'TotalFat': 0.8,
#   'Carbohydrate': 18.2},
#  'KRAFT_BREYERS_LT_N_LVLY_LOWFAT_STR_BERY_YOGURT_1_MILKFAT_': {'Calories': 108.0,
#   'Protein': 3.2,
#   'TotalFat': 0.8,
#   'Carbohydrate': 21.9},
#  'KRAFT_BREYERS_SMOTH_CRMY_LOWFAT_STR_BERY_YOGURT_1_MILKFAT_': {'Calories': 102.0,
#   'Protein': 3.8,
#   'TotalFat': 0.9,
#   'Carbohydrate': 19.9},
#  'KRAFT_BREYERS_LT_NONFAT_STR_BERY_YOGURT_W_ASPRT_FRUCT_SW_T_': {'Calories': 55.0,
#   'Protein': 3.4,
#   'TotalFat': 0.2,
#   'Carbohydrate': 9.9},
#  'CREAM_HALF_HALF_FAT_FREE': {'Calories': 59.0,
#   'Protein': 2.6,
#   'TotalFat': 1.4,
#   'Carbohydrate': 9.0},
#  'REDDI_WIP_FAT_FREE_WHIPPED_TOPPING': {'Calories': 149.0,
#   'Protein': 3.0,
#   'TotalFat': 5.0,
#   'Carbohydrate': 25.0},
#  'MILK_CHOC_FLUID_COMM_RED_FAT_W_ADDED_CA': {'Calories': 78.0,
#   'Protein': 2.99,
#   'TotalFat': 1.9,
#   'Carbohydrate': 12.13},
#  'YOGURT_FRUIT_LOFAT_W_LO_CAL_SWEETENER': {'Calories': 105.0,
#   'Protein': 4.86,
#   'TotalFat': 1.41,
#   'Carbohydrate': 18.6},
#  'CHEESE_PARMESAN_DRY_GRATED_RED_FAT': {'Calories': 265.0,
#   'Protein': 20.0,
#   'TotalFat': 20.0,
#   'Carbohydrate': 1.37},
#  'CREAM_SUB_FLAV_LIQ': {'Calories': 251.0,
#   'Protein': 0.69,
#   'TotalFat': 13.5,
#   'Carbohydrate': 35.07},
#  'CREAM_SUB_FLAV_PDR': {'Calories': 498.0,
#   'Protein': 0.68,
#   'TotalFat': 21.47,
#   'Carbohydrate': 75.42},
#  'CHEESE_PROVOLONE_RED_FAT': {'Calories': 274.0,
#   'Protein': 24.7,
#   'TotalFat': 17.6,
#   'Carbohydrate': 3.5},
#  'CHEESE_MEXICAN_BLEND_RED_FAT': {'Calories': 282.0,
#   'Protein': 24.69,
#   'TotalFat': 19.4,
#   'Carbohydrate': 3.41},
#  'EGG_MIX_USDA_CMDTY': {'Calories': 555.0,
#   'Protein': 35.6,
#   'TotalFat': 34.5,
#   'Carbohydrate': 23.97},
#  'MILK_WHL_3_25_MILKFAT_WO_ADDED_VIT_A_VITAMIN_D': {'Calories': 61.0,
#   'Protein': 3.15,
#   'TotalFat': 3.27,
#   'Carbohydrate': 4.78},
#  'MILK_DRY_WHL_WO_ADDED_VITAMIN_D': {'Calories': 496.0,
#   'Protein': 26.32,
#   'TotalFat': 26.71,
#   'Carbohydrate': 38.42},
#  'MILK_CND_EVAP_WO_ADDED_VIT_A_VITAMIN_D': {'Calories': 135.0,
#   'Protein': 6.81,
#   'TotalFat': 7.56,
#   'Carbohydrate': 10.04},
#  'CHEESE_PRODUCT_PAST_PROCESS_AMERICAN_RED_FAT_FORT_W_VIT_D': {'Calories': 240.0,
#   'Protein': 17.6,
#   'TotalFat': 14.1,
#   'Carbohydrate': 10.6},
#  'YOGURT_FRUIT_LOFAT_9_GRAMS_PROT_PER_8_OZ_FORT_W_VITAMIN_D': {'Calories': 99.0,
#   'Protein': 3.98,
#   'TotalFat': 1.15,
#   'Carbohydrate': 18.64},
#  'YOGURT_FRUIT_LOFAT_10_GRAMS_PROT_PER_8_OZ_FORT_W_VITAMIN_D': {'Calories': 102.0,
#   'Protein': 4.37,
#   'TotalFat': 1.08,
#   'Carbohydrate': 19.05},
#  'YOGURT_FRUIT_VAR_NONFAT_FORT_W_VITAMIN_D': {'Calories': 95.0,
#   'Protein': 4.4,
#   'TotalFat': 0.2,
#   'Carbohydrate': 19.0},
#  'YOGURT_FRUIT_LOWFAT_W_LO_CAL_SWTNR_FORT_W_VITAMIN_D': {'Calories': 105.0,
#   'Protein': 4.86,
#   'TotalFat': 1.41,
#   'Carbohydrate': 18.6},
#  'YOGURT_VANILLA_LOFAT_11_GRAMS_PROT_PER_8_OZ_FORT_W_VIT_D': {'Calories': 85.0,
#   'Protein': 4.93,
#   'TotalFat': 1.25,
#   'Carbohydrate': 13.8},
#  'YOGURT_VAN_LEM_FLAV_NONFAT_MILK_W_LO_CAL_SWTNR_FORT_W_VIT_D': {'Calories': 43.0,
#   'Protein': 3.86,
#   'TotalFat': 0.18,
#   'Carbohydrate': 7.5},
#  'YOGURT_CHOC_NONFAT_MILK_FORT_W_VITAMIN_D': {'Calories': 112.0,
#   'Protein': 3.53,
#   'TotalFat': 0.0,
#   'Carbohydrate': 23.53},
#  'PROTEIN_SUPP_MILK_BSD_MUSCLE_MILK_PDR': {'Calories': 411.0,
#   'Protein': 45.71,
#   'TotalFat': 17.14,
#   'Carbohydrate': 18.5},
#  'PROTEIN_SUPP_MILK_BSD_MUSCLE_MILK_LT_PDR': {'Calories': 396.0,
#   'Protein': 50.0,
#   'TotalFat': 12.0,
#   'Carbohydrate': 22.0},
#  'DULCE_DE_LECHE': {'Calories': 315.0,
#   'Protein': 6.84,
#   'TotalFat': 7.35,
#   'Carbohydrate': 55.35},
#  'EGG_SUB_LIQ_OR_FRZ_FAT_FREE': {'Calories': 48.0,
#   'Protein': 10.0,
#   'TotalFat': 0.0,
#   'Carbohydrate': 2.0},
#  'CHEESE_DRY_WHITE_QUESO_SECO': {'Calories': 325.0,
#   'Protein': 24.51,
#   'TotalFat': 24.35,
#   'Carbohydrate': 2.04},
#  'CHEESE_FRSH_QUESO_FRESCO': {'Calories': 299.0,
#   'Protein': 18.09,
#   'TotalFat': 23.82,
#   'Carbohydrate': 2.98},
#  'CHEESE_WHITE_QUESO_BLANCO': {'Calories': 310.0,
#   'Protein': 20.38,
#   'TotalFat': 24.31,
#   'Carbohydrate': 2.53},
#  'MILK_BTTRMLK_FLUID_WHL': {'Calories': 62.0,
#   'Protein': 3.21,
#   'TotalFat': 3.31,
#   'Carbohydrate': 4.88},
#  'YOGURT_VANILLA_FLAVOR_LOWFAT_MILK_SWTND_W_LO_CAL_SWTNR': {'Calories': 86.0,
#   'Protein': 4.93,
#   'TotalFat': 1.25,
#   'Carbohydrate': 13.8},
#  'YOGURT_FRZ_FLAVORS_NOT_CHOC_NONFAT_MILK_W_LOW_CALORIE_SWTNR': {'Calories': 104.0,
#   'Protein': 4.4,
#   'TotalFat': 0.8,
#   'Carbohydrate': 19.7},
#  'ICE_CRM_SOFT_SERVE_CHOC': {'Calories': 222.0,
#   'Protein': 4.1,
#   'TotalFat': 13.0,
#   'Carbohydrate': 22.2},
#  'ICE_CRM_BAR_OR_STK_CHOC_COVERED': {'Calories': 331.0,
#   'Protein': 4.1,
#   'TotalFat': 24.1,
#   'Carbohydrate': 24.5},
#  'ICE_CRM_SNDWCH': {'Calories': 237.0,
#   'Protein': 4.29,
#   'TotalFat': 8.57,
#   'Carbohydrate': 37.14},
#  'ICE_CRM_COOKIE_SNDWCH': {'Calories': 240.0,
#   'Protein': 3.7,
#   'TotalFat': 7.4,
#   'Carbohydrate': 39.6},
#  'ICE_CRM_CONE_CHOC_COVERED_W_NUTS_FLAVORS_OTHER_THAN_CHOC': {'Calories': 354.0,
#   'Protein': 5.21,
#   'TotalFat': 21.88,
#   'Carbohydrate': 34.38},
#  'ICE_CRM_SNDWCH_MADE_W_LT_ICE_CRM_VANILLA': {'Calories': 186.0,
#   'Protein': 4.29,
#   'TotalFat': 3.04,
#   'Carbohydrate': 39.64},
#  'ICE_CRM_SNDWCH_VANILLA_LT_NO_SUGAR_ADDED': {'Calories': 200.0,
#   'Protein': 5.71,
#   'TotalFat': 2.86,
#   'Carbohydrate': 42.86},
#  'FAT_FREE_ICE_CRM_NO_SUGAR_ADDED_FLAVORS_OTHER_THAN_CHOC': {'Calories': 129.0,
#   'Protein': 4.41,
#   'TotalFat': 0.0,
#   'Carbohydrate': 27.94},
#  'MILK_DSSRT_BAR_FRZ_MADE_FROM_LOWFAT_MILK': {'Calories': 147.0,
#   'Protein': 4.41,
#   'TotalFat': 1.47,
#   'Carbohydrate': 33.09},
#  'NUTRITIONAL_SUPP_FOR_PEOPLE_W_DIABETES_LIQ': {'Calories': 88.0,
#   'Protein': 4.4,
#   'TotalFat': 3.08,
#   'Carbohydrate': 11.88},
#  'CHEESE_MEXICAN_BLEND': {'Calories': 358.0,
#   'Protein': 23.54,
#   'TotalFat': 28.51,
#   'Carbohydrate': 1.75},
#  'CHEESE_PRODUCT_PAST_PROCESS_AMERICAN_VITAMIN_D_FORT': {'Calories': 310.0,
#   'Protein': 18.18,
#   'TotalFat': 22.63,
#   'Carbohydrate': 8.52},
#  'CHEESE_PAST_PROCESS_AMERICAN_WO_ADDED_VITAMIN_D': {'Calories': 371.0,
#   'Protein': 18.13,
#   'TotalFat': 31.79,
#   'Carbohydrate': 3.7},
#  'CHEESE_FD_PAST_PROCESS_AMERICAN_WO_ADDED_VITAMIN_D': {'Calories': 330.0,
#   'Protein': 16.86,
#   'TotalFat': 25.63,
#   'Carbohydrate': 8.56},
#  'EGG_WHL_RAW_FRZ_SALTED': {'Calories': 138.0,
#   'Protein': 10.97,
#   'TotalFat': 10.07,
#   'Carbohydrate': 0.83},
#  'ALLSPICE_GROUND': {'Calories': 263.0,
#   'Protein': 6.09,
#   'TotalFat': 8.69,
#   'Carbohydrate': 72.12},
#  'ANISE_SEED': {'Calories': 337.0,
#   'Protein': 17.6,
#   'TotalFat': 15.9,
#   'Carbohydrate': 50.02},
#  'SPICES_BASIL_DRIED': {'Calories': 233.0,
#   'Protein': 22.98,
#   'TotalFat': 4.07,
#   'Carbohydrate': 47.75},
#  'SPICES_BAY_LEAF': {'Calories': 313.0,
#   'Protein': 7.61,
#   'TotalFat': 8.36,
#   'Carbohydrate': 74.97},
#  'CARAWAY_SEED': {'Calories': 333.0,
#   'Protein': 19.77,
#   'TotalFat': 14.59,
#   'Carbohydrate': 49.9},
#  'SPICES_CARDAMOM': {'Calories': 311.0,
#   'Protein': 10.76,
#   'TotalFat': 6.7,
#   'Carbohydrate': 68.47},
#  'CELERY_SEED': {'Calories': 392.0,
#   'Protein': 18.07,
#   'TotalFat': 25.27,
#   'Carbohydrate': 41.35},
#  'CHERVIL_DRIED': {'Calories': 237.0,
#   'Protein': 23.2,
#   'TotalFat': 3.9,
#   'Carbohydrate': 49.1},
#  'CHILI_POWDER': {'Calories': 282.0,
#   'Protein': 13.46,
#   'TotalFat': 14.28,
#   'Carbohydrate': 49.7},
#  'CINNAMON_GROUND': {'Calories': 247.0,
#   'Protein': 3.99,
#   'TotalFat': 1.24,
#   'Carbohydrate': 80.59},
#  'CLOVES_GROUND': {'Calories': 274.0,
#   'Protein': 5.97,
#   'TotalFat': 13.0,
#   'Carbohydrate': 65.53},
#  'CORIANDER_LEAF_DRIED': {'Calories': 279.0,
#   'Protein': 21.93,
#   'TotalFat': 4.78,
#   'Carbohydrate': 52.1},
#  'CORIANDER_SEED': {'Calories': 298.0,
#   'Protein': 12.37,
#   'TotalFat': 17.77,
#   'Carbohydrate': 54.99},
#  'CUMIN_SEED': {'Calories': 375.0,
#   'Protein': 17.81,
#   'TotalFat': 22.27,
#   'Carbohydrate': 44.24},
#  'CURRY_POWDER': {'Calories': 325.0,
#   'Protein': 12.66,
#   'TotalFat': 13.81,
#   'Carbohydrate': 58.15},
#  'DILL_SEED': {'Calories': 305.0,
#   'Protein': 15.98,
#   'TotalFat': 14.54,
#   'Carbohydrate': 55.17},
#  'DILL_WEED_DRIED': {'Calories': 253.0,
#   'Protein': 19.96,
#   'TotalFat': 4.36,
#   'Carbohydrate': 55.82},
#  'FENNEL_SEED': {'Calories': 345.0,
#   'Protein': 15.8,
#   'TotalFat': 14.87,
#   'Carbohydrate': 52.29},
#  'FENUGREEK_SEED': {'Calories': 323.0,
#   'Protein': 23.0,
#   'TotalFat': 6.41,
#   'Carbohydrate': 58.35},
#  'GARLIC_POWDER': {'Calories': 331.0,
#   'Protein': 16.55,
#   'TotalFat': 0.73,
#   'Carbohydrate': 72.73},
#  'GINGER_GROUND': {'Calories': 335.0,
#   'Protein': 8.98,
#   'TotalFat': 4.24,
#   'Carbohydrate': 71.62},
#  'MACE_GROUND': {'Calories': 475.0,
#   'Protein': 6.71,
#   'TotalFat': 32.38,
#   'Carbohydrate': 50.5},
#  'MARJORAM_DRIED': {'Calories': 271.0,
#   'Protein': 12.66,
#   'TotalFat': 7.04,
#   'Carbohydrate': 60.56},
#  'SPICES_MUSTARD_SD_GROUND': {'Calories': 508.0,
#   'Protein': 26.08,
#   'TotalFat': 36.24,
#   'Carbohydrate': 28.09},
#  'NUTMEG_GROUND': {'Calories': 525.0,
#   'Protein': 5.84,
#   'TotalFat': 36.31,
#   'Carbohydrate': 49.29},
#  'ONION_POWDER': {'Calories': 341.0,
#   'Protein': 10.41,
#   'TotalFat': 1.04,
#   'Carbohydrate': 79.12},
#  'SPICES_OREGANO_DRIED': {'Calories': 265.0,
#   'Protein': 9.0,
#   'TotalFat': 4.28,
#   'Carbohydrate': 68.92},
#  'PAPRIKA': {'Calories': 282.0,
#   'Protein': 14.14,
#   'TotalFat': 12.89,
#   'Carbohydrate': 53.99},
#  'PARSLEY_DRIED': {'Calories': 292.0,
#   'Protein': 26.63,
#   'TotalFat': 5.48,
#   'Carbohydrate': 50.64},
#  'PEPPER_BLACK': {'Calories': 251.0,
#   'Protein': 10.39,
#   'TotalFat': 3.26,
#   'Carbohydrate': 63.95},
#  'PEPPER_RED_OR_CAYENNE': {'Calories': 318.0,
#   'Protein': 12.01,
#   'TotalFat': 17.27,
#   'Carbohydrate': 56.63},
#  'PEPPER_WHITE': {'Calories': 296.0,
#   'Protein': 10.4,
#   'TotalFat': 2.12,
#   'Carbohydrate': 68.61},
#  'POPPY_SEED': {'Calories': 525.0,
#   'Protein': 17.99,
#   'TotalFat': 41.56,
#   'Carbohydrate': 28.13},
#  'POULTRY_SEASONING': {'Calories': 307.0,
#   'Protein': 9.59,
#   'TotalFat': 7.53,
#   'Carbohydrate': 65.59},
#  'PUMPKIN_PIE_SPICE': {'Calories': 342.0,
#   'Protein': 5.76,
#   'TotalFat': 12.6,
#   'Carbohydrate': 69.28},
#  'ROSEMARY_DRIED': {'Calories': 331.0,
#   'Protein': 4.88,
#   'TotalFat': 15.22,
#   'Carbohydrate': 64.06},
#  'SAFFRON': {'Calories': 310.0,
#   'Protein': 11.43,
#   'TotalFat': 5.85,
#   'Carbohydrate': 65.37},
#  'SAGE_GROUND': {'Calories': 315.0,
#   'Protein': 10.63,
#   'TotalFat': 12.75,
#   'Carbohydrate': 60.73},
#  'SAVORY_GROUND': {'Calories': 272.0,
#   'Protein': 6.73,
#   'TotalFat': 5.91,
#   'Carbohydrate': 68.73},
#  'SPICES_TARRAGON_DRIED': {'Calories': 295.0,
#   'Protein': 22.77,
#   'TotalFat': 7.24,
#   'Carbohydrate': 50.22},
#  'SPICES_THYME_DRIED': {'Calories': 276.0,
#   'Protein': 9.11,
#   'TotalFat': 7.43,
#   'Carbohydrate': 63.94},
#  'TURMERIC_GROUND': {'Calories': 354.0,
#   'Protein': 7.83,
#   'TotalFat': 9.88,
#   'Carbohydrate': 64.93},
#  'BASIL_FRESH': {'Calories': 23.0,
#   'Protein': 3.15,
#   'TotalFat': 0.64,
#   'Carbohydrate': 2.65},
#  'DILL_WEED_FRSH': {'Calories': 43.0,
#   'Protein': 3.46,
#   'TotalFat': 1.12,
#   'Carbohydrate': 7.02},
#  'MUSTARD_PREPARED_YELLOW': {'Calories': 67.0,
#   'Protein': 4.37,
#   'TotalFat': 4.01,
#   'Carbohydrate': 5.33},
#  'SALT_TABLE': {'Calories': 0.0,
#   'Protein': 0.0,
#   'TotalFat': 0.0,
#   'Carbohydrate': 0.0},
#  'VINEGAR_CIDER': {'Calories': 21.0,
#   'Protein': 0.0,
#   'TotalFat': 0.0,
#   'Carbohydrate': 0.93},
#  'THYME_FRSH': {'Calories': 101.0,
#   'Protein': 5.56,
#   'TotalFat': 1.68,
#   'Carbohydrate': 24.45},
#  'VANILLA_EXTRACT': {'Calories': 288.0,
#   'Protein': 0.06,
#   'TotalFat': 0.06,
#   'Carbohydrate': 12.65},
#  'VANILLA_EXTRACT_IMITN_ALCOHOL': {'Calories': 237.0,
#   'Protein': 0.05,
#   'TotalFat': 0.0,
#   'Carbohydrate': 2.41},
#  'VANILLA_EXTRACT_IMITN_NO_ALCOHOL': {'Calories': 56.0,
#   'Protein': 0.03,
#   'TotalFat': 0.0,
#   'Carbohydrate': 14.4},
#  'VINEGAR_DISTILLED': {'Calories': 18.0,
#   'Protein': 0.0,
#   'TotalFat': 0.0,
#   'Carbohydrate': 0.04},
#  'CAPERS_CANNED': {'Calories': 23.0,
#   'Protein': 2.36,
#   'TotalFat': 0.86,
#   'Carbohydrate': 4.89},
#  'HORSERADISH_PREPARED': {'Calories': 48.0,
#   'Protein': 1.18,
#   'TotalFat': 0.69,
#   'Carbohydrate': 11.29},
#  'ROSEMARY_FRESH': {'Calories': 131.0,
#   'Protein': 3.31,
#   'TotalFat': 5.86,
#   'Carbohydrate': 20.7},
#  'PEPPERMINT_FRESH': {'Calories': 70.0,
#   'Protein': 3.75,
#   'TotalFat': 0.94,
#   'Carbohydrate': 14.89},
#  'SPEARMINT_FRESH': {'Calories': 44.0,
#   'Protein': 3.29,
#   'TotalFat': 0.73,
#   'Carbohydrate': 8.41},
#  'SPEARMINT_DRIED': {'Calories': 285.0,
#   'Protein': 19.93,
#   'TotalFat': 6.03,
#   'Carbohydrate': 52.04},
#  'VINEGAR_RED_WINE': {'Calories': 19.0,
#   'Protein': 0.04,
#   'TotalFat': 0.0,
#   'Carbohydrate': 0.27},
#  'VINEGAR_BALSAMIC': {'Calories': 88.0,
#   'Protein': 0.49,
#   'TotalFat': 0.0,
#   'Carbohydrate': 17.03},
#  'CAMPBELL_SOUP_CO_PACE_DRY_TACO_SEAS_MIX': {'Calories': 188.0,
#   'Protein': 0.0,
#   'TotalFat': 0.0,
#   'Carbohydrate': 56.29},
#  'GERBER_GRADUATES_FRUIT_STRIPS_REAL_FRUIT_BARS': {'Calories': 330.0,
#   'Protein': 0.82,
#   'TotalFat': 2.24,
#   'Carbohydrate': 76.61},
#  'ZWIEBACK': {'Calories': 426.0,
#   'Protein': 10.1,
#   'TotalFat': 9.7,
#   'Carbohydrate': 74.2},
#  'CHILD_FORMULA_MEAD_JOHNSON_PORTAGEN_W_IRON_PDR_NOT_RECON': {'Calories': 483.0,
#   'Protein': 16.5,
#   'TotalFat': 22.0,
#   'Carbohydrate': 54.8},
#  'CHILD_FORMULA_MEAD_JOHNSON_PORTAGEN_W_IRON_PREP_FROM_PDR': {'Calories': 88.0,
#   'Protein': 3.33,
#   'TotalFat': 4.48,
#   'Carbohydrate': 8.57},
#  'In_for_M_JOHN_ENF_ENFAC_LIP_with_ir_po_wi_ARA_and_DH': {'Calories': 514.0,
#   'Protein': 12.5,
#   'TotalFat': 27.0,
#   'Carbohydrate': 56.0},
#  'CHILD_FORMULA_ABBOTT_NUTR_PEDIASURE_RTF_FORMERLY_ROSS_': {'Calories': 99.0,
#   'Protein': 2.86,
#   'TotalFat': 4.77,
#   'Carbohydrate': 11.15},
#  'CHI_FORMU_ABBT_NUTR_PEDIASU_RTF_W_IRON_FIB_FORMER_ROSS_': {'Calories': 99.0,
#   'Protein': 2.8,
#   'TotalFat': 4.7,
#   'Carbohydrate': 11.28},
#  'TODDLER_FORMULA_MEAD_JOHNSON_ENFAGROW_PREMIUM_RTF': {'Calories': 64.0,
#   'Protein': 1.78,
#   'TotalFat': 3.63,
#   'Carbohydrate': 7.18},
#  'FAT_BEEF_TALLOW': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'LARD': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SALAD_DRSNG_KRAFT_MAYO_LT_MAYO': {'Calories': 334.0,
#   'Protein': 0.6,
#   'TotalFat': 32.9,
#   'Carbohydrate': 8.5},
#  'SALAD_DRSNG_KRAFT_MAYO_FAT_FREE_MAYO_DRSNG': {'Calories': 70.0,
#   'Protein': 0.2,
#   'TotalFat': 2.7,
#   'Carbohydrate': 12.4},
#  'SALAD_DRSNG_KRAFT_MIRACLE_WHIP_FREE_NONFAT_DRSNG': {'Calories': 84.0,
#   'Protein': 0.2,
#   'TotalFat': 2.7,
#   'Carbohydrate': 15.5},
#  'SALAD_DRSNG_RUSSIAN_DRSNG': {'Calories': 355.0,
#   'Protein': 0.69,
#   'TotalFat': 26.18,
#   'Carbohydrate': 31.9},
#  'SALAD_DRSNG_SESAME_SD_DRSNG_REG': {'Calories': 443.0,
#   'Protein': 3.1,
#   'TotalFat': 45.2,
#   'Carbohydrate': 8.6},
#  'SALAD_DRSNG_1000_ISLAND_COMM_REG': {'Calories': 370.0,
#   'Protein': 1.09,
#   'TotalFat': 35.06,
#   'Carbohydrate': 14.64},
#  'SALAD_DRSNG_MAYO_TYPE_REG_W_SALT': {'Calories': 390.0,
#   'Protein': 0.9,
#   'TotalFat': 33.4,
#   'Carbohydrate': 23.9},
#  'SALAD_DRSNG_FRENCH_DRSNG_RED_FAT': {'Calories': 222.0,
#   'Protein': 0.58,
#   'TotalFat': 11.52,
#   'Carbohydrate': 31.22},
#  'SALAD_DRSNG_ITALIAN_DRSNG_RED_FAT': {'Calories': 75.0,
#   'Protein': 0.47,
#   'TotalFat': 6.38,
#   'Carbohydrate': 4.57},
#  'SALAD_DRSNG_RUSSIAN_DRSNG_LO_CAL': {'Calories': 141.0,
#   'Protein': 0.5,
#   'TotalFat': 4.0,
#   'Carbohydrate': 27.6},
#  'SALAD_DRSNG_1000_ISLAND_DRSNG_RED_FAT': {'Calories': 195.0,
#   'Protein': 0.83,
#   'TotalFat': 11.32,
#   'Carbohydrate': 24.06},
#  'SALAD_DRSNG_MAYO_SOYBN_OIL_W_SALT': {'Calories': 718.0,
#   'Protein': 0.9,
#   'TotalFat': 79.39,
#   'Carbohydrate': 3.16},
#  'SALAD_DRSNG_MAYO_SOYBN_SAFFLOWER_OIL_W_SALT': {'Calories': 717.0,
#   'Protein': 1.1,
#   'TotalFat': 79.4,
#   'Carbohydrate': 2.7},
#  'SALAD_DRSNG_MAYO_IMITN_SOYBN': {'Calories': 232.0,
#   'Protein': 0.3,
#   'TotalFat': 19.2,
#   'Carbohydrate': 16.0},
#  'SALAD_DRSNG_MAYO_IMITN_MILK_CRM': {'Calories': 97.0,
#   'Protein': 2.1,
#   'TotalFat': 5.1,
#   'Carbohydrate': 11.1},
#  'SALAD_DRSNG_MAYO_IMITN_SOYBN_WO_CHOL': {'Calories': 482.0,
#   'Protein': 0.1,
#   'TotalFat': 47.7,
#   'Carbohydrate': 15.8},
#  'SANDWICH_SPRD_W_CHOPD_PICKLE_REG_UNSPEC_OILS': {'Calories': 389.0,
#   'Protein': 0.9,
#   'TotalFat': 34.0,
#   'Carbohydrate': 22.4},
#  'SHORTENING_HOUSEHOLD_PARTIALLY_HYDROG_SOYBN_COTTONSEED': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SOYBN_SALAD_OR_COOKING_PARTIALLY_HYDROGENATED_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_RICE_BRAN': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_WHEAT_GERM': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_PNUT_SALAD_OR_COOKING': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SOYBN_SALAD_OR_COOKING': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_COCNT': {'Calories': 862.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_OLIVE_SALAD_OR_COOKING': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_PALM': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SESAME_SALAD_OR_COOKING': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SUNFLOWER_LINOLEIC_LESS_THAN_60_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'MARGARINE_REG_HARD_SOYBN_HYDR_': {'Calories': 719.0,
#   'Protein': 0.9,
#   'TotalFat': 80.5,
#   'Carbohydrate': 0.9},
#  'SALAD_DRSNG_ITALIAN_DRSNG_COMM_REG': {'Calories': 291.0,
#   'Protein': 0.38,
#   'TotalFat': 28.37,
#   'Carbohydrate': 10.43},
#  'SALAD_DRSNG_FRENCH_DRSNG_COMM_REG': {'Calories': 457.0,
#   'Protein': 0.77,
#   'TotalFat': 44.81,
#   'Carbohydrate': 15.58},
#  'VEG_OIL_SPRD_UNSPEC_OILS_APPROX_37_FAT_W_SALT': {'Calories': 339.0,
#   'Protein': 0.51,
#   'TotalFat': 37.77,
#   'Carbohydrate': 0.66},
#  'SALAD_DRSNG_FRENCH_HOME_RECIPE': {'Calories': 631.0,
#   'Protein': 0.1,
#   'TotalFat': 70.2,
#   'Carbohydrate': 3.4},
#  'SALAD_DRSNG_HOME_RECIPE_CKD': {'Calories': 157.0,
#   'Protein': 4.2,
#   'TotalFat': 9.5,
#   'Carbohydrate': 14.9},
#  'SALAD_DRSNG_HOME_RECIPE_VINEGAR_OIL': {'Calories': 449.0,
#   'Protein': 0.0,
#   'TotalFat': 50.1,
#   'Carbohydrate': 2.5},
#  'SALAD_DRSNG_FRENCH_DRSNG_COMM_REG_WO_SALT': {'Calories': 459.0,
#   'Protein': 0.77,
#   'TotalFat': 44.81,
#   'Carbohydrate': 15.58},
#  'SALAD_DRSNG_FRENCH_DRSNG_RED_FAT_WO_SALT': {'Calories': 233.0,
#   'Protein': 0.58,
#   'TotalFat': 13.46,
#   'Carbohydrate': 29.28},
#  'SALAD_DRSNG_ITALIAN_DRSNG_COMM_REG_WO_SALT': {'Calories': 292.0,
#   'Protein': 0.38,
#   'TotalFat': 28.37,
#   'Carbohydrate': 10.43},
#  'SALAD_DRSNG_ITALIAN_DRSNG_RED_FAT_WO_SALT': {'Calories': 76.0,
#   'Protein': 0.47,
#   'TotalFat': 6.38,
#   'Carbohydrate': 4.57},
#  'SALAD_DRSNG_MAYO_SOYBN_OIL_WO_SALT': {'Calories': 717.0,
#   'Protein': 1.1,
#   'TotalFat': 79.4,
#   'Carbohydrate': 2.7},
#  'SALAD_DRSNG_FRENCH_CTTNSD_OIL_HOME_RECIPE': {'Calories': 631.0,
#   'Protein': 0.1,
#   'TotalFat': 70.2,
#   'Carbohydrate': 3.4},
#  'SALAD_DRSNG_FRENCH_DRSNG_FAT_FREE': {'Calories': 132.0,
#   'Protein': 0.2,
#   'TotalFat': 0.27,
#   'Carbohydrate': 32.14},
#  'OIL_COCOA_BUTTER': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_CTTNSD_SALAD_OR_COOKING': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SUNFLOWER_LINOLEIC_APPROX_65_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SAFFLOWER_SALAD_OR_COOKING_LINOLEIC_OVER_70_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SAFFLOWER_SALAD_OR_COOKING_HI_OLEIC': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'VEGETABLE_OIL_PALM_KERNEL': {'Calories': 862.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_POPPYSEED': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_TOMATOSEED': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_TEASEED': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_GRAPESEED': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_CORN_INDUSTRIAL_RTL_ALLPURP_SALAD_OR_COOKING': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FAT_MUTTON_TALLOW': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_WALNUT': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_ALMOND': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_APRICOT_KERNEL': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SOYBN_LECITHIN': {'Calories': 763.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_HAZELNUT': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_BABASSU': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SHEANUT': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SALAD_DRSNG_BLUE_OR_ROQUEFORT_CHS_DRSNG_COMM_REG': {'Calories': 476.0,
#   'Protein': 1.37,
#   'TotalFat': 51.1,
#   'Carbohydrate': 4.62},
#  'OIL_CUPU_ASSU': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FAT_CHICKEN': {'Calories': 900.0,
#   'Protein': 0.0,
#   'TotalFat': 99.8,
#   'Carbohydrate': 0.0},
#  'OIL_SOYBN_SALAD_OR_COOKING_PARTIALLY_HYDROGENATED_CTTNSD': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_HOUSEHOLD_LARD_VEG_OIL': {'Calories': 900.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SUNFLOWER_LINOLEIC_PARTIALLY_HYDROGENATED_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_BREAD_SOYBN_HYDR_CTTNSD': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_CAKE_MIX_SOYBN_HYDR_CTTNSD_HYDR_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_INDUSTRIAL_LARD_VEG_OIL': {'Calories': 900.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_FRYING_HVY_DUTY_BF_TALLOW_CTTNSD': {'Calories': 900.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_CONFECTIONERY_COCNT_HYDR_OR_PALM_KERNEL_HYDR_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_INDUSTRIAL_SOYBN_HYDR_CTTNSD': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_FRYING_HVY_DUTY_PALM_HYDR_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_HOUSEHOLD_SOYBN_HYDR_PALM': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_FRYING_HVY_DUTY_SOYBN_HYDR_LINOLEIC_LESS_THAN_1_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_CONFECTIONERY_FRACTIONATED_PALM': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_NUTMEG_BUTTER': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_UCUHUBA_BUTTER': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FAT_DUCK': {'Calories': 882.0,
#   'Protein': 0.0,
#   'TotalFat': 99.8,
#   'Carbohydrate': 0.0},
#  'FAT_TURKEY': {'Calories': 900.0,
#   'Protein': 0.0,
#   'TotalFat': 99.8,
#   'Carbohydrate': 0.0},
#  'FAT_GOOSE': {'Calories': 900.0,
#   'Protein': 0.0,
#   'TotalFat': 99.8,
#   'Carbohydrate': 0.0},
#  'OIL_AVOCADO': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_CANOLA': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_MUSTARD': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SUNFLOWER_HI_OLEIC_70_OVER_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'MARGARINE_LIKE_MARGARINE_BUTTER_BLEND_SOYBN_OIL_BUTTER': {'Calories': 714.0,
#   'Protein': 0.31,
#   'TotalFat': 80.32,
#   'Carbohydrate': 0.77},
#  'SHORTENING_SPL_PURPOSE_FOR_CAKES_FROSTINGS_SOYBN_HYDR_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_SPL_PURPOSE_FOR_BAKING_SOYBN_HYDR_PALM_CTTNSD': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_OAT': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FISH_OIL_COD_LIVER': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FISH_OIL_HERRING': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FISH_OIL_MENHADEN': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FISH_OIL_MENHADEN_FULLY_HYDR': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FISH_OIL_SALMON': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FISH_OIL_SARDINE': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_MULTIPURPOSE_SOYBN_HYDR_PALM_HYDR_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'MARGARINE_LIKE_VEG_OIL_BUTTER_SPRD_TUB_W_SALT': {'Calories': 362.0,
#   'Protein': 1.0,
#   'TotalFat': 40.0,
#   'Carbohydrate': 1.0},
#  'BUTTER_LT_STK_W_SALT': {'Calories': 509.0,
#   'Protein': 3.3,
#   'TotalFat': 55.1,
#   'Carbohydrate': 0.0},
#  'BUTTER_LT_STK_WO_SALT': {'Calories': 499.0,
#   'Protein': 3.3,
#   'TotalFat': 55.1,
#   'Carbohydrate': 0.0},
#  'MEAT_DRIPPINGS_LARD_BF_TALLOW_MUTTON_TALLOW_': {'Calories': 889.0,
#   'Protein': 0.0,
#   'TotalFat': 98.59,
#   'Carbohydrate': 0.0},
#  'ANIMAL_FAT_BACON_GREASE': {'Calories': 897.0,
#   'Protein': 0.0,
#   'TotalFat': 99.5,
#   'Carbohydrate': 0.0},
#  'MARGARINE_REG_80_FAT_COMP_STK_W_SALT': {'Calories': 717.0,
#   'Protein': 0.16,
#   'TotalFat': 80.71,
#   'Carbohydrate': 0.7},
#  'MARGARINE_REG_80_FAT_COMP_TUB_W_SALT': {'Calories': 713.0,
#   'Protein': 0.22,
#   'TotalFat': 80.17,
#   'Carbohydrate': 0.75},
#  'MARGARINE_LIKE_VEG_OIL_SPRD_60_FAT_STK_W_SALT': {'Calories': 537.0,
#   'Protein': 0.12,
#   'TotalFat': 60.39,
#   'Carbohydrate': 0.69},
#  'MARGARINE_LIKE_VEG_OIL_SPRD_60_FAT_TUB_W_SALT': {'Calories': 533.0,
#   'Protein': 0.17,
#   'TotalFat': 59.81,
#   'Carbohydrate': 0.86},
#  'MARGARINE_LIKE_VEG_OIL_SPRD_60_FAT_STICK_TUB_BOTTLE_W_SALT': {'Calories': 526.0,
#   'Protein': 0.6,
#   'TotalFat': 59.17,
#   'Carbohydrate': 0.0},
#  'SHORTENING_VEG_HOUSEHOLD_COMP': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 99.97,
#   'Carbohydrate': 0.0},
#  'MARGARINE_REG_80_FAT_COMP_STK_WO_SALT': {'Calories': 717.0,
#   'Protein': 0.16,
#   'TotalFat': 80.71,
#   'Carbohydrate': 0.7},
#  'MARGARINE_REG_80_FAT_COMP_TUB_WO_SALT': {'Calories': 713.0,
#   'Protein': 0.22,
#   'TotalFat': 80.17,
#   'Carbohydrate': 0.75},
#  'VEG_OIL_SPRD_60_FAT_STICK_TUB_BOTTLE_WO_SALT': {'Calories': 533.0,
#   'Protein': 0.17,
#   'TotalFat': 59.81,
#   'Carbohydrate': 0.86},
#  'MARGARINE_LIKE_VEG_OIL_SPRD_FAT_FREE_LIQ_W_SALT': {'Calories': 43.0,
#   'Protein': 1.5,
#   'TotalFat': 3.0,
#   'Carbohydrate': 2.5},
#  'MARGARINE_LIKE_SPRD_W_YOGURT_70_FAT_STK_W_SALT': {'Calories': 630.0,
#   'Protein': 0.3,
#   'TotalFat': 70.0,
#   'Carbohydrate': 0.5},
#  'MARGARINE_LIKE_SPRD_W_YOGURT_APPROX_40_FAT_TUB_W_SALT': {'Calories': 330.0,
#   'Protein': 2.0,
#   'TotalFat': 35.0,
#   'Carbohydrate': 2.0},
#  'MARGARINE_80_FAT_STK_INCL_REG_HYDR_CORN_SOYBN_OILS': {'Calories': 717.0,
#   'Protein': 0.16,
#   'TotalFat': 80.71,
#   'Carbohydrate': 0.7},
#  'MARGARINE_VEG_OIL_SPRD_70_FAT_SOYBN_PART_HYDR_SOYBN_STK': {'Calories': 628.0,
#   'Protein': 0.26,
#   'TotalFat': 70.22,
#   'Carbohydrate': 1.53},
#  'MARGARINE_SPRD_APPROX_48_FAT_TUB': {'Calories': 424.0,
#   'Protein': 0.2,
#   'TotalFat': 47.53,
#   'Carbohydrate': 0.86},
# ...
#   'Protein': 1.61,
#   'TotalFat': 3.63,
#   'Carbohydrate': 9.68},
#  'SOUP_CHICK_CND_CHUNKY_RTS': {'Calories': 71.0,
#   'Protein': 5.06,
#   'TotalFat': 2.64,
#   'Carbohydrate': 6.88},
#  'SOUP_CRM_OF_CHICK_CND_COND': {'Calories': 90.0,
#   'Protein': 2.38,
#   'TotalFat': 5.77,
#   'Carbohydrate': 7.16},
#  'SOUP_CHICK_GUMBO_CND_COND': {'Calories': 45.0,
#   'Protein': 2.1,
#   'TotalFat': 1.14,
#   'Carbohydrate': 6.67},
#  'SOUP_CHUNKY_CHICK_NOODLE_CND_RTS': {'Calories': 39.0,
#   'Protein': 3.09,
#   'TotalFat': 1.16,
#   'Carbohydrate': 4.0},
#  'SOUP_CHICK_NOODLE_CND_COND': {'Calories': 52.0,
#   'Protein': 2.59,
#   'TotalFat': 1.94,
#   'Carbohydrate': 6.03},
#  'SOUP_CHICK_RICE_CND_CHUNKY_RTS': {'Calories': 53.0,
#   'Protein': 5.11,
#   'TotalFat': 1.33,
#   'Carbohydrate': 5.41},
#  'SOUP_CHICK_W_RICE_CND_COND': {'Calories': 49.0,
#   'Protein': 2.89,
#   'TotalFat': 1.56,
#   'Carbohydrate': 5.84},
#  'SOUP_CHICK_VEG_CHUNKY_CND_RTS': {'Calories': 69.0,
#   'Protein': 5.13,
#   'TotalFat': 2.01,
#   'Carbohydrate': 7.87},
#  'SOUP_CHICK_VEG_CND_COND': {'Calories': 61.0,
#   'Protein': 2.94,
#   'TotalFat': 2.32,
#   'Carbohydrate': 7.01},
#  'SOUP_CHILI_BF_CND_COND': {'Calories': 117.0,
#   'Protein': 5.09,
#   'TotalFat': 2.53,
#   'Carbohydrate': 18.86},
#  'SOUP_CLAM_CHOWDER_MANHATTAN_STYLE_CND_CHUNKY_RTS': {'Calories': 56.0,
#   'Protein': 3.02,
#   'TotalFat': 1.41,
#   'Carbohydrate': 7.84},
#  'SOUP_CLAM_CHOWDER_MANHATTAN_CND_COND': {'Calories': 61.0,
#   'Protein': 1.74,
#   'TotalFat': 1.76,
#   'Carbohydrate': 9.74},
#  'CAMPBELL_SOUP_COMPANY_HEALTHY_REQUEST_CHICK_W_RICE_COND': {'Calories': 56.0,
#   'Protein': 1.59,
#   'TotalFat': 1.19,
#   'Carbohydrate': 7.19},
#  'SOUP_CLAM_CHOWDER_NEW_ENGLAND_CND_COND': {'Calories': 72.0,
#   'Protein': 3.17,
#   'TotalFat': 2.06,
#   'Carbohydrate': 10.32},
#  'SOUP_BF_BROTH_BOUILLON_CONSOMME_CND_COND': {'Calories': 13.0,
#   'Protein': 2.52,
#   'TotalFat': 0.0,
#   'Carbohydrate': 0.84},
#  'SOUP_CRAB_CND_RTS': {'Calories': 31.0,
#   'Protein': 2.25,
#   'TotalFat': 0.62,
#   'Carbohydrate': 4.22},
#  'SOUP_ESCAROLE_CND_RTS': {'Calories': 11.0,
#   'Protein': 0.62,
#   'TotalFat': 0.73,
#   'Carbohydrate': 0.72},
#  'SOUP_GAZPACHO_CND_RTS': {'Calories': 19.0,
#   'Protein': 2.9,
#   'TotalFat': 0.1,
#   'Carbohydrate': 1.8},
#  'SOUP_LENTIL_W_HAM_CND_RTS': {'Calories': 56.0,
#   'Protein': 3.74,
#   'TotalFat': 1.12,
#   'Carbohydrate': 8.16},
#  'CAMPBELL_COMPANY_CAMPBELL_S_RED_WHITE_CHEDDAR_CHS_SOUP_COND': {'Calories': 81.0,
#   'Protein': 1.61,
#   'TotalFat': 4.03,
#   'Carbohydrate': 8.87},
#  'SOUP_MINESTRONE_CND_CHUNKY_RTS': {'Calories': 53.0,
#   'Protein': 2.13,
#   'TotalFat': 1.17,
#   'Carbohydrate': 8.64},
#  'SOUP_MINESTRONE_CND_COND': {'Calories': 68.0,
#   'Protein': 3.48,
#   'TotalFat': 2.05,
#   'Carbohydrate': 9.17},
#  'CAMPBELL_CAMPBELL_S_RED_WHITE_CHICK_DUMPLINGS_SOUP_COND': {'Calories': 56.0,
#   'Protein': 2.38,
#   'TotalFat': 1.98,
#   'Carbohydrate': 7.94},
#  'SOUP_MUSHROOM_BARLEY_CND_COND': {'Calories': 61.0,
#   'Protein': 1.5,
#   'TotalFat': 1.8,
#   'Carbohydrate': 9.6},
#  'SOUP_CRM_OF_MUSHROOM_CND_COND': {'Calories': 85.0,
#   'Protein': 1.61,
#   'TotalFat': 5.89,
#   'Carbohydrate': 6.72},
#  'SOUP_MUSHROOM_W_BF_STOCK_CND_COND': {'Calories': 68.0,
#   'Protein': 2.51,
#   'TotalFat': 3.21,
#   'Carbohydrate': 7.41},
#  'SOUP_ONION_CND_COND': {'Calories': 46.0,
#   'Protein': 3.06,
#   'TotalFat': 1.42,
#   'Carbohydrate': 6.68},
#  'SOUP_CRM_OF_ONION_CND_COND': {'Calories': 88.0,
#   'Protein': 2.2,
#   'TotalFat': 4.2,
#   'Carbohydrate': 10.4},
#  'CAMPBELL_S_RED_WHITE_CHICK_STARS_SOUP_COND': {'Calories': 56.0,
#   'Protein': 2.38,
#   'TotalFat': 1.59,
#   'Carbohydrate': 8.73},
#  'SOUP_OYSTER_STEW_CND_COND': {'Calories': 48.0,
#   'Protein': 1.72,
#   'TotalFat': 3.13,
#   'Carbohydrate': 3.32},
#  'SOUP_PEA_GRN_CND_COND': {'Calories': 125.0,
#   'Protein': 6.54,
#   'TotalFat': 2.23,
#   'Carbohydrate': 20.18},
#  'SOUP_PEA_SPLIT_W_HAM_CND_CHUNKY_RTS': {'Calories': 77.0,
#   'Protein': 4.62,
#   'TotalFat': 1.66,
#   'Carbohydrate': 11.17},
#  'SOUP_PEA_SPLIT_W_HAM_CND_COND': {'Calories': 141.0,
#   'Protein': 7.68,
#   'TotalFat': 3.28,
#   'Carbohydrate': 20.81},
#  'SOUP_PEPPERPOT_CND_COND': {'Calories': 84.0,
#   'Protein': 5.19,
#   'TotalFat': 3.78,
#   'Carbohydrate': 7.66},
#  'SOUP_CRM_OF_POTATO_CND_COND': {'Calories': 59.0,
#   'Protein': 1.39,
#   'TotalFat': 1.88,
#   'Carbohydrate': 9.14},
#  'CAMPBELL_S_RED_WHITE_CHICK_ALPHABET_SOUP_COND': {'Calories': 56.0,
#   'Protein': 2.38,
#   'TotalFat': 1.19,
#   'Carbohydrate': 9.52},
#  'SOUP_SCOTCH_BROTH_CND_COND': {'Calories': 66.0,
#   'Protein': 4.05,
#   'TotalFat': 2.14,
#   'Carbohydrate': 7.73},
#  'SOUP_CRM_OF_SHRIMP_CND_COND': {'Calories': 72.0,
#   'Protein': 2.22,
#   'TotalFat': 4.14,
#   'Carbohydrate': 6.53},
#  'CAMPBELL_SOUP_COMPANY_CAMPBELL_S_RED_WHITE_CHICK_BROTH_COND': {'Calories': 16.0,
#   'Protein': 0.81,
#   'TotalFat': 0.81,
#   'Carbohydrate': 0.81},
#  'CAMPBELL_SOUP_CAMPBELL_S_RED_WHITE_CHICK_GUMBO_SOUP_COND': {'Calories': 48.0,
#   'Protein': 1.59,
#   'TotalFat': 0.79,
#   'Carbohydrate': 7.94},
#  'SOUP_STOCKPOT_CND_COND': {'Calories': 78.0,
#   'Protein': 3.79,
#   'TotalFat': 3.04,
#   'Carbohydrate': 8.95},
#  'SOUP_TOMATO_BF_W_NOODLE_CND_COND': {'Calories': 112.0,
#   'Protein': 3.55,
#   'TotalFat': 3.42,
#   'Carbohydrate': 16.87},
#  'CAMPBELL_S_RED_WHITE_CHICK_NOODLE_SOUP_COND': {'Calories': 48.0,
#   'Protein': 2.38,
#   'TotalFat': 1.59,
#   'Carbohydrate': 6.35},
#  'SOUP_TOMATO_RICE_CND_COND': {'Calories': 93.0,
#   'Protein': 1.64,
#   'TotalFat': 2.12,
#   'Carbohydrate': 17.08},
#  'SOUP_TURKEY_CHUNKY_CND_RTS': {'Calories': 57.0,
#   'Protein': 4.33,
#   'TotalFat': 1.87,
#   'Carbohydrate': 5.96},
#  'SOUP_TURKEY_NOODLE_CND_COND': {'Calories': 55.0,
#   'Protein': 3.11,
#   'TotalFat': 1.59,
#   'Carbohydrate': 6.88},
#  'SOUP_TURKEY_VEG_CND_COND': {'Calories': 60.0,
#   'Protein': 2.52,
#   'TotalFat': 2.47,
#   'Carbohydrate': 7.05},
#  'SOUP_CHUNKY_VEG_CND_RTS': {'Calories': 51.0,
#   'Protein': 1.46,
#   'TotalFat': 1.54,
#   'Carbohydrate': 7.92},
#  'SOUP_VEGETARIAN_VEG_CND_COND': {'Calories': 59.0,
#   'Protein': 1.72,
#   'TotalFat': 1.58,
#   'Carbohydrate': 9.78},
#  'SOUP_CHUNKY_BF_CND_RTS': {'Calories': 66.0,
#   'Protein': 3.97,
#   'TotalFat': 1.11,
#   'Carbohydrate': 10.08},
#  'SOUP_VEG_BF_CND_COND': {'Calories': 63.0,
#   'Protein': 4.45,
#   'TotalFat': 1.51,
#   'Carbohydrate': 8.11},
#  'SOUP_VEG_W_BF_BROTH_CND_COND': {'Calories': 66.0,
#   'Protein': 2.42,
#   'TotalFat': 1.56,
#   'Carbohydrate': 10.7},
#  'SOUP_BF_BROTH_OR_BOUILLON_PDR_DRY': {'Calories': 213.0,
#   'Protein': 15.97,
#   'TotalFat': 8.89,
#   'Carbohydrate': 17.4},
#  'SOUP_BEEF_BROTH_CUBED_DRY': {'Calories': 170.0,
#   'Protein': 17.3,
#   'TotalFat': 4.0,
#   'Carbohydrate': 16.1},
#  'SOUP_BF_NOODLE_DRY_MIX': {'Calories': 324.0,
#   'Protein': 17.93,
#   'TotalFat': 6.39,
#   'Carbohydrate': 48.64},
#  'SOUP_CHICK_BROTH_OR_BOUILLON_DRY': {'Calories': 267.0,
#   'Protein': 16.66,
#   'TotalFat': 13.88,
#   'Carbohydrate': 18.01},
#  'SOUP_CHICK_BROTH_CUBES_DRY': {'Calories': 198.0,
#   'Protein': 14.6,
#   'TotalFat': 4.7,
#   'Carbohydrate': 23.5},
#  'CAMPBELL_S_RED_WHITE_CHICK_NOODLEO_S_SOUP_COND': {'Calories': 71.0,
#   'Protein': 2.38,
#   'TotalFat': 1.98,
#   'Carbohydrate': 11.9},
#  'CAMPBELL_COMPANY_CAMPBELL_S_RED_WHITE_CHICK_VEG_SOUP_COND': {'Calories': 63.0,
#   'Protein': 2.38,
#   'TotalFat': 0.79,
#   'Carbohydrate': 11.9},
#  'CAMPBELL_SOUP_COMPANY_CAMPBELL_S_RED_WHITE_BF_BROTH_COND': {'Calories': 12.0,
#   'Protein': 2.42,
#   'TotalFat': 0.0,
#   'Carbohydrate': 0.81},
#  'SOUP_ONION_DRY_MIX': {'Calories': 293.0,
#   'Protein': 7.48,
#   'TotalFat': 0.34,
#   'Carbohydrate': 65.07},
#  'CAMPBELL_SOUP_COMPANY_CAMPBELLS_RED_WHITE_BF_CONSOMME_COND': {'Calories': 16.0,
#   'Protein': 3.23,
#   'TotalFat': 0.0,
#   'Carbohydrate': 0.81},
#  'SOUP_TOMATO_VEG_DRY_MIX': {'Calories': 325.0,
#   'Protein': 11.73,
#   'TotalFat': 5.09,
#   'Carbohydrate': 59.9},
#  'SOUP_CRM_OF_VEG_DRY_PDR': {'Calories': 446.0,
#   'Protein': 8.0,
#   'TotalFat': 24.1,
#   'Carbohydrate': 52.1},
#  'SAUCE_CHS_DRY_PDR': {'Calories': 448.0,
#   'Protein': 22.69,
#   'TotalFat': 25.44,
#   'Carbohydrate': 33.66},
#  'CAMPBELL_S_RED_WHITE_BATMAN_FUN_SHAPES_SOUP_COND': {'Calories': 56.0,
#   'Protein': 2.38,
#   'TotalFat': 1.59,
#   'Carbohydrate': 7.94},
#  'SAUCE_TERIYAKI_RTS': {'Calories': 89.0,
#   'Protein': 5.93,
#   'TotalFat': 0.02,
#   'Carbohydrate': 15.56},
#  'GRAVY_AU_JUS_CANNED': {'Calories': 16.0,
#   'Protein': 1.2,
#   'TotalFat': 0.2,
#   'Carbohydrate': 2.5},
#  'GRAVY_AU_JUS_DRY': {'Calories': 313.0,
#   'Protein': 9.2,
#   'TotalFat': 9.63,
#   'Carbohydrate': 47.49},
#  'GRAVY_BF_CND_RTS': {'Calories': 53.0,
#   'Protein': 3.75,
#   'TotalFat': 2.36,
#   'Carbohydrate': 4.81},
#  'CAMPBELL_SOUP_CAMPBELL_S_RED_WHITE_BEAN_W_BACON_SOUP_COND': {'Calories': 125.0,
#   'Protein': 6.25,
#   'TotalFat': 2.34,
#   'Carbohydrate': 19.53},
#  'GRAVY_BROWN_DRY': {'Calories': 367.0,
#   'Protein': 10.74,
#   'TotalFat': 9.61,
#   'Carbohydrate': 59.38},
#  'GRAVY_CHICK_CND_RTS': {'Calories': 79.0,
#   'Protein': 1.93,
#   'TotalFat': 5.71,
#   'Carbohydrate': 5.42},
#  'GRAVY_CHICKEN_DRY': {'Calories': 381.0,
#   'Protein': 11.27,
#   'TotalFat': 9.73,
#   'Carbohydrate': 62.09},
#  'GRAVY_MUSHROOM_CANNED': {'Calories': 50.0,
#   'Protein': 1.26,
#   'TotalFat': 2.71,
#   'Carbohydrate': 5.47},
#  'GRAVY_MUSHROOM_DRY_PDR': {'Calories': 328.0,
#   'Protein': 10.0,
#   'TotalFat': 4.0,
#   'Carbohydrate': 64.66},
#  'GRAVY_ONION_DRY_MIX': {'Calories': 322.0,
#   'Protein': 9.0,
#   'TotalFat': 3.0,
#   'Carbohydrate': 67.64},
#  'GRAVY_PORK_DRY_PDR': {'Calories': 367.0,
#   'Protein': 8.78,
#   'TotalFat': 8.63,
#   'Carbohydrate': 63.57},
#  'GRAVY_TURKEY_CND_RTS': {'Calories': 51.0,
#   'Protein': 2.6,
#   'TotalFat': 2.1,
#   'Carbohydrate': 5.1},
#  'GRAVY_TURKEY_DRY': {'Calories': 367.0,
#   'Protein': 10.42,
#   'TotalFat': 7.19,
#   'Carbohydrate': 65.12},
#  'GRAVY_UNSPEC_TYPE_DRY': {'Calories': 344.0,
#   'Protein': 13.0,
#   'TotalFat': 8.0,
#   'Carbohydrate': 58.0},
#  'SOUP_CHICK_NOODLE_DRY_MIX': {'Calories': 377.0,
#   'Protein': 15.42,
#   'TotalFat': 6.51,
#   'Carbohydrate': 62.32},
#  'SAUCE_MOLE_POBLANO_DRY_MIX_SINGLE_BRAND': {'Calories': 571.0,
#   'Protein': 7.48,
#   'TotalFat': 41.58,
#   'Carbohydrate': 41.7},
#  'SAUCE_SOFRITO_PREP_FROM_RECIPE': {'Calories': 237.0,
#   'Protein': 12.8,
#   'TotalFat': 18.2,
#   'Carbohydrate': 5.46},
#  'USDA_COMMODITY_SPAGHETTI_SAU_MEATLESS_CND': {'Calories': 48.0,
#   'Protein': 1.2,
#   'TotalFat': 0.9,
#   'Carbohydrate': 8.7},
#  'CAMPBELL_COMPANY_CAMPBELL_S_RED_WHITE_BF_NOODLE_SOUP_COND': {'Calories': 56.0,
#   'Protein': 3.17,
#   'TotalFat': 1.59,
#   'Carbohydrate': 6.35},
#  'CAMPBELL_CAMPBELL_S_RED_WHITE_BF_W_VEG_BARLEY_SOUP_COND': {'Calories': 71.0,
#   'Protein': 3.97,
#   'TotalFat': 1.19,
#   'Carbohydrate': 11.9},
#  'SOUP_BF_MUSHROOM_CND_COND': {'Calories': 61.0,
#   'Protein': 4.6,
#   'TotalFat': 2.4,
#   'Carbohydrate': 5.2},
#  'SOUP_CHICK_MUSHROOM_CND_COND': {'Calories': 109.0,
#   'Protein': 3.5,
#   'TotalFat': 7.3,
#   'Carbohydrate': 7.6},
#  'SAUCE_BARBECUE': {'Calories': 150.0,
#   'Protein': 0.0,
#   'TotalFat': 0.29,
#   'Carbohydrate': 36.25},
#  'SAUCE_PLUM_READY_TO_SERVE': {'Calories': 184.0,
#   'Protein': 0.89,
#   'TotalFat': 1.04,
#   'Carbohydrate': 42.81},
#  'SAUCE_PIZZA_CND_RTS': {'Calories': 54.0,
#   'Protein': 2.18,
#   'TotalFat': 1.15,
#   'Carbohydrate': 8.67},
#  'SOUP_TOMATO_BISQUE_CND_COND': {'Calories': 96.0,
#   'Protein': 1.76,
#   'TotalFat': 1.95,
#   'Carbohydrate': 18.47},
#  'SOUP_TOMATO_CND_COND': {'Calories': 66.0,
#   'Protein': 1.46,
#   'TotalFat': 0.44,
#   'Carbohydrate': 15.22},
#  'SAUCE_SALSA_RTS': {'Calories': 27.0,
#   'Protein': 1.54,
#   'TotalFat': 0.16,
#   'Carbohydrate': 6.26},
#  'SAUCE_HOMEMADE_WHITE_THIN': {'Calories': 105.0,
#   'Protein': 3.77,
#   'TotalFat': 6.73,
#   'Carbohydrate': 7.4},
#  'SAUCE_HOMEMADE_WHITE_MED': {'Calories': 147.0,
#   'Protein': 3.84,
#   'TotalFat': 10.63,
#   'Carbohydrate': 9.17},
#  'SAUCE_HOMEMADE_WHITE_THICK': {'Calories': 186.0,
#   'Protein': 3.99,
#   'TotalFat': 13.83,
#   'Carbohydrate': 11.61},
#  'SAUCE_RTS_PEPPER_OR_HOT': {'Calories': 11.0,
#   'Protein': 0.51,
#   'TotalFat': 0.37,
#   'Carbohydrate': 1.75},
#  'SAUCE_RTS_PEPPER_TABASCO': {'Calories': 12.0,
#   'Protein': 1.29,
#   'TotalFat': 0.76,
#   'Carbohydrate': 0.8},
#  'SOUP_STOCK_BEEF_HOME_PREPARED': {'Calories': 13.0,
#   'Protein': 1.97,
#   'TotalFat': 0.09,
#   'Carbohydrate': 1.2},
#  'SOUP_STOCK_CHICK_HOME_PREPARED': {'Calories': 36.0,
#   'Protein': 2.52,
#   'TotalFat': 1.2,
#   'Carbohydrate': 3.53},
#  'SOUP_STOCK_FISH_HOME_PREPARED': {'Calories': 17.0,
#   'Protein': 2.26,
#   'TotalFat': 0.81,
#   'Carbohydrate': 0.0},
#  'SAUCE_HOISIN_RTS': {'Calories': 220.0,
#   'Protein': 3.31,
#   'TotalFat': 3.39,
#   'Carbohydrate': 44.08},
#  'SAUCE_OYSTER_RTS': {'Calories': 51.0,
#   'Protein': 1.35,
#   'TotalFat': 0.25,
#   'Carbohydrate': 10.92},
#  'SOUP_MINESTRONE_CND_RED_NA_RTS': {'Calories': 50.0,
#   'Protein': 2.0,
#   'TotalFat': 0.8,
#   'Carbohydrate': 9.0},
#  'USDA_COMMODITY_SALSA': {'Calories': 36.0,
#   'Protein': 1.5,
#   'TotalFat': 0.2,
#   'Carbohydrate': 7.0},
#  'SAUCE_FISH_READY_TO_SERVE': {'Calories': 35.0,
#   'Protein': 5.06,
#   'TotalFat': 0.01,
#   'Carbohydrate': 3.64},
#  'SOUP_SHARK_FIN_REST_PREP': {'Calories': 46.0,
#   'Protein': 3.2,
#   'TotalFat': 2.0,
#   'Carbohydrate': 3.8},
#  'SOUP_CRM_OF_MUSHROOM_CND_COND_RED_NA': {'Calories': 52.0,
#   'Protein': 1.21,
#   'TotalFat': 1.69,
#   'Carbohydrate': 8.1},
#  'SOUP_CHICK_OR_BEEF_BROTH_CND_LESS_REDUCED_NA': {'Calories': 7.0,
#   'Protein': 1.36,
#   'TotalFat': 0.0,
#   'Carbohydrate': 0.38},
#  'SAUCE_TERIYAKI_RTS_RED_NA': {'Calories': 89.0,
#   'Protein': 5.93,
#   'TotalFat': 0.02,
#   'Carbohydrate': 15.58},
#  'SOUP_BEAN_HAM_CND_RED_NA_PREP_W_H2O_OR_RTS': {'Calories': 74.0,
#   'Protein': 4.19,
#   'TotalFat': 1.03,
#   'Carbohydrate': 13.66},
#  'SPLIT_PEA_SOUP_CND_RED_NA_PREP_W_H2O_OR_READY_TO_SERVE': {'Calories': 71.0,
#   'Protein': 3.85,
#   'TotalFat': 0.92,
#   'Carbohydrate': 11.83},
#  'SPLIT_PEA_W_HAM_SOUP_CND_RED_NA_PREP_W_H2O_OR_RTS': {'Calories': 68.0,
#   'Protein': 4.0,
#   'TotalFat': 0.7,
#   'Carbohydrate': 11.4},
#  'SOUP_CHICK_BROTH_CND_RTS': {'Calories': 5.0,
#   'Protein': 0.43,
#   'TotalFat': 0.21,
#   'Carbohydrate': 0.43},
#  'CAMPBELL_SOUP_COMPANY_HEALTHY_REQUEST_CRM_OF_CHICK_SOUP_COND': {'Calories': 65.0,
#   'Protein': 1.61,
#   'TotalFat': 2.02,
#   'Carbohydrate': 9.68},
#  'SOUP_CRM_OF_ASPARAGUS_CND_PREP_W_EQ_VOLUME_MILK': {'Calories': 65.0,
#   'Protein': 2.55,
#   'TotalFat': 3.3,
#   'Carbohydrate': 6.61},
#  'SOUP_CHICK_VEG_W_POTATO_CHS_CHUNKY_RTS': {'Calories': 65.0,
#   'Protein': 1.16,
#   'TotalFat': 4.46,
#   'Carbohydrate': 5.2},
#  'CAMPBELL_S_RED_WHITE_98_FAT_FREE_CRM_OF_BROCCOLI_SOUP_COND': {'Calories': 56.0,
#   'Protein': 1.61,
#   'TotalFat': 1.61,
#   'Carbohydrate': 8.06},
#  'SOUP_CRM_OF_CELERY_CND_PREP_W_EQ_VOLUME_MILK': {'Calories': 66.0,
#   'Protein': 2.29,
#   'TotalFat': 3.91,
#   'Carbohydrate': 5.86},
#  'SOUP_CHS_CND_PREP_W_EQ_VOLUME_MILK': {'Calories': 92.0,
#   'Protein': 3.77,
#   'TotalFat': 5.8,
#   'Carbohydrate': 6.47},
#  'CAMPBELL_SOUP_COMPANY_RED_WHITE_25_LESS_NA_CHIC_NOODL_COND': {'Calories': 48.0,
#   'Protein': 2.38,
#   'TotalFat': 1.59,
#   'Carbohydrate': 6.35},
#  'CAMPBELL_SOUP_COMPANY_RED_WHITE_25_LESS_NA_TOMATO_SOUP_COND': {'Calories': 73.0,
#   'Protein': 1.61,
#   'TotalFat': 0.0,
#   'Carbohydrate': 16.13},
#  'CAMPBELL_SOUP_COMPANY_RED_WHITE_25_LESS_NA_CRM_OF_MSHR_COND': {'Calories': 89.0,
#   'Protein': 1.61,
#   'TotalFat': 6.45,
#   'Carbohydrate': 6.45},
#  'CAMPBELL_SOUP_COMPANY_RED_WHITE_98_FAT_FR_BRCCLI_CHS_COND': {'Calories': 56.0,
#   'Protein': 1.61,
#   'TotalFat': 1.21,
#   'Carbohydrate': 9.68},
#  'SOUP_CRM_OF_CHICK_CND_PREP_W_EQ_VOLUME_MILK': {'Calories': 77.0,
#   'Protein': 3.01,
#   'TotalFat': 4.62,
#   'Carbohydrate': 6.04},
#  'SOUP_VEG_CND_LO_NA_COND': {'Calories': 65.0,
#   'Protein': 2.2,
#   'TotalFat': 0.9,
#   'Carbohydrate': 12.11},
#  'CAMPBELL_S_RED_WHITE_98_FAT_FREE_CRM_OF_CELERY_SOUP_COND': {'Calories': 56.0,
#   'Protein': 0.81,
#   'TotalFat': 2.42,
#   'Carbohydrate': 7.26},
#  'CAMPBELL_S_RED_WHITE_98_FAT_FREE_CRM_OF_CHICK_SOUP_COND': {'Calories': 56.0,
#   'Protein': 1.61,
#   'TotalFat': 2.02,
#   'Carbohydrate': 8.06},
#  'CAMPBELL_PREGO_PASTA_CHNKY_GRD_MSHRM_GRN_PPPR_ITAL_SAU_RTS': {'Calories': 69.0,
#   'Protein': 1.54,
#   'TotalFat': 2.31,
#   'Carbohydrate': 10.0},
#  'CAMPBELL_PREGO_PASTA_CHUNKY_GARDEN_MUSHROOM_ITALIAN_SAU_RTS': {'Calories': 69.0,
#   'Protein': 1.54,
#   'TotalFat': 2.31,
#   'Carbohydrate': 10.0},
#  ...}

# %% [markdown]
# # Calculation of the optimal weight and the recommended ranges

# %%
# Get user input
height = float(input("Enter height in meters: "))
weight = float(input("Enter current weight in kg: "))
age = int(input("Enter age in years: "))
gender = input("Enter gender (male/female): ")

# Calculate ideal weight and nutrient ranges
ideal_weight = calculate_ideal_weight(height, gender)
nutrient_ranges = calculate_nutrient_ranges(weight)

# Print the results
print("Ideal Weight: {:.2f} kg".format(ideal_weight))
print('----------------------------------------------------------')
print("Recommended Nutrient Ranges per day:")
for nutrient, (nutrient_range, unit) in nutrient_ranges.items():
    print("{}: {:.2f} - {:.2f} {}".format(nutrient, nutrient_range[0], nutrient_range[1], unit))
    
final_ranges = {}
for x,y in nutrient_ranges.items():
    final_ranges[x]=y[0]
    
nutrient_ranges = final_ranges
# Out:
# Enter height in meters: 1.7
# Enter current weight in kg: 89
# Enter age in years: 33
# Enter gender (male/female): male
# Ideal Weight: 65.94 kg
# ----------------------------------------------------------
# Recommended Nutrient Ranges per day:
# Calories: 2225.00 - 2670.00 kilocalories
# Protein: 71.20 - 106.80 grams
# TotalFat: 44.50 - 62.30 grams
# Carbohydrate: 267.00 - 356.00 grams

# %% [markdown]
# # Let's plan for it

# %%
# the amount calclated for a day
nutrient_ranges
# Out:
# {'Calories': (2225.0, 2670.0),
#  'Protein': (71.2, 106.8),
#  'TotalFat': (44.5, 62.3),
#  'Carbohydrate': (267.0, 356.0)}

# %%
# dict of food values
food_nutrient
# Out:
# {'BUTTER_WITH_SALT': {'Calories': 717.0,
#   'Protein': 0.85,
#   'TotalFat': 81.11,
#   'Carbohydrate': 0.06},
#  'BUTTER_WHIPPED_WITH_SALT': {'Calories': 717.0,
#   'Protein': 0.85,
#   'TotalFat': 81.11,
#   'Carbohydrate': 0.06},
#  'BUTTER_OIL_ANHYDROUS': {'Calories': 876.0,
#   'Protein': 0.28,
#   'TotalFat': 99.48,
#   'Carbohydrate': 0.0},
#  'CHEESE_BLUE': {'Calories': 353.0,
#   'Protein': 21.4,
#   'TotalFat': 28.74,
#   'Carbohydrate': 2.34},
#  'CHEESE_BRICK': {'Calories': 371.0,
#   'Protein': 23.24,
#   'TotalFat': 29.68,
#   'Carbohydrate': 2.79},
#  'CHEESE_BRIE': {'Calories': 334.0,
#   'Protein': 20.75,
#   'TotalFat': 27.68,
#   'Carbohydrate': 0.45},
#  'CHEESE_CAMEMBERT': {'Calories': 300.0,
#   'Protein': 19.8,
#   'TotalFat': 24.26,
#   'Carbohydrate': 0.46},
#  'CHEESE_CARAWAY': {'Calories': 376.0,
#   'Protein': 25.18,
#   'TotalFat': 29.2,
#   'Carbohydrate': 3.06},
#  'CHEESE_CHEDDAR': {'Calories': 403.0,
#   'Protein': 24.9,
#   'TotalFat': 33.14,
#   'Carbohydrate': 1.28},
#  'CHEESE_CHESHIRE': {'Calories': 387.0,
#   'Protein': 23.37,
#   'TotalFat': 30.6,
#   'Carbohydrate': 4.78},
#  'CHEESE_COLBY': {'Calories': 394.0,
#   'Protein': 23.76,
#   'TotalFat': 32.11,
#   'Carbohydrate': 2.57},
#  'CHEESE_COTTAGE_CRMD_LRG_OR_SML_CURD': {'Calories': 98.0,
#   'Protein': 11.12,
#   'TotalFat': 4.3,
#   'Carbohydrate': 3.38},
#  'CHEESE_COTTAGE_CRMD_W_FRUIT': {'Calories': 97.0,
#   'Protein': 10.69,
#   'TotalFat': 3.85,
#   'Carbohydrate': 4.61},
#  'CHEESE_COTTAGE_NONFAT_UNCRMD_DRY_LRG_OR_SML_CURD': {'Calories': 72.0,
#   'Protein': 10.34,
#   'TotalFat': 0.29,
#   'Carbohydrate': 6.66},
#  'CHEESE_COTTAGE_LOWFAT_2_MILKFAT': {'Calories': 86.0,
#   'Protein': 11.83,
#   'TotalFat': 2.45,
#   'Carbohydrate': 3.66},
#  'CHEESE_COTTAGE_LOWFAT_1_MILKFAT': {'Calories': 72.0,
#   'Protein': 12.39,
#   'TotalFat': 1.02,
#   'Carbohydrate': 2.72},
#  'CHEESE_CREAM': {'Calories': 342.0,
#   'Protein': 5.93,
#   'TotalFat': 34.24,
#   'Carbohydrate': 4.07},
#  'CHEESE_EDAM': {'Calories': 357.0,
#   'Protein': 24.99,
#   'TotalFat': 27.8,
#   'Carbohydrate': 1.43},
#  'CHEESE_FETA': {'Calories': 264.0,
#   'Protein': 14.21,
#   'TotalFat': 21.28,
#   'Carbohydrate': 4.09},
#  'CHEESE_FONTINA': {'Calories': 389.0,
#   'Protein': 25.6,
#   'TotalFat': 31.14,
#   'Carbohydrate': 1.55},
#  'CHEESE_GJETOST': {'Calories': 466.0,
#   'Protein': 9.65,
#   'TotalFat': 29.51,
#   'Carbohydrate': 42.65},
#  'CHEESE_GOUDA': {'Calories': 356.0,
#   'Protein': 24.94,
#   'TotalFat': 27.44,
#   'Carbohydrate': 2.22},
#  'CHEESE_GRUYERE': {'Calories': 413.0,
#   'Protein': 29.81,
#   'TotalFat': 32.34,
#   'Carbohydrate': 0.36},
#  'CHEESE_LIMBURGER': {'Calories': 327.0,
#   'Protein': 20.05,
#   'TotalFat': 27.25,
#   'Carbohydrate': 0.49},
#  'CHEESE_MONTEREY': {'Calories': 373.0,
#   'Protein': 24.48,
#   'TotalFat': 30.28,
#   'Carbohydrate': 0.68},
#  'CHEESE_MOZZARELLA_WHL_MILK': {'Calories': 300.0,
#   'Protein': 22.17,
#   'TotalFat': 22.35,
#   'Carbohydrate': 2.19},
#  'CHEESE_MOZZARELLA_WHL_MILK_LO_MOIST': {'Calories': 318.0,
#   'Protein': 21.6,
#   'TotalFat': 24.64,
#   'Carbohydrate': 2.47},
#  'CHEESE_MOZZARELLA_PART_SKIM_MILK': {'Calories': 254.0,
#   'Protein': 24.26,
#   'TotalFat': 15.92,
#   'Carbohydrate': 2.77},
#  'CHEESE_MOZZARELLA_PART_SKIM_MILK_LO_MOIST': {'Calories': 302.0,
#   'Protein': 25.96,
#   'TotalFat': 20.03,
#   'Carbohydrate': 3.83},
#  'CHEESE_MUENSTER': {'Calories': 368.0,
#   'Protein': 23.41,
#   'TotalFat': 30.04,
#   'Carbohydrate': 1.12},
#  'CHEESE_NEUFCHATEL': {'Calories': 253.0,
#   'Protein': 9.15,
#   'TotalFat': 22.78,
#   'Carbohydrate': 3.59},
#  'CHEESE_PARMESAN_GRATED': {'Calories': 431.0,
#   'Protein': 38.46,
#   'TotalFat': 28.61,
#   'Carbohydrate': 4.06},
#  'CHEESE_PARMESAN_HARD': {'Calories': 392.0,
#   'Protein': 35.75,
#   'TotalFat': 25.83,
#   'Carbohydrate': 3.22},
#  'CHEESE_PORT_DE_SALUT': {'Calories': 352.0,
#   'Protein': 23.78,
#   'TotalFat': 28.2,
#   'Carbohydrate': 0.57},
#  'CHEESE_PROVOLONE': {'Calories': 351.0,
#   'Protein': 25.58,
#   'TotalFat': 26.62,
#   'Carbohydrate': 2.14},
#  'CHEESE_RICOTTA_WHOLE_MILK': {'Calories': 174.0,
#   'Protein': 11.26,
#   'TotalFat': 12.98,
#   'Carbohydrate': 3.04},
#  'CHEESE_RICOTTA_PART_SKIM_MILK': {'Calories': 138.0,
#   'Protein': 11.39,
#   'TotalFat': 7.91,
#   'Carbohydrate': 5.14},
#  'CHEESE_ROMANO': {'Calories': 387.0,
#   'Protein': 31.8,
#   'TotalFat': 26.94,
#   'Carbohydrate': 3.63},
#  'CHEESE_ROQUEFORT': {'Calories': 369.0,
#   'Protein': 21.54,
#   'TotalFat': 30.64,
#   'Carbohydrate': 2.0},
#  'CHEESE_SWISS': {'Calories': 380.0,
#   'Protein': 26.93,
#   'TotalFat': 27.8,
#   'Carbohydrate': 5.38},
#  'CHEESE_TILSIT': {'Calories': 340.0,
#   'Protein': 24.41,
#   'TotalFat': 25.98,
#   'Carbohydrate': 1.88},
#  'CHEESE_PAST_PROCESS_AMERICAN_FORT_W_VITAMIN_D': {'Calories': 371.0,
#   'Protein': 18.13,
#   'TotalFat': 31.79,
#   'Carbohydrate': 3.7},
#  'CHEESE_PAST_PROCESS_PIMENTO': {'Calories': 375.0,
#   'Protein': 22.13,
#   'TotalFat': 31.2,
#   'Carbohydrate': 1.73},
#  'CHEESE_PAST_PROCESS_SWISS': {'Calories': 334.0,
#   'Protein': 24.73,
#   'TotalFat': 25.01,
#   'Carbohydrate': 2.1},
#  'CHEESE_FD_COLD_PK_AMERICAN': {'Calories': 331.0,
#   'Protein': 19.66,
#   'TotalFat': 24.46,
#   'Carbohydrate': 8.32},
#  'CHEESE_FD_PAST_PROCESS_AMERICAN_VITAMIN_D_FORT': {'Calories': 330.0,
#   'Protein': 16.86,
#   'TotalFat': 25.63,
#   'Carbohydrate': 8.56},
#  'CHEESE_FD_PAST_PROCESS_SWISS': {'Calories': 323.0,
#   'Protein': 21.92,
#   'TotalFat': 24.14,
#   'Carbohydrate': 4.5},
#  'CHEESE_SPRD_PAST_PROCESS_AMERICAN': {'Calories': 290.0,
#   'Protein': 16.41,
#   'TotalFat': 21.23,
#   'Carbohydrate': 8.73},
#  'CREAM_FLUID_HALF_AND_HALF': {'Calories': 130.0,
#   'Protein': 2.96,
#   'TotalFat': 11.5,
#   'Carbohydrate': 4.3},
#  'CREAM_FLUID_LT_COFFEE_CRM_OR_TABLE_CRM_': {'Calories': 195.0,
#   'Protein': 2.7,
#   'TotalFat': 19.31,
#   'Carbohydrate': 3.66},
#  'CREAM_FLUID_LT_WHIPPING': {'Calories': 292.0,
#   'Protein': 2.17,
#   'TotalFat': 30.91,
#   'Carbohydrate': 2.96},
#  'CREAM_FLUID_HVY_WHIPPING': {'Calories': 345.0,
#   'Protein': 2.05,
#   'TotalFat': 37.0,
#   'Carbohydrate': 2.79},
#  'CREAM_WHIPPED_CRM_TOPPING_PRESSURIZED': {'Calories': 257.0,
#   'Protein': 3.2,
#   'TotalFat': 22.22,
#   'Carbohydrate': 12.49},
#  'CREAM_SOUR_RED_FAT_CULTURED': {'Calories': 135.0,
#   'Protein': 2.94,
#   'TotalFat': 12.0,
#   'Carbohydrate': 4.26},
#  'CREAM_SOUR_CULTURED': {'Calories': 193.0,
#   'Protein': 2.07,
#   'TotalFat': 19.73,
#   'Carbohydrate': 2.88},
#  'EGGNOG': {'Calories': 88.0,
#   'Protein': 4.55,
#   'TotalFat': 4.19,
#   'Carbohydrate': 8.05},
#  'SOUR_DRSNG_NON_BUTTERFAT_CULTURED_FILLED_CREAM_TYPE': {'Calories': 178.0,
#   'Protein': 3.25,
#   'TotalFat': 16.57,
#   'Carbohydrate': 4.68},
#  'MILK_FILLED_FLUID_W_BLEND_OF_HYDR_VEG_OILS': {'Calories': 63.0,
#   'Protein': 3.33,
#   'TotalFat': 3.46,
#   'Carbohydrate': 4.74},
#  'MILK_FILLED_FLUID_W_LAURIC_ACID_OIL': {'Calories': 63.0,
#   'Protein': 3.33,
#   'TotalFat': 3.4,
#   'Carbohydrate': 4.74},
#  'CREAM_SUB_LIQ_W_HYDR_VEG_OIL_SOY_PROT': {'Calories': 136.0,
#   'Protein': 1.0,
#   'TotalFat': 9.97,
#   'Carbohydrate': 11.38},
#  'CREAM_SUB_LIQ_W_LAURIC_ACID_OIL_NA_CASEINATE': {'Calories': 136.0,
#   'Protein': 1.0,
#   'TotalFat': 9.97,
#   'Carbohydrate': 11.38},
#  'CREAM_SUBSTITUTE_POWDERED': {'Calories': 545.0,
#   'Protein': 4.79,
#   'TotalFat': 35.48,
#   'Carbohydrate': 54.88},
#  'DESSERT_TOPPING_POWDERED': {'Calories': 577.0,
#   'Protein': 4.9,
#   'TotalFat': 39.92,
#   'Carbohydrate': 52.54},
#  'DESSERT_TOPPING_PDR_1_5_OZ_PREP_W_1_2_CUP_MILK': {'Calories': 194.0,
#   'Protein': 3.61,
#   'TotalFat': 12.72,
#   'Carbohydrate': 17.13},
#  'DESSERT_TOPPING_PRESSURIZED': {'Calories': 264.0,
#   'Protein': 0.98,
#   'TotalFat': 22.3,
#   'Carbohydrate': 16.07},
#  'DESSERT_TOPPING_SEMI_SOLID_FRZ': {'Calories': 318.0,
#   'Protein': 1.25,
#   'TotalFat': 25.31,
#   'Carbohydrate': 23.05},
#  'SOUR_CRM_IMITN_CULTURED': {'Calories': 208.0,
#   'Protein': 2.4,
#   'TotalFat': 19.52,
#   'Carbohydrate': 6.63},
#  'MILK_SUBSTITUTES_FLUID_W_LAURIC_ACID_OIL': {'Calories': 61.0,
#   'Protein': 1.75,
#   'TotalFat': 3.41,
#   'Carbohydrate': 6.16},
#  'MILK_WHL_3_25_MILKFAT_W_ADDED_VITAMIN_D': {'Calories': 61.0,
#   'Protein': 3.15,
#   'TotalFat': 3.25,
#   'Carbohydrate': 4.8},
#  'MILK_PRODUCER_FLUID_3_7_MILKFAT': {'Calories': 64.0,
#   'Protein': 3.28,
#   'TotalFat': 3.66,
#   'Carbohydrate': 4.65},
#  'MILK_RED_FAT_FLUID_2_MILKFAT_W_ADDED_VIT_A_VITAMIN_D': {'Calories': 50.0,
#   'Protein': 3.3,
#   'TotalFat': 1.98,
#   'Carbohydrate': 4.8},
#  'MILK_RED_FAT_FLUID_2_MILKFAT_W_ADDED_NFMS_VIT_A_VIT_D': {'Calories': 51.0,
#   'Protein': 3.48,
#   'TotalFat': 1.92,
#   'Carbohydrate': 4.97},
#  'MILK_RED_FAT_FLUID_2_MILKFAT_PROT_FORT_W_ADDED_VIT_A_D': {'Calories': 56.0,
#   'Protein': 3.95,
#   'TotalFat': 1.98,
#   'Carbohydrate': 5.49},
#  'MILK_LOWFAT_FLUID_1_MILKFAT_W_ADDED_VIT_A_VITAMIN_D': {'Calories': 42.0,
#   'Protein': 3.37,
#   'TotalFat': 0.97,
#   'Carbohydrate': 4.99},
#  'MILK_LOWFAT_FLUID_1_MILKFAT_W_ADD_NONFAT_MILK_SOL_VIT_A_D': {'Calories': 43.0,
#   'Protein': 3.48,
#   'TotalFat': 0.97,
#   'Carbohydrate': 4.97},
#  'MILK_LOWFAT_FLUID_1_MILKFAT_PROT_FORT_W_ADDED_VIT_A_D': {'Calories': 48.0,
#   'Protein': 3.93,
#   'TotalFat': 1.17,
#   'Carbohydrate': 5.52},
#  'MILK_NONFAT_FLUID_W_ADDED_VIT_A_VIT_D_FAT_FREE_OR_SKIM_': {'Calories': 34.0,
#   'Protein': 3.37,
#   'TotalFat': 0.08,
#   'Carbohydrate': 4.96},
#  'MILK_NONFAT_FLUID_W_ADDED_NONFAT_MILK_SOL_VIT_A_VIT_D': {'Calories': 37.0,
#   'Protein': 3.57,
#   'TotalFat': 0.25,
#   'Carbohydrate': 5.02},
#  'MILK_NONFAT_FLUID_PROT_FORT_W_ADD_VIT_A_D_FAT_FREE_SKIM_': {'Calories': 41.0,
#   'Protein': 3.96,
#   'TotalFat': 0.25,
#   'Carbohydrate': 5.56},
#  'MILK_BTTRMLK_FLUID_CULTURED_LOWFAT': {'Calories': 40.0,
#   'Protein': 3.31,
#   'TotalFat': 0.88,
#   'Carbohydrate': 4.79},
#  'MILK_LO_NA_FLUID': {'Calories': 61.0,
#   'Protein': 3.1,
#   'TotalFat': 3.46,
#   'Carbohydrate': 4.46},
#  'MILK_DRY_WHL_W_ADDED_VITAMIN_D': {'Calories': 496.0,
#   'Protein': 26.32,
#   'TotalFat': 26.71,
#   'Carbohydrate': 38.42},
#  'MILK_DRY_NONFAT_REG_WO_ADDED_VIT_A_VITAMIN_D': {'Calories': 362.0,
#   'Protein': 36.16,
#   'TotalFat': 0.77,
#   'Carbohydrate': 51.98},
#  'MILK_DRY_NONFAT_INST_W_ADDED_VIT_A_VITAMIN_D': {'Calories': 358.0,
#   'Protein': 35.1,
#   'TotalFat': 0.72,
#   'Carbohydrate': 52.19},
#  'MILK_DRY_NONFAT_CA_RED': {'Calories': 354.0,
#   'Protein': 35.5,
#   'TotalFat': 0.2,
#   'Carbohydrate': 51.8},
#  'MILK_BUTTERMILK_DRIED': {'Calories': 387.0,
#   'Protein': 34.3,
#   'TotalFat': 5.78,
#   'Carbohydrate': 49.0},
#  'MILK_CND_COND_SWTND': {'Calories': 321.0,
#   'Protein': 7.91,
#   'TotalFat': 8.7,
#   'Carbohydrate': 54.4},
#  'MILK_CND_EVAP_W_ADDED_VITAMIN_D_WO_ADDED_VIT_A': {'Calories': 134.0,
#   'Protein': 6.81,
#   'TotalFat': 7.56,
#   'Carbohydrate': 10.04},
#  'MILK_CND_EVAP_NONFAT_W_ADDED_VIT_A_VITAMIN_D': {'Calories': 78.0,
#   'Protein': 7.55,
#   'TotalFat': 0.2,
#   'Carbohydrate': 11.35},
#  'MILK_CHOC_FLUID_COMM_WHL_W_ADDED_VIT_A_VITAMIN_D': {'Calories': 83.0,
#   'Protein': 3.17,
#   'TotalFat': 3.39,
#   'Carbohydrate': 10.34},
#  'MILK_CHOC_FLUID_COMM_RED_FAT': {'Calories': 76.0,
#   'Protein': 2.99,
#   'TotalFat': 1.9,
#   'Carbohydrate': 12.13},
#  'MILK_CHOC_FLUID_COMM_LOWFAT_W_ADDED_VIT_A_VITAMIN_D': {'Calories': 63.0,
#   'Protein': 3.24,
#   'TotalFat': 1.0,
#   'Carbohydrate': 10.44},
#  'MILK_CHOC_BEV_HOT_COCOA_HOMEMADE': {'Calories': 77.0,
#   'Protein': 3.52,
#   'TotalFat': 2.34,
#   'Carbohydrate': 10.74},
#  'MILK_GOAT_FLUID_W_ADDED_VITAMIN_D': {'Calories': 69.0,
#   'Protein': 3.56,
#   'TotalFat': 4.14,
#   'Carbohydrate': 4.45},
#  'MILK_HUMAN_MATURE_FLUID': {'Calories': 70.0,
#   'Protein': 1.03,
#   'TotalFat': 4.38,
#   'Carbohydrate': 6.89},
#  'MILK_INDIAN_BUFFALO_FLUID': {'Calories': 97.0,
#   'Protein': 3.75,
#   'TotalFat': 6.89,
#   'Carbohydrate': 5.18},
#  'MILK_SHEEP_FLUID': {'Calories': 108.0,
#   'Protein': 5.98,
#   'TotalFat': 7.0,
#   'Carbohydrate': 5.36},
#  'MILK_SHAKES_THICK_CHOC': {'Calories': 119.0,
#   'Protein': 3.05,
#   'TotalFat': 2.7,
#   'Carbohydrate': 21.15},
#  'MILK_SHAKES_THICK_VANILLA': {'Calories': 112.0,
#   'Protein': 3.86,
#   'TotalFat': 3.03,
#   'Carbohydrate': 17.75},
#  'WHEY_ACID_FLUID': {'Calories': 24.0,
#   'Protein': 0.76,
#   'TotalFat': 0.09,
#   'Carbohydrate': 5.12},
#  'WHEY_ACID_DRIED': {'Calories': 339.0,
#   'Protein': 11.73,
#   'TotalFat': 0.54,
#   'Carbohydrate': 73.45},
#  'WHEY_SWEET_FLUID': {'Calories': 27.0,
#   'Protein': 0.85,
#   'TotalFat': 0.36,
#   'Carbohydrate': 5.14},
#  'WHEY_SWEET_DRIED': {'Calories': 353.0,
#   'Protein': 12.93,
#   'TotalFat': 1.07,
#   'Carbohydrate': 74.46},
#  'YOGURT_PLN_WHL_MILK_8_GRAMS_PROT_PER_8_OZ': {'Calories': 61.0,
#   'Protein': 3.47,
#   'TotalFat': 3.25,
#   'Carbohydrate': 4.66},
#  'YOGURT_PLN_LOFAT_12_GRAMS_PROT_PER_8_OZ': {'Calories': 63.0,
#   'Protein': 5.25,
#   'TotalFat': 1.55,
#   'Carbohydrate': 7.04},
#  'YOGURT_PLN_SKIM_MILK_13_GRAMS_PROT_PER_8_OZ': {'Calories': 56.0,
#   'Protein': 5.73,
#   'TotalFat': 0.18,
#   'Carbohydrate': 7.68},
#  'YOGURT_VANILLA_LOFAT_11_GRAMS_PROT_PER_8_OZ': {'Calories': 85.0,
#   'Protein': 4.93,
#   'TotalFat': 1.25,
#   'Carbohydrate': 13.8},
#  'YOGURT_FRUIT_LOFAT_9_GRAMS_PROT_PER_8_OZ': {'Calories': 99.0,
#   'Protein': 3.98,
#   'TotalFat': 1.15,
#   'Carbohydrate': 18.64},
#  'YOGURT_FRUIT_LOFAT_10_GRAMS_PROT_PER_8_OZ': {'Calories': 102.0,
#   'Protein': 4.37,
#   'TotalFat': 1.08,
#   'Carbohydrate': 19.05},
#  'YOGURT_FRUIT_LOFAT_11_GRAMS_PROT_PER_8_OZ': {'Calories': 105.0,
#   'Protein': 4.86,
#   'TotalFat': 1.41,
#   'Carbohydrate': 18.6},
#  'EGG_WHL_RAW_FRSH': {'Calories': 143.0,
#   'Protein': 12.56,
#   'TotalFat': 9.51,
#   'Carbohydrate': 0.72},
#  'EGG_WHITE_RAW_FRESH': {'Calories': 52.0,
#   'Protein': 10.9,
#   'TotalFat': 0.17,
#   'Carbohydrate': 0.73},
#  'EGG_YOLK_RAW_FRSH': {'Calories': 322.0,
#   'Protein': 15.86,
#   'TotalFat': 26.54,
#   'Carbohydrate': 3.59},
#  'EGG_YOLK_RAW_FROZEN': {'Calories': 303.0,
#   'Protein': 15.5,
#   'TotalFat': 25.6,
#   'Carbohydrate': 1.15},
#  'EGG_YOLK_RAW_FRZ_SUGARED': {'Calories': 307.0,
#   'Protein': 13.8,
#   'TotalFat': 22.75,
#   'Carbohydrate': 10.8},
#  'EGG_WHL_CKD_FRIED': {'Calories': 196.0,
#   'Protein': 13.61,
#   'TotalFat': 14.84,
#   'Carbohydrate': 0.83},
#  'EGG_WHL_CKD_HARD_BOILED': {'Calories': 155.0,
#   'Protein': 12.58,
#   'TotalFat': 10.61,
#   'Carbohydrate': 1.12},
#  'EGG_WHOLE_COOKED_OMELET': {'Calories': 154.0,
#   'Protein': 10.57,
#   'TotalFat': 11.66,
#   'Carbohydrate': 0.64},
#  'EGG_WHL_CKD_POACHED': {'Calories': 143.0,
#   'Protein': 12.51,
#   'TotalFat': 9.47,
#   'Carbohydrate': 0.71},
#  'EGG_WHL_CKD_SCRMBLD': {'Calories': 149.0,
#   'Protein': 9.99,
#   'TotalFat': 10.98,
#   'Carbohydrate': 1.61},
#  'EGG_WHOLE_DRIED': {'Calories': 594.0,
#   'Protein': 47.35,
#   'TotalFat': 40.95,
#   'Carbohydrate': 4.95},
#  'EGG_WHL_DRIED_STABILIZED_GLUCOSE_RED': {'Calories': 615.0,
#   'Protein': 48.17,
#   'TotalFat': 43.95,
#   'Carbohydrate': 2.38},
#  'EGG_WHITE_DRIED_FLAKES_GLUCOSE_RED': {'Calories': 351.0,
#   'Protein': 76.92,
#   'TotalFat': 0.04,
#   'Carbohydrate': 4.17},
#  'EGG_WHITE_DRIED_PDR_GLUCOSE_RED': {'Calories': 376.0,
#   'Protein': 82.4,
#   'TotalFat': 0.04,
#   'Carbohydrate': 4.47},
#  'EGG_YOLK_DRIED': {'Calories': 666.0,
#   'Protein': 34.25,
#   'TotalFat': 55.8,
#   'Carbohydrate': 3.6},
#  'EGG_DUCK_WHOLE_FRESH_RAW': {'Calories': 185.0,
#   'Protein': 12.81,
#   'TotalFat': 13.77,
#   'Carbohydrate': 1.45},
#  'EGG_GOOSE_WHOLE_FRESH_RAW': {'Calories': 185.0,
#   'Protein': 13.87,
#   'TotalFat': 13.27,
#   'Carbohydrate': 1.35},
#  'EGG_QUAIL_WHOLE_FRESH_RAW': {'Calories': 158.0,
#   'Protein': 13.05,
#   'TotalFat': 11.09,
#   'Carbohydrate': 0.41},
#  'EGG_TURKEY_WHL_FRSH_RAW': {'Calories': 171.0,
#   'Protein': 13.68,
#   'TotalFat': 11.88,
#   'Carbohydrate': 1.15},
#  'EGG_SUBSTITUTE_POWDER': {'Calories': 444.0,
#   'Protein': 55.5,
#   'TotalFat': 13.0,
#   'Carbohydrate': 21.8},
#  'BUTTER_WITHOUT_SALT': {'Calories': 717.0,
#   'Protein': 0.85,
#   'TotalFat': 81.11,
#   'Carbohydrate': 0.06},
#  'CHEESE_PARMESAN_SHREDDED': {'Calories': 415.0,
#   'Protein': 37.86,
#   'TotalFat': 27.34,
#   'Carbohydrate': 3.41},
#  'MILK_NONFAT_FLUID_WO_ADDED_VIT_A_VIT_D_FAT_FREE_OR_SKIM_': {'Calories': 34.0,
#   'Protein': 3.37,
#   'TotalFat': 0.08,
#   'Carbohydrate': 4.96},
#  'MILK_RED_FAT_FLUID_2_MILKFAT_W_NONFAT_MILK_SOL_WO_VIT_A': {'Calories': 56.0,
#   'Protein': 3.95,
#   'TotalFat': 1.98,
#   'Carbohydrate': 5.49},
#  'MILK_CND_EVAP_W_VIT_A': {'Calories': 134.0,
#   'Protein': 6.81,
#   'TotalFat': 7.56,
#   'Carbohydrate': 10.04},
#  'MILK_DRY_NONFAT_REG_W_ADDED_VIT_A_VITAMIN_D': {'Calories': 362.0,
#   'Protein': 36.16,
#   'TotalFat': 0.77,
#   'Carbohydrate': 51.98},
#  'MILK_DRY_NONFAT_INST_WO_ADDED_VIT_A_VITAMIN_D': {'Calories': 358.0,
#   'Protein': 35.1,
#   'TotalFat': 0.72,
#   'Carbohydrate': 52.19},
#  'CHEESE_GOAT_HARD_TYPE': {'Calories': 452.0,
#   'Protein': 30.52,
#   'TotalFat': 35.59,
#   'Carbohydrate': 2.17},
#  'CHEESE_GOAT_SEMISOFT_TYPE': {'Calories': 364.0,
#   'Protein': 21.58,
#   'TotalFat': 29.84,
#   'Carbohydrate': 2.54},
#  'CHEESE_GOAT_SOFT_TYPE': {'Calories': 268.0,
#   'Protein': 18.52,
#   'TotalFat': 21.08,
#   'Carbohydrate': 0.89},
#  'EGG_YOLK_RAW_FRZ_SALTED': {'Calories': 274.0,
#   'Protein': 14.0,
#   'TotalFat': 23.0,
#   'Carbohydrate': 1.6},
#  'CHEESE_SUB_MOZZARELLA': {'Calories': 248.0,
#   'Protein': 11.47,
#   'TotalFat': 12.22,
#   'Carbohydrate': 23.67},
#  'CHEESE_FONDUE': {'Calories': 229.0,
#   'Protein': 14.23,
#   'TotalFat': 13.47,
#   'Carbohydrate': 3.77},
#  'CHEESE_SAU_PREP_FROM_RECIPE': {'Calories': 197.0,
#   'Protein': 10.33,
#   'TotalFat': 14.92,
#   'Carbohydrate': 5.48},
#  'CHEESE_MEXICAN_QUESO_ANEJO': {'Calories': 373.0,
#   'Protein': 21.44,
#   'TotalFat': 29.98,
#   'Carbohydrate': 4.63},
#  'CHEESE_MEXICAN_QUESO_ASADERO': {'Calories': 356.0,
#   'Protein': 22.6,
#   'TotalFat': 28.26,
#   'Carbohydrate': 2.87},
#  'CHEESE_MEXICAN_QUESO_CHIHUAHUA': {'Calories': 374.0,
#   'Protein': 21.56,
#   'TotalFat': 29.68,
#   'Carbohydrate': 5.56},
#  'CHEESE_LOFAT_CHEDDAR_OR_COLBY': {'Calories': 173.0,
#   'Protein': 24.35,
#   'TotalFat': 7.0,
#   'Carbohydrate': 1.91},
#  'CHEESE_LOW_SODIUM_CHEDDAR_OR_COLBY': {'Calories': 398.0,
#   'Protein': 24.35,
#   'TotalFat': 32.62,
#   'Carbohydrate': 1.91},
#  'EGG_WHOLE_RAW_FROZEN': {'Calories': 148.0,
#   'Protein': 11.95,
#   'TotalFat': 10.2,
#   'Carbohydrate': 1.05},
#  'EGG_WHITE_RAW_FROZEN': {'Calories': 47.0,
#   'Protein': 9.8,
#   'TotalFat': 0.0,
#   'Carbohydrate': 1.05},
#  'EGG_WHITE_DRIED': {'Calories': 382.0,
#   'Protein': 81.1,
#   'TotalFat': 0.0,
#   'Carbohydrate': 7.8},
#  'MILK_RED_FAT_FLUID_2_MILKFAT_WO_ADDED_VIT_A_VIT_D': {'Calories': 50.0,
#   'Protein': 3.3,
#   'TotalFat': 1.98,
#   'Carbohydrate': 4.8},
#  'MILK_FLUID_1_FAT_WO_ADDED_VIT_A_VIT_D': {'Calories': 42.0,
#   'Protein': 3.37,
#   'TotalFat': 0.97,
#   'Carbohydrate': 4.99},
#  'SOUR_CREAM_REDUCED_FAT': {'Calories': 181.0,
#   'Protein': 7.0,
#   'TotalFat': 14.1,
#   'Carbohydrate': 7.0},
#  'SOUR_CREAM_LIGHT': {'Calories': 138.0,
#   'Protein': 3.5,
#   'TotalFat': 10.6,
#   'Carbohydrate': 7.1},
#  'SOUR_CREAM_FAT_FREE': {'Calories': 74.0,
#   'Protein': 3.1,
#   'TotalFat': 0.0,
#   'Carbohydrate': 15.6},
#  'USDA_COMMODITY_CHS_CHEDDAR_RED_FAT': {'Calories': 282.0,
#   'Protein': 27.2,
#   'TotalFat': 18.3,
#   'Carbohydrate': 2.0},
#  'YOGURT_VAN_OR_LEM_FLAV_NONFAT_MILK_SWTND_W_LOW_CALORIE_SWTNR': {'Calories': 43.0,
#   'Protein': 3.86,
#   'TotalFat': 0.18,
#   'Carbohydrate': 7.5},
#  'PARMESAN_CHS_TOPPING_FAT_FREE': {'Calories': 370.0,
#   'Protein': 40.0,
#   'TotalFat': 5.0,
#   'Carbohydrate': 40.0},
#  'CHEESE_CREAM_FAT_FREE': {'Calories': 105.0,
#   'Protein': 15.69,
#   'TotalFat': 1.0,
#   'Carbohydrate': 7.66},
#  'YOGURT_CHOC_NONFAT_MILK': {'Calories': 112.0,
#   'Protein': 3.53,
#   'TotalFat': 0.0,
#   'Carbohydrate': 23.53},
#  'KRAFT_CHEEZ_WHIZ_PAST_PROCESS_CHS_SAU': {'Calories': 276.0,
#   'Protein': 12.0,
#   'TotalFat': 21.0,
#   'Carbohydrate': 9.2},
#  'KRAFT_CHEEZ_WHIZ_LT_PAST_PROCESS_CHS_PRODUCT': {'Calories': 215.0,
#   'Protein': 16.3,
#   'TotalFat': 9.5,
#   'Carbohydrate': 16.2},
#  'KRAFT_FREE_SINGLES_AMERICAN_NONFAT_PAST_PROCESS_CHS_PRODUCT': {'Calories': 148.0,
#   'Protein': 22.7,
#   'TotalFat': 1.0,
#   'Carbohydrate': 11.7},
#  'KRAFT_VELVEETA_PAST_PROCESS_CHS_SPRD': {'Calories': 303.0,
#   'Protein': 16.3,
#   'TotalFat': 22.0,
#   'Carbohydrate': 9.8},
#  'KRAFT_VELVEETA_LT_RED_FAT_PAST_PROCESS_CHS_PRODUCT': {'Calories': 222.0,
#   'Protein': 19.6,
#   'TotalFat': 10.6,
#   'Carbohydrate': 11.8},
#  'KRAFT_BREAKSTONE_S_RED_FAT_SOUR_CRM': {'Calories': 152.0,
#   'Protein': 4.5,
#   'TotalFat': 12.0,
#   'Carbohydrate': 6.5},
#  'KRAFT_BREAKSTONE_S_FREE_FAT_FREE_SOUR_CRM': {'Calories': 91.0,
#   'Protein': 4.7,
#   'TotalFat': 1.3,
#   'Carbohydrate': 15.1},
#  'KRAFT_BREYERS_LOWFAT_STRAWBERRY_YOGURT_1_MILKFAT_': {'Calories': 96.0,
#   'Protein': 3.8,
#   'TotalFat': 0.8,
#   'Carbohydrate': 18.2},
#  'KRAFT_BREYERS_LT_N_LVLY_LOWFAT_STR_BERY_YOGURT_1_MILKFAT_': {'Calories': 108.0,
#   'Protein': 3.2,
#   'TotalFat': 0.8,
#   'Carbohydrate': 21.9},
#  'KRAFT_BREYERS_SMOTH_CRMY_LOWFAT_STR_BERY_YOGURT_1_MILKFAT_': {'Calories': 102.0,
#   'Protein': 3.8,
#   'TotalFat': 0.9,
#   'Carbohydrate': 19.9},
#  'KRAFT_BREYERS_LT_NONFAT_STR_BERY_YOGURT_W_ASPRT_FRUCT_SW_T_': {'Calories': 55.0,
#   'Protein': 3.4,
#   'TotalFat': 0.2,
#   'Carbohydrate': 9.9},
#  'CREAM_HALF_HALF_FAT_FREE': {'Calories': 59.0,
#   'Protein': 2.6,
#   'TotalFat': 1.4,
#   'Carbohydrate': 9.0},
#  'REDDI_WIP_FAT_FREE_WHIPPED_TOPPING': {'Calories': 149.0,
#   'Protein': 3.0,
#   'TotalFat': 5.0,
#   'Carbohydrate': 25.0},
#  'MILK_CHOC_FLUID_COMM_RED_FAT_W_ADDED_CA': {'Calories': 78.0,
#   'Protein': 2.99,
#   'TotalFat': 1.9,
#   'Carbohydrate': 12.13},
#  'YOGURT_FRUIT_LOFAT_W_LO_CAL_SWEETENER': {'Calories': 105.0,
#   'Protein': 4.86,
#   'TotalFat': 1.41,
#   'Carbohydrate': 18.6},
#  'CHEESE_PARMESAN_DRY_GRATED_RED_FAT': {'Calories': 265.0,
#   'Protein': 20.0,
#   'TotalFat': 20.0,
#   'Carbohydrate': 1.37},
#  'CREAM_SUB_FLAV_LIQ': {'Calories': 251.0,
#   'Protein': 0.69,
#   'TotalFat': 13.5,
#   'Carbohydrate': 35.07},
#  'CREAM_SUB_FLAV_PDR': {'Calories': 498.0,
#   'Protein': 0.68,
#   'TotalFat': 21.47,
#   'Carbohydrate': 75.42},
#  'CHEESE_PROVOLONE_RED_FAT': {'Calories': 274.0,
#   'Protein': 24.7,
#   'TotalFat': 17.6,
#   'Carbohydrate': 3.5},
#  'CHEESE_MEXICAN_BLEND_RED_FAT': {'Calories': 282.0,
#   'Protein': 24.69,
#   'TotalFat': 19.4,
#   'Carbohydrate': 3.41},
#  'EGG_MIX_USDA_CMDTY': {'Calories': 555.0,
#   'Protein': 35.6,
#   'TotalFat': 34.5,
#   'Carbohydrate': 23.97},
#  'MILK_WHL_3_25_MILKFAT_WO_ADDED_VIT_A_VITAMIN_D': {'Calories': 61.0,
#   'Protein': 3.15,
#   'TotalFat': 3.27,
#   'Carbohydrate': 4.78},
#  'MILK_DRY_WHL_WO_ADDED_VITAMIN_D': {'Calories': 496.0,
#   'Protein': 26.32,
#   'TotalFat': 26.71,
#   'Carbohydrate': 38.42},
#  'MILK_CND_EVAP_WO_ADDED_VIT_A_VITAMIN_D': {'Calories': 135.0,
#   'Protein': 6.81,
#   'TotalFat': 7.56,
#   'Carbohydrate': 10.04},
#  'CHEESE_PRODUCT_PAST_PROCESS_AMERICAN_RED_FAT_FORT_W_VIT_D': {'Calories': 240.0,
#   'Protein': 17.6,
#   'TotalFat': 14.1,
#   'Carbohydrate': 10.6},
#  'YOGURT_FRUIT_LOFAT_9_GRAMS_PROT_PER_8_OZ_FORT_W_VITAMIN_D': {'Calories': 99.0,
#   'Protein': 3.98,
#   'TotalFat': 1.15,
#   'Carbohydrate': 18.64},
#  'YOGURT_FRUIT_LOFAT_10_GRAMS_PROT_PER_8_OZ_FORT_W_VITAMIN_D': {'Calories': 102.0,
#   'Protein': 4.37,
#   'TotalFat': 1.08,
#   'Carbohydrate': 19.05},
#  'YOGURT_FRUIT_VAR_NONFAT_FORT_W_VITAMIN_D': {'Calories': 95.0,
#   'Protein': 4.4,
#   'TotalFat': 0.2,
#   'Carbohydrate': 19.0},
#  'YOGURT_FRUIT_LOWFAT_W_LO_CAL_SWTNR_FORT_W_VITAMIN_D': {'Calories': 105.0,
#   'Protein': 4.86,
#   'TotalFat': 1.41,
#   'Carbohydrate': 18.6},
#  'YOGURT_VANILLA_LOFAT_11_GRAMS_PROT_PER_8_OZ_FORT_W_VIT_D': {'Calories': 85.0,
#   'Protein': 4.93,
#   'TotalFat': 1.25,
#   'Carbohydrate': 13.8},
#  'YOGURT_VAN_LEM_FLAV_NONFAT_MILK_W_LO_CAL_SWTNR_FORT_W_VIT_D': {'Calories': 43.0,
#   'Protein': 3.86,
#   'TotalFat': 0.18,
#   'Carbohydrate': 7.5},
#  'YOGURT_CHOC_NONFAT_MILK_FORT_W_VITAMIN_D': {'Calories': 112.0,
#   'Protein': 3.53,
#   'TotalFat': 0.0,
#   'Carbohydrate': 23.53},
#  'PROTEIN_SUPP_MILK_BSD_MUSCLE_MILK_PDR': {'Calories': 411.0,
#   'Protein': 45.71,
#   'TotalFat': 17.14,
#   'Carbohydrate': 18.5},
#  'PROTEIN_SUPP_MILK_BSD_MUSCLE_MILK_LT_PDR': {'Calories': 396.0,
#   'Protein': 50.0,
#   'TotalFat': 12.0,
#   'Carbohydrate': 22.0},
#  'DULCE_DE_LECHE': {'Calories': 315.0,
#   'Protein': 6.84,
#   'TotalFat': 7.35,
#   'Carbohydrate': 55.35},
#  'EGG_SUB_LIQ_OR_FRZ_FAT_FREE': {'Calories': 48.0,
#   'Protein': 10.0,
#   'TotalFat': 0.0,
#   'Carbohydrate': 2.0},
#  'CHEESE_DRY_WHITE_QUESO_SECO': {'Calories': 325.0,
#   'Protein': 24.51,
#   'TotalFat': 24.35,
#   'Carbohydrate': 2.04},
#  'CHEESE_FRSH_QUESO_FRESCO': {'Calories': 299.0,
#   'Protein': 18.09,
#   'TotalFat': 23.82,
#   'Carbohydrate': 2.98},
#  'CHEESE_WHITE_QUESO_BLANCO': {'Calories': 310.0,
#   'Protein': 20.38,
#   'TotalFat': 24.31,
#   'Carbohydrate': 2.53},
#  'MILK_BTTRMLK_FLUID_WHL': {'Calories': 62.0,
#   'Protein': 3.21,
#   'TotalFat': 3.31,
#   'Carbohydrate': 4.88},
#  'YOGURT_VANILLA_FLAVOR_LOWFAT_MILK_SWTND_W_LO_CAL_SWTNR': {'Calories': 86.0,
#   'Protein': 4.93,
#   'TotalFat': 1.25,
#   'Carbohydrate': 13.8},
#  'YOGURT_FRZ_FLAVORS_NOT_CHOC_NONFAT_MILK_W_LOW_CALORIE_SWTNR': {'Calories': 104.0,
#   'Protein': 4.4,
#   'TotalFat': 0.8,
#   'Carbohydrate': 19.7},
#  'ICE_CRM_SOFT_SERVE_CHOC': {'Calories': 222.0,
#   'Protein': 4.1,
#   'TotalFat': 13.0,
#   'Carbohydrate': 22.2},
#  'ICE_CRM_BAR_OR_STK_CHOC_COVERED': {'Calories': 331.0,
#   'Protein': 4.1,
#   'TotalFat': 24.1,
#   'Carbohydrate': 24.5},
#  'ICE_CRM_SNDWCH': {'Calories': 237.0,
#   'Protein': 4.29,
#   'TotalFat': 8.57,
#   'Carbohydrate': 37.14},
#  'ICE_CRM_COOKIE_SNDWCH': {'Calories': 240.0,
#   'Protein': 3.7,
#   'TotalFat': 7.4,
#   'Carbohydrate': 39.6},
#  'ICE_CRM_CONE_CHOC_COVERED_W_NUTS_FLAVORS_OTHER_THAN_CHOC': {'Calories': 354.0,
#   'Protein': 5.21,
#   'TotalFat': 21.88,
#   'Carbohydrate': 34.38},
#  'ICE_CRM_SNDWCH_MADE_W_LT_ICE_CRM_VANILLA': {'Calories': 186.0,
#   'Protein': 4.29,
#   'TotalFat': 3.04,
#   'Carbohydrate': 39.64},
#  'ICE_CRM_SNDWCH_VANILLA_LT_NO_SUGAR_ADDED': {'Calories': 200.0,
#   'Protein': 5.71,
#   'TotalFat': 2.86,
#   'Carbohydrate': 42.86},
#  'FAT_FREE_ICE_CRM_NO_SUGAR_ADDED_FLAVORS_OTHER_THAN_CHOC': {'Calories': 129.0,
#   'Protein': 4.41,
#   'TotalFat': 0.0,
#   'Carbohydrate': 27.94},
#  'MILK_DSSRT_BAR_FRZ_MADE_FROM_LOWFAT_MILK': {'Calories': 147.0,
#   'Protein': 4.41,
#   'TotalFat': 1.47,
#   'Carbohydrate': 33.09},
#  'NUTRITIONAL_SUPP_FOR_PEOPLE_W_DIABETES_LIQ': {'Calories': 88.0,
#   'Protein': 4.4,
#   'TotalFat': 3.08,
#   'Carbohydrate': 11.88},
#  'CHEESE_MEXICAN_BLEND': {'Calories': 358.0,
#   'Protein': 23.54,
#   'TotalFat': 28.51,
#   'Carbohydrate': 1.75},
#  'CHEESE_PRODUCT_PAST_PROCESS_AMERICAN_VITAMIN_D_FORT': {'Calories': 310.0,
#   'Protein': 18.18,
#   'TotalFat': 22.63,
#   'Carbohydrate': 8.52},
#  'CHEESE_PAST_PROCESS_AMERICAN_WO_ADDED_VITAMIN_D': {'Calories': 371.0,
#   'Protein': 18.13,
#   'TotalFat': 31.79,
#   'Carbohydrate': 3.7},
#  'CHEESE_FD_PAST_PROCESS_AMERICAN_WO_ADDED_VITAMIN_D': {'Calories': 330.0,
#   'Protein': 16.86,
#   'TotalFat': 25.63,
#   'Carbohydrate': 8.56},
#  'EGG_WHL_RAW_FRZ_SALTED': {'Calories': 138.0,
#   'Protein': 10.97,
#   'TotalFat': 10.07,
#   'Carbohydrate': 0.83},
#  'ALLSPICE_GROUND': {'Calories': 263.0,
#   'Protein': 6.09,
#   'TotalFat': 8.69,
#   'Carbohydrate': 72.12},
#  'ANISE_SEED': {'Calories': 337.0,
#   'Protein': 17.6,
#   'TotalFat': 15.9,
#   'Carbohydrate': 50.02},
#  'SPICES_BASIL_DRIED': {'Calories': 233.0,
#   'Protein': 22.98,
#   'TotalFat': 4.07,
#   'Carbohydrate': 47.75},
#  'SPICES_BAY_LEAF': {'Calories': 313.0,
#   'Protein': 7.61,
#   'TotalFat': 8.36,
#   'Carbohydrate': 74.97},
#  'CARAWAY_SEED': {'Calories': 333.0,
#   'Protein': 19.77,
#   'TotalFat': 14.59,
#   'Carbohydrate': 49.9},
#  'SPICES_CARDAMOM': {'Calories': 311.0,
#   'Protein': 10.76,
#   'TotalFat': 6.7,
#   'Carbohydrate': 68.47},
#  'CELERY_SEED': {'Calories': 392.0,
#   'Protein': 18.07,
#   'TotalFat': 25.27,
#   'Carbohydrate': 41.35},
#  'CHERVIL_DRIED': {'Calories': 237.0,
#   'Protein': 23.2,
#   'TotalFat': 3.9,
#   'Carbohydrate': 49.1},
#  'CHILI_POWDER': {'Calories': 282.0,
#   'Protein': 13.46,
#   'TotalFat': 14.28,
#   'Carbohydrate': 49.7},
#  'CINNAMON_GROUND': {'Calories': 247.0,
#   'Protein': 3.99,
#   'TotalFat': 1.24,
#   'Carbohydrate': 80.59},
#  'CLOVES_GROUND': {'Calories': 274.0,
#   'Protein': 5.97,
#   'TotalFat': 13.0,
#   'Carbohydrate': 65.53},
#  'CORIANDER_LEAF_DRIED': {'Calories': 279.0,
#   'Protein': 21.93,
#   'TotalFat': 4.78,
#   'Carbohydrate': 52.1},
#  'CORIANDER_SEED': {'Calories': 298.0,
#   'Protein': 12.37,
#   'TotalFat': 17.77,
#   'Carbohydrate': 54.99},
#  'CUMIN_SEED': {'Calories': 375.0,
#   'Protein': 17.81,
#   'TotalFat': 22.27,
#   'Carbohydrate': 44.24},
#  'CURRY_POWDER': {'Calories': 325.0,
#   'Protein': 12.66,
#   'TotalFat': 13.81,
#   'Carbohydrate': 58.15},
#  'DILL_SEED': {'Calories': 305.0,
#   'Protein': 15.98,
#   'TotalFat': 14.54,
#   'Carbohydrate': 55.17},
#  'DILL_WEED_DRIED': {'Calories': 253.0,
#   'Protein': 19.96,
#   'TotalFat': 4.36,
#   'Carbohydrate': 55.82},
#  'FENNEL_SEED': {'Calories': 345.0,
#   'Protein': 15.8,
#   'TotalFat': 14.87,
#   'Carbohydrate': 52.29},
#  'FENUGREEK_SEED': {'Calories': 323.0,
#   'Protein': 23.0,
#   'TotalFat': 6.41,
#   'Carbohydrate': 58.35},
#  'GARLIC_POWDER': {'Calories': 331.0,
#   'Protein': 16.55,
#   'TotalFat': 0.73,
#   'Carbohydrate': 72.73},
#  'GINGER_GROUND': {'Calories': 335.0,
#   'Protein': 8.98,
#   'TotalFat': 4.24,
#   'Carbohydrate': 71.62},
#  'MACE_GROUND': {'Calories': 475.0,
#   'Protein': 6.71,
#   'TotalFat': 32.38,
#   'Carbohydrate': 50.5},
#  'MARJORAM_DRIED': {'Calories': 271.0,
#   'Protein': 12.66,
#   'TotalFat': 7.04,
#   'Carbohydrate': 60.56},
#  'SPICES_MUSTARD_SD_GROUND': {'Calories': 508.0,
#   'Protein': 26.08,
#   'TotalFat': 36.24,
#   'Carbohydrate': 28.09},
#  'NUTMEG_GROUND': {'Calories': 525.0,
#   'Protein': 5.84,
#   'TotalFat': 36.31,
#   'Carbohydrate': 49.29},
#  'ONION_POWDER': {'Calories': 341.0,
#   'Protein': 10.41,
#   'TotalFat': 1.04,
#   'Carbohydrate': 79.12},
#  'SPICES_OREGANO_DRIED': {'Calories': 265.0,
#   'Protein': 9.0,
#   'TotalFat': 4.28,
#   'Carbohydrate': 68.92},
#  'PAPRIKA': {'Calories': 282.0,
#   'Protein': 14.14,
#   'TotalFat': 12.89,
#   'Carbohydrate': 53.99},
#  'PARSLEY_DRIED': {'Calories': 292.0,
#   'Protein': 26.63,
#   'TotalFat': 5.48,
#   'Carbohydrate': 50.64},
#  'PEPPER_BLACK': {'Calories': 251.0,
#   'Protein': 10.39,
#   'TotalFat': 3.26,
#   'Carbohydrate': 63.95},
#  'PEPPER_RED_OR_CAYENNE': {'Calories': 318.0,
#   'Protein': 12.01,
#   'TotalFat': 17.27,
#   'Carbohydrate': 56.63},
#  'PEPPER_WHITE': {'Calories': 296.0,
#   'Protein': 10.4,
#   'TotalFat': 2.12,
#   'Carbohydrate': 68.61},
#  'POPPY_SEED': {'Calories': 525.0,
#   'Protein': 17.99,
#   'TotalFat': 41.56,
#   'Carbohydrate': 28.13},
#  'POULTRY_SEASONING': {'Calories': 307.0,
#   'Protein': 9.59,
#   'TotalFat': 7.53,
#   'Carbohydrate': 65.59},
#  'PUMPKIN_PIE_SPICE': {'Calories': 342.0,
#   'Protein': 5.76,
#   'TotalFat': 12.6,
#   'Carbohydrate': 69.28},
#  'ROSEMARY_DRIED': {'Calories': 331.0,
#   'Protein': 4.88,
#   'TotalFat': 15.22,
#   'Carbohydrate': 64.06},
#  'SAFFRON': {'Calories': 310.0,
#   'Protein': 11.43,
#   'TotalFat': 5.85,
#   'Carbohydrate': 65.37},
#  'SAGE_GROUND': {'Calories': 315.0,
#   'Protein': 10.63,
#   'TotalFat': 12.75,
#   'Carbohydrate': 60.73},
#  'SAVORY_GROUND': {'Calories': 272.0,
#   'Protein': 6.73,
#   'TotalFat': 5.91,
#   'Carbohydrate': 68.73},
#  'SPICES_TARRAGON_DRIED': {'Calories': 295.0,
#   'Protein': 22.77,
#   'TotalFat': 7.24,
#   'Carbohydrate': 50.22},
#  'SPICES_THYME_DRIED': {'Calories': 276.0,
#   'Protein': 9.11,
#   'TotalFat': 7.43,
#   'Carbohydrate': 63.94},
#  'TURMERIC_GROUND': {'Calories': 354.0,
#   'Protein': 7.83,
#   'TotalFat': 9.88,
#   'Carbohydrate': 64.93},
#  'BASIL_FRESH': {'Calories': 23.0,
#   'Protein': 3.15,
#   'TotalFat': 0.64,
#   'Carbohydrate': 2.65},
#  'DILL_WEED_FRSH': {'Calories': 43.0,
#   'Protein': 3.46,
#   'TotalFat': 1.12,
#   'Carbohydrate': 7.02},
#  'MUSTARD_PREPARED_YELLOW': {'Calories': 67.0,
#   'Protein': 4.37,
#   'TotalFat': 4.01,
#   'Carbohydrate': 5.33},
#  'SALT_TABLE': {'Calories': 0.0,
#   'Protein': 0.0,
#   'TotalFat': 0.0,
#   'Carbohydrate': 0.0},
#  'VINEGAR_CIDER': {'Calories': 21.0,
#   'Protein': 0.0,
#   'TotalFat': 0.0,
#   'Carbohydrate': 0.93},
#  'THYME_FRSH': {'Calories': 101.0,
#   'Protein': 5.56,
#   'TotalFat': 1.68,
#   'Carbohydrate': 24.45},
#  'VANILLA_EXTRACT': {'Calories': 288.0,
#   'Protein': 0.06,
#   'TotalFat': 0.06,
#   'Carbohydrate': 12.65},
#  'VANILLA_EXTRACT_IMITN_ALCOHOL': {'Calories': 237.0,
#   'Protein': 0.05,
#   'TotalFat': 0.0,
#   'Carbohydrate': 2.41},
#  'VANILLA_EXTRACT_IMITN_NO_ALCOHOL': {'Calories': 56.0,
#   'Protein': 0.03,
#   'TotalFat': 0.0,
#   'Carbohydrate': 14.4},
#  'VINEGAR_DISTILLED': {'Calories': 18.0,
#   'Protein': 0.0,
#   'TotalFat': 0.0,
#   'Carbohydrate': 0.04},
#  'CAPERS_CANNED': {'Calories': 23.0,
#   'Protein': 2.36,
#   'TotalFat': 0.86,
#   'Carbohydrate': 4.89},
#  'HORSERADISH_PREPARED': {'Calories': 48.0,
#   'Protein': 1.18,
#   'TotalFat': 0.69,
#   'Carbohydrate': 11.29},
#  'ROSEMARY_FRESH': {'Calories': 131.0,
#   'Protein': 3.31,
#   'TotalFat': 5.86,
#   'Carbohydrate': 20.7},
#  'PEPPERMINT_FRESH': {'Calories': 70.0,
#   'Protein': 3.75,
#   'TotalFat': 0.94,
#   'Carbohydrate': 14.89},
#  'SPEARMINT_FRESH': {'Calories': 44.0,
#   'Protein': 3.29,
#   'TotalFat': 0.73,
#   'Carbohydrate': 8.41},
#  'SPEARMINT_DRIED': {'Calories': 285.0,
#   'Protein': 19.93,
#   'TotalFat': 6.03,
#   'Carbohydrate': 52.04},
#  'VINEGAR_RED_WINE': {'Calories': 19.0,
#   'Protein': 0.04,
#   'TotalFat': 0.0,
#   'Carbohydrate': 0.27},
#  'VINEGAR_BALSAMIC': {'Calories': 88.0,
#   'Protein': 0.49,
#   'TotalFat': 0.0,
#   'Carbohydrate': 17.03},
#  'CAMPBELL_SOUP_CO_PACE_DRY_TACO_SEAS_MIX': {'Calories': 188.0,
#   'Protein': 0.0,
#   'TotalFat': 0.0,
#   'Carbohydrate': 56.29},
#  'GERBER_GRADUATES_FRUIT_STRIPS_REAL_FRUIT_BARS': {'Calories': 330.0,
#   'Protein': 0.82,
#   'TotalFat': 2.24,
#   'Carbohydrate': 76.61},
#  'ZWIEBACK': {'Calories': 426.0,
#   'Protein': 10.1,
#   'TotalFat': 9.7,
#   'Carbohydrate': 74.2},
#  'CHILD_FORMULA_MEAD_JOHNSON_PORTAGEN_W_IRON_PDR_NOT_RECON': {'Calories': 483.0,
#   'Protein': 16.5,
#   'TotalFat': 22.0,
#   'Carbohydrate': 54.8},
#  'CHILD_FORMULA_MEAD_JOHNSON_PORTAGEN_W_IRON_PREP_FROM_PDR': {'Calories': 88.0,
#   'Protein': 3.33,
#   'TotalFat': 4.48,
#   'Carbohydrate': 8.57},
#  'In_for_M_JOHN_ENF_ENFAC_LIP_with_ir_po_wi_ARA_and_DH': {'Calories': 514.0,
#   'Protein': 12.5,
#   'TotalFat': 27.0,
#   'Carbohydrate': 56.0},
#  'CHILD_FORMULA_ABBOTT_NUTR_PEDIASURE_RTF_FORMERLY_ROSS_': {'Calories': 99.0,
#   'Protein': 2.86,
#   'TotalFat': 4.77,
#   'Carbohydrate': 11.15},
#  'CHI_FORMU_ABBT_NUTR_PEDIASU_RTF_W_IRON_FIB_FORMER_ROSS_': {'Calories': 99.0,
#   'Protein': 2.8,
#   'TotalFat': 4.7,
#   'Carbohydrate': 11.28},
#  'TODDLER_FORMULA_MEAD_JOHNSON_ENFAGROW_PREMIUM_RTF': {'Calories': 64.0,
#   'Protein': 1.78,
#   'TotalFat': 3.63,
#   'Carbohydrate': 7.18},
#  'FAT_BEEF_TALLOW': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'LARD': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SALAD_DRSNG_KRAFT_MAYO_LT_MAYO': {'Calories': 334.0,
#   'Protein': 0.6,
#   'TotalFat': 32.9,
#   'Carbohydrate': 8.5},
#  'SALAD_DRSNG_KRAFT_MAYO_FAT_FREE_MAYO_DRSNG': {'Calories': 70.0,
#   'Protein': 0.2,
#   'TotalFat': 2.7,
#   'Carbohydrate': 12.4},
#  'SALAD_DRSNG_KRAFT_MIRACLE_WHIP_FREE_NONFAT_DRSNG': {'Calories': 84.0,
#   'Protein': 0.2,
#   'TotalFat': 2.7,
#   'Carbohydrate': 15.5},
#  'SALAD_DRSNG_RUSSIAN_DRSNG': {'Calories': 355.0,
#   'Protein': 0.69,
#   'TotalFat': 26.18,
#   'Carbohydrate': 31.9},
#  'SALAD_DRSNG_SESAME_SD_DRSNG_REG': {'Calories': 443.0,
#   'Protein': 3.1,
#   'TotalFat': 45.2,
#   'Carbohydrate': 8.6},
#  'SALAD_DRSNG_1000_ISLAND_COMM_REG': {'Calories': 370.0,
#   'Protein': 1.09,
#   'TotalFat': 35.06,
#   'Carbohydrate': 14.64},
#  'SALAD_DRSNG_MAYO_TYPE_REG_W_SALT': {'Calories': 390.0,
#   'Protein': 0.9,
#   'TotalFat': 33.4,
#   'Carbohydrate': 23.9},
#  'SALAD_DRSNG_FRENCH_DRSNG_RED_FAT': {'Calories': 222.0,
#   'Protein': 0.58,
#   'TotalFat': 11.52,
#   'Carbohydrate': 31.22},
#  'SALAD_DRSNG_ITALIAN_DRSNG_RED_FAT': {'Calories': 75.0,
#   'Protein': 0.47,
#   'TotalFat': 6.38,
#   'Carbohydrate': 4.57},
#  'SALAD_DRSNG_RUSSIAN_DRSNG_LO_CAL': {'Calories': 141.0,
#   'Protein': 0.5,
#   'TotalFat': 4.0,
#   'Carbohydrate': 27.6},
#  'SALAD_DRSNG_1000_ISLAND_DRSNG_RED_FAT': {'Calories': 195.0,
#   'Protein': 0.83,
#   'TotalFat': 11.32,
#   'Carbohydrate': 24.06},
#  'SALAD_DRSNG_MAYO_SOYBN_OIL_W_SALT': {'Calories': 718.0,
#   'Protein': 0.9,
#   'TotalFat': 79.39,
#   'Carbohydrate': 3.16},
#  'SALAD_DRSNG_MAYO_SOYBN_SAFFLOWER_OIL_W_SALT': {'Calories': 717.0,
#   'Protein': 1.1,
#   'TotalFat': 79.4,
#   'Carbohydrate': 2.7},
#  'SALAD_DRSNG_MAYO_IMITN_SOYBN': {'Calories': 232.0,
#   'Protein': 0.3,
#   'TotalFat': 19.2,
#   'Carbohydrate': 16.0},
#  'SALAD_DRSNG_MAYO_IMITN_MILK_CRM': {'Calories': 97.0,
#   'Protein': 2.1,
#   'TotalFat': 5.1,
#   'Carbohydrate': 11.1},
#  'SALAD_DRSNG_MAYO_IMITN_SOYBN_WO_CHOL': {'Calories': 482.0,
#   'Protein': 0.1,
#   'TotalFat': 47.7,
#   'Carbohydrate': 15.8},
#  'SANDWICH_SPRD_W_CHOPD_PICKLE_REG_UNSPEC_OILS': {'Calories': 389.0,
#   'Protein': 0.9,
#   'TotalFat': 34.0,
#   'Carbohydrate': 22.4},
#  'SHORTENING_HOUSEHOLD_PARTIALLY_HYDROG_SOYBN_COTTONSEED': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SOYBN_SALAD_OR_COOKING_PARTIALLY_HYDROGENATED_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_RICE_BRAN': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_WHEAT_GERM': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_PNUT_SALAD_OR_COOKING': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SOYBN_SALAD_OR_COOKING': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_COCNT': {'Calories': 862.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_OLIVE_SALAD_OR_COOKING': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_PALM': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SESAME_SALAD_OR_COOKING': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SUNFLOWER_LINOLEIC_LESS_THAN_60_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'MARGARINE_REG_HARD_SOYBN_HYDR_': {'Calories': 719.0,
#   'Protein': 0.9,
#   'TotalFat': 80.5,
#   'Carbohydrate': 0.9},
#  'SALAD_DRSNG_ITALIAN_DRSNG_COMM_REG': {'Calories': 291.0,
#   'Protein': 0.38,
#   'TotalFat': 28.37,
#   'Carbohydrate': 10.43},
#  'SALAD_DRSNG_FRENCH_DRSNG_COMM_REG': {'Calories': 457.0,
#   'Protein': 0.77,
#   'TotalFat': 44.81,
#   'Carbohydrate': 15.58},
#  'VEG_OIL_SPRD_UNSPEC_OILS_APPROX_37_FAT_W_SALT': {'Calories': 339.0,
#   'Protein': 0.51,
#   'TotalFat': 37.77,
#   'Carbohydrate': 0.66},
#  'SALAD_DRSNG_FRENCH_HOME_RECIPE': {'Calories': 631.0,
#   'Protein': 0.1,
#   'TotalFat': 70.2,
#   'Carbohydrate': 3.4},
#  'SALAD_DRSNG_HOME_RECIPE_CKD': {'Calories': 157.0,
#   'Protein': 4.2,
#   'TotalFat': 9.5,
#   'Carbohydrate': 14.9},
#  'SALAD_DRSNG_HOME_RECIPE_VINEGAR_OIL': {'Calories': 449.0,
#   'Protein': 0.0,
#   'TotalFat': 50.1,
#   'Carbohydrate': 2.5},
#  'SALAD_DRSNG_FRENCH_DRSNG_COMM_REG_WO_SALT': {'Calories': 459.0,
#   'Protein': 0.77,
#   'TotalFat': 44.81,
#   'Carbohydrate': 15.58},
#  'SALAD_DRSNG_FRENCH_DRSNG_RED_FAT_WO_SALT': {'Calories': 233.0,
#   'Protein': 0.58,
#   'TotalFat': 13.46,
#   'Carbohydrate': 29.28},
#  'SALAD_DRSNG_ITALIAN_DRSNG_COMM_REG_WO_SALT': {'Calories': 292.0,
#   'Protein': 0.38,
#   'TotalFat': 28.37,
#   'Carbohydrate': 10.43},
#  'SALAD_DRSNG_ITALIAN_DRSNG_RED_FAT_WO_SALT': {'Calories': 76.0,
#   'Protein': 0.47,
#   'TotalFat': 6.38,
#   'Carbohydrate': 4.57},
#  'SALAD_DRSNG_MAYO_SOYBN_OIL_WO_SALT': {'Calories': 717.0,
#   'Protein': 1.1,
#   'TotalFat': 79.4,
#   'Carbohydrate': 2.7},
#  'SALAD_DRSNG_FRENCH_CTTNSD_OIL_HOME_RECIPE': {'Calories': 631.0,
#   'Protein': 0.1,
#   'TotalFat': 70.2,
#   'Carbohydrate': 3.4},
#  'SALAD_DRSNG_FRENCH_DRSNG_FAT_FREE': {'Calories': 132.0,
#   'Protein': 0.2,
#   'TotalFat': 0.27,
#   'Carbohydrate': 32.14},
#  'OIL_COCOA_BUTTER': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_CTTNSD_SALAD_OR_COOKING': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SUNFLOWER_LINOLEIC_APPROX_65_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SAFFLOWER_SALAD_OR_COOKING_LINOLEIC_OVER_70_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SAFFLOWER_SALAD_OR_COOKING_HI_OLEIC': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'VEGETABLE_OIL_PALM_KERNEL': {'Calories': 862.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_POPPYSEED': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_TOMATOSEED': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_TEASEED': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_GRAPESEED': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_CORN_INDUSTRIAL_RTL_ALLPURP_SALAD_OR_COOKING': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FAT_MUTTON_TALLOW': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_WALNUT': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_ALMOND': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_APRICOT_KERNEL': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SOYBN_LECITHIN': {'Calories': 763.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_HAZELNUT': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_BABASSU': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SHEANUT': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SALAD_DRSNG_BLUE_OR_ROQUEFORT_CHS_DRSNG_COMM_REG': {'Calories': 476.0,
#   'Protein': 1.37,
#   'TotalFat': 51.1,
#   'Carbohydrate': 4.62},
#  'OIL_CUPU_ASSU': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FAT_CHICKEN': {'Calories': 900.0,
#   'Protein': 0.0,
#   'TotalFat': 99.8,
#   'Carbohydrate': 0.0},
#  'OIL_SOYBN_SALAD_OR_COOKING_PARTIALLY_HYDROGENATED_CTTNSD': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_HOUSEHOLD_LARD_VEG_OIL': {'Calories': 900.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SUNFLOWER_LINOLEIC_PARTIALLY_HYDROGENATED_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_BREAD_SOYBN_HYDR_CTTNSD': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_CAKE_MIX_SOYBN_HYDR_CTTNSD_HYDR_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_INDUSTRIAL_LARD_VEG_OIL': {'Calories': 900.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_FRYING_HVY_DUTY_BF_TALLOW_CTTNSD': {'Calories': 900.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_CONFECTIONERY_COCNT_HYDR_OR_PALM_KERNEL_HYDR_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_INDUSTRIAL_SOYBN_HYDR_CTTNSD': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_FRYING_HVY_DUTY_PALM_HYDR_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_HOUSEHOLD_SOYBN_HYDR_PALM': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_FRYING_HVY_DUTY_SOYBN_HYDR_LINOLEIC_LESS_THAN_1_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_CONFECTIONERY_FRACTIONATED_PALM': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_NUTMEG_BUTTER': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_UCUHUBA_BUTTER': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FAT_DUCK': {'Calories': 882.0,
#   'Protein': 0.0,
#   'TotalFat': 99.8,
#   'Carbohydrate': 0.0},
#  'FAT_TURKEY': {'Calories': 900.0,
#   'Protein': 0.0,
#   'TotalFat': 99.8,
#   'Carbohydrate': 0.0},
#  'FAT_GOOSE': {'Calories': 900.0,
#   'Protein': 0.0,
#   'TotalFat': 99.8,
#   'Carbohydrate': 0.0},
#  'OIL_AVOCADO': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_CANOLA': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_MUSTARD': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_SUNFLOWER_HI_OLEIC_70_OVER_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'MARGARINE_LIKE_MARGARINE_BUTTER_BLEND_SOYBN_OIL_BUTTER': {'Calories': 714.0,
#   'Protein': 0.31,
#   'TotalFat': 80.32,
#   'Carbohydrate': 0.77},
#  'SHORTENING_SPL_PURPOSE_FOR_CAKES_FROSTINGS_SOYBN_HYDR_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_SPL_PURPOSE_FOR_BAKING_SOYBN_HYDR_PALM_CTTNSD': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'OIL_OAT': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FISH_OIL_COD_LIVER': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FISH_OIL_HERRING': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FISH_OIL_MENHADEN': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FISH_OIL_MENHADEN_FULLY_HYDR': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FISH_OIL_SALMON': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'FISH_OIL_SARDINE': {'Calories': 902.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'SHORTENING_MULTIPURPOSE_SOYBN_HYDR_PALM_HYDR_': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 100.0,
#   'Carbohydrate': 0.0},
#  'MARGARINE_LIKE_VEG_OIL_BUTTER_SPRD_TUB_W_SALT': {'Calories': 362.0,
#   'Protein': 1.0,
#   'TotalFat': 40.0,
#   'Carbohydrate': 1.0},
#  'BUTTER_LT_STK_W_SALT': {'Calories': 509.0,
#   'Protein': 3.3,
#   'TotalFat': 55.1,
#   'Carbohydrate': 0.0},
#  'BUTTER_LT_STK_WO_SALT': {'Calories': 499.0,
#   'Protein': 3.3,
#   'TotalFat': 55.1,
#   'Carbohydrate': 0.0},
#  'MEAT_DRIPPINGS_LARD_BF_TALLOW_MUTTON_TALLOW_': {'Calories': 889.0,
#   'Protein': 0.0,
#   'TotalFat': 98.59,
#   'Carbohydrate': 0.0},
#  'ANIMAL_FAT_BACON_GREASE': {'Calories': 897.0,
#   'Protein': 0.0,
#   'TotalFat': 99.5,
#   'Carbohydrate': 0.0},
#  'MARGARINE_REG_80_FAT_COMP_STK_W_SALT': {'Calories': 717.0,
#   'Protein': 0.16,
#   'TotalFat': 80.71,
#   'Carbohydrate': 0.7},
#  'MARGARINE_REG_80_FAT_COMP_TUB_W_SALT': {'Calories': 713.0,
#   'Protein': 0.22,
#   'TotalFat': 80.17,
#   'Carbohydrate': 0.75},
#  'MARGARINE_LIKE_VEG_OIL_SPRD_60_FAT_STK_W_SALT': {'Calories': 537.0,
#   'Protein': 0.12,
#   'TotalFat': 60.39,
#   'Carbohydrate': 0.69},
#  'MARGARINE_LIKE_VEG_OIL_SPRD_60_FAT_TUB_W_SALT': {'Calories': 533.0,
#   'Protein': 0.17,
#   'TotalFat': 59.81,
#   'Carbohydrate': 0.86},
#  'MARGARINE_LIKE_VEG_OIL_SPRD_60_FAT_STICK_TUB_BOTTLE_W_SALT': {'Calories': 526.0,
#   'Protein': 0.6,
#   'TotalFat': 59.17,
#   'Carbohydrate': 0.0},
#  'SHORTENING_VEG_HOUSEHOLD_COMP': {'Calories': 884.0,
#   'Protein': 0.0,
#   'TotalFat': 99.97,
#   'Carbohydrate': 0.0},
#  'MARGARINE_REG_80_FAT_COMP_STK_WO_SALT': {'Calories': 717.0,
#   'Protein': 0.16,
#   'TotalFat': 80.71,
#   'Carbohydrate': 0.7},
#  'MARGARINE_REG_80_FAT_COMP_TUB_WO_SALT': {'Calories': 713.0,
#   'Protein': 0.22,
#   'TotalFat': 80.17,
#   'Carbohydrate': 0.75},
#  'VEG_OIL_SPRD_60_FAT_STICK_TUB_BOTTLE_WO_SALT': {'Calories': 533.0,
#   'Protein': 0.17,
#   'TotalFat': 59.81,
#   'Carbohydrate': 0.86},
#  'MARGARINE_LIKE_VEG_OIL_SPRD_FAT_FREE_LIQ_W_SALT': {'Calories': 43.0,
#   'Protein': 1.5,
#   'TotalFat': 3.0,
#   'Carbohydrate': 2.5},
#  'MARGARINE_LIKE_SPRD_W_YOGURT_70_FAT_STK_W_SALT': {'Calories': 630.0,
#   'Protein': 0.3,
#   'TotalFat': 70.0,
#   'Carbohydrate': 0.5},
#  'MARGARINE_LIKE_SPRD_W_YOGURT_APPROX_40_FAT_TUB_W_SALT': {'Calories': 330.0,
#   'Protein': 2.0,
#   'TotalFat': 35.0,
#   'Carbohydrate': 2.0},
#  'MARGARINE_80_FAT_STK_INCL_REG_HYDR_CORN_SOYBN_OILS': {'Calories': 717.0,
#   'Protein': 0.16,
#   'TotalFat': 80.71,
#   'Carbohydrate': 0.7},
#  'MARGARINE_VEG_OIL_SPRD_70_FAT_SOYBN_PART_HYDR_SOYBN_STK': {'Calories': 628.0,
#   'Protein': 0.26,
#   'TotalFat': 70.22,
#   'Carbohydrate': 1.53},
#  'MARGARINE_SPRD_APPROX_48_FAT_TUB': {'Calories': 424.0,
#   'Protein': 0.2,
#   'TotalFat': 47.53,
#   'Carbohydrate': 0.86},
# ...
#   'Protein': 1.61,
#   'TotalFat': 3.63,
#   'Carbohydrate': 9.68},
#  'SOUP_CHICK_CND_CHUNKY_RTS': {'Calories': 71.0,
#   'Protein': 5.06,
#   'TotalFat': 2.64,
#   'Carbohydrate': 6.88},
#  'SOUP_CRM_OF_CHICK_CND_COND': {'Calories': 90.0,
#   'Protein': 2.38,
#   'TotalFat': 5.77,
#   'Carbohydrate': 7.16},
#  'SOUP_CHICK_GUMBO_CND_COND': {'Calories': 45.0,
#   'Protein': 2.1,
#   'TotalFat': 1.14,
#   'Carbohydrate': 6.67},
#  'SOUP_CHUNKY_CHICK_NOODLE_CND_RTS': {'Calories': 39.0,
#   'Protein': 3.09,
#   'TotalFat': 1.16,
#   'Carbohydrate': 4.0},
#  'SOUP_CHICK_NOODLE_CND_COND': {'Calories': 52.0,
#   'Protein': 2.59,
#   'TotalFat': 1.94,
#   'Carbohydrate': 6.03},
#  'SOUP_CHICK_RICE_CND_CHUNKY_RTS': {'Calories': 53.0,
#   'Protein': 5.11,
#   'TotalFat': 1.33,
#   'Carbohydrate': 5.41},
#  'SOUP_CHICK_W_RICE_CND_COND': {'Calories': 49.0,
#   'Protein': 2.89,
#   'TotalFat': 1.56,
#   'Carbohydrate': 5.84},
#  'SOUP_CHICK_VEG_CHUNKY_CND_RTS': {'Calories': 69.0,
#   'Protein': 5.13,
#   'TotalFat': 2.01,
#   'Carbohydrate': 7.87},
#  'SOUP_CHICK_VEG_CND_COND': {'Calories': 61.0,
#   'Protein': 2.94,
#   'TotalFat': 2.32,
#   'Carbohydrate': 7.01},
#  'SOUP_CHILI_BF_CND_COND': {'Calories': 117.0,
#   'Protein': 5.09,
#   'TotalFat': 2.53,
#   'Carbohydrate': 18.86},
#  'SOUP_CLAM_CHOWDER_MANHATTAN_STYLE_CND_CHUNKY_RTS': {'Calories': 56.0,
#   'Protein': 3.02,
#   'TotalFat': 1.41,
#   'Carbohydrate': 7.84},
#  'SOUP_CLAM_CHOWDER_MANHATTAN_CND_COND': {'Calories': 61.0,
#   'Protein': 1.74,
#   'TotalFat': 1.76,
#   'Carbohydrate': 9.74},
#  'CAMPBELL_SOUP_COMPANY_HEALTHY_REQUEST_CHICK_W_RICE_COND': {'Calories': 56.0,
#   'Protein': 1.59,
#   'TotalFat': 1.19,
#   'Carbohydrate': 7.19},
#  'SOUP_CLAM_CHOWDER_NEW_ENGLAND_CND_COND': {'Calories': 72.0,
#   'Protein': 3.17,
#   'TotalFat': 2.06,
#   'Carbohydrate': 10.32},
#  'SOUP_BF_BROTH_BOUILLON_CONSOMME_CND_COND': {'Calories': 13.0,
#   'Protein': 2.52,
#   'TotalFat': 0.0,
#   'Carbohydrate': 0.84},
#  'SOUP_CRAB_CND_RTS': {'Calories': 31.0,
#   'Protein': 2.25,
#   'TotalFat': 0.62,
#   'Carbohydrate': 4.22},
#  'SOUP_ESCAROLE_CND_RTS': {'Calories': 11.0,
#   'Protein': 0.62,
#   'TotalFat': 0.73,
#   'Carbohydrate': 0.72},
#  'SOUP_GAZPACHO_CND_RTS': {'Calories': 19.0,
#   'Protein': 2.9,
#   'TotalFat': 0.1,
#   'Carbohydrate': 1.8},
#  'SOUP_LENTIL_W_HAM_CND_RTS': {'Calories': 56.0,
#   'Protein': 3.74,
#   'TotalFat': 1.12,
#   'Carbohydrate': 8.16},
#  'CAMPBELL_COMPANY_CAMPBELL_S_RED_WHITE_CHEDDAR_CHS_SOUP_COND': {'Calories': 81.0,
#   'Protein': 1.61,
#   'TotalFat': 4.03,
#   'Carbohydrate': 8.87},
#  'SOUP_MINESTRONE_CND_CHUNKY_RTS': {'Calories': 53.0,
#   'Protein': 2.13,
#   'TotalFat': 1.17,
#   'Carbohydrate': 8.64},
#  'SOUP_MINESTRONE_CND_COND': {'Calories': 68.0,
#   'Protein': 3.48,
#   'TotalFat': 2.05,
#   'Carbohydrate': 9.17},
#  'CAMPBELL_CAMPBELL_S_RED_WHITE_CHICK_DUMPLINGS_SOUP_COND': {'Calories': 56.0,
#   'Protein': 2.38,
#   'TotalFat': 1.98,
#   'Carbohydrate': 7.94},
#  'SOUP_MUSHROOM_BARLEY_CND_COND': {'Calories': 61.0,
#   'Protein': 1.5,
#   'TotalFat': 1.8,
#   'Carbohydrate': 9.6},
#  'SOUP_CRM_OF_MUSHROOM_CND_COND': {'Calories': 85.0,
#   'Protein': 1.61,
#   'TotalFat': 5.89,
#   'Carbohydrate': 6.72},
#  'SOUP_MUSHROOM_W_BF_STOCK_CND_COND': {'Calories': 68.0,
#   'Protein': 2.51,
#   'TotalFat': 3.21,
#   'Carbohydrate': 7.41},
#  'SOUP_ONION_CND_COND': {'Calories': 46.0,
#   'Protein': 3.06,
#   'TotalFat': 1.42,
#   'Carbohydrate': 6.68},
#  'SOUP_CRM_OF_ONION_CND_COND': {'Calories': 88.0,
#   'Protein': 2.2,
#   'TotalFat': 4.2,
#   'Carbohydrate': 10.4},
#  'CAMPBELL_S_RED_WHITE_CHICK_STARS_SOUP_COND': {'Calories': 56.0,
#   'Protein': 2.38,
#   'TotalFat': 1.59,
#   'Carbohydrate': 8.73},
#  'SOUP_OYSTER_STEW_CND_COND': {'Calories': 48.0,
#   'Protein': 1.72,
#   'TotalFat': 3.13,
#   'Carbohydrate': 3.32},
#  'SOUP_PEA_GRN_CND_COND': {'Calories': 125.0,
#   'Protein': 6.54,
#   'TotalFat': 2.23,
#   'Carbohydrate': 20.18},
#  'SOUP_PEA_SPLIT_W_HAM_CND_CHUNKY_RTS': {'Calories': 77.0,
#   'Protein': 4.62,
#   'TotalFat': 1.66,
#   'Carbohydrate': 11.17},
#  'SOUP_PEA_SPLIT_W_HAM_CND_COND': {'Calories': 141.0,
#   'Protein': 7.68,
#   'TotalFat': 3.28,
#   'Carbohydrate': 20.81},
#  'SOUP_PEPPERPOT_CND_COND': {'Calories': 84.0,
#   'Protein': 5.19,
#   'TotalFat': 3.78,
#   'Carbohydrate': 7.66},
#  'SOUP_CRM_OF_POTATO_CND_COND': {'Calories': 59.0,
#   'Protein': 1.39,
#   'TotalFat': 1.88,
#   'Carbohydrate': 9.14},
#  'CAMPBELL_S_RED_WHITE_CHICK_ALPHABET_SOUP_COND': {'Calories': 56.0,
#   'Protein': 2.38,
#   'TotalFat': 1.19,
#   'Carbohydrate': 9.52},
#  'SOUP_SCOTCH_BROTH_CND_COND': {'Calories': 66.0,
#   'Protein': 4.05,
#   'TotalFat': 2.14,
#   'Carbohydrate': 7.73},
#  'SOUP_CRM_OF_SHRIMP_CND_COND': {'Calories': 72.0,
#   'Protein': 2.22,
#   'TotalFat': 4.14,
#   'Carbohydrate': 6.53},
#  'CAMPBELL_SOUP_COMPANY_CAMPBELL_S_RED_WHITE_CHICK_BROTH_COND': {'Calories': 16.0,
#   'Protein': 0.81,
#   'TotalFat': 0.81,
#   'Carbohydrate': 0.81},
#  'CAMPBELL_SOUP_CAMPBELL_S_RED_WHITE_CHICK_GUMBO_SOUP_COND': {'Calories': 48.0,
#   'Protein': 1.59,
#   'TotalFat': 0.79,
#   'Carbohydrate': 7.94},
#  'SOUP_STOCKPOT_CND_COND': {'Calories': 78.0,
#   'Protein': 3.79,
#   'TotalFat': 3.04,
#   'Carbohydrate': 8.95},
#  'SOUP_TOMATO_BF_W_NOODLE_CND_COND': {'Calories': 112.0,
#   'Protein': 3.55,
#   'TotalFat': 3.42,
#   'Carbohydrate': 16.87},
#  'CAMPBELL_S_RED_WHITE_CHICK_NOODLE_SOUP_COND': {'Calories': 48.0,
#   'Protein': 2.38,
#   'TotalFat': 1.59,
#   'Carbohydrate': 6.35},
#  'SOUP_TOMATO_RICE_CND_COND': {'Calories': 93.0,
#   'Protein': 1.64,
#   'TotalFat': 2.12,
#   'Carbohydrate': 17.08},
#  'SOUP_TURKEY_CHUNKY_CND_RTS': {'Calories': 57.0,
#   'Protein': 4.33,
#   'TotalFat': 1.87,
#   'Carbohydrate': 5.96},
#  'SOUP_TURKEY_NOODLE_CND_COND': {'Calories': 55.0,
#   'Protein': 3.11,
#   'TotalFat': 1.59,
#   'Carbohydrate': 6.88},
#  'SOUP_TURKEY_VEG_CND_COND': {'Calories': 60.0,
#   'Protein': 2.52,
#   'TotalFat': 2.47,
#   'Carbohydrate': 7.05},
#  'SOUP_CHUNKY_VEG_CND_RTS': {'Calories': 51.0,
#   'Protein': 1.46,
#   'TotalFat': 1.54,
#   'Carbohydrate': 7.92},
#  'SOUP_VEGETARIAN_VEG_CND_COND': {'Calories': 59.0,
#   'Protein': 1.72,
#   'TotalFat': 1.58,
#   'Carbohydrate': 9.78},
#  'SOUP_CHUNKY_BF_CND_RTS': {'Calories': 66.0,
#   'Protein': 3.97,
#   'TotalFat': 1.11,
#   'Carbohydrate': 10.08},
#  'SOUP_VEG_BF_CND_COND': {'Calories': 63.0,
#   'Protein': 4.45,
#   'TotalFat': 1.51,
#   'Carbohydrate': 8.11},
#  'SOUP_VEG_W_BF_BROTH_CND_COND': {'Calories': 66.0,
#   'Protein': 2.42,
#   'TotalFat': 1.56,
#   'Carbohydrate': 10.7},
#  'SOUP_BF_BROTH_OR_BOUILLON_PDR_DRY': {'Calories': 213.0,
#   'Protein': 15.97,
#   'TotalFat': 8.89,
#   'Carbohydrate': 17.4},
#  'SOUP_BEEF_BROTH_CUBED_DRY': {'Calories': 170.0,
#   'Protein': 17.3,
#   'TotalFat': 4.0,
#   'Carbohydrate': 16.1},
#  'SOUP_BF_NOODLE_DRY_MIX': {'Calories': 324.0,
#   'Protein': 17.93,
#   'TotalFat': 6.39,
#   'Carbohydrate': 48.64},
#  'SOUP_CHICK_BROTH_OR_BOUILLON_DRY': {'Calories': 267.0,
#   'Protein': 16.66,
#   'TotalFat': 13.88,
#   'Carbohydrate': 18.01},
#  'SOUP_CHICK_BROTH_CUBES_DRY': {'Calories': 198.0,
#   'Protein': 14.6,
#   'TotalFat': 4.7,
#   'Carbohydrate': 23.5},
#  'CAMPBELL_S_RED_WHITE_CHICK_NOODLEO_S_SOUP_COND': {'Calories': 71.0,
#   'Protein': 2.38,
#   'TotalFat': 1.98,
#   'Carbohydrate': 11.9},
#  'CAMPBELL_COMPANY_CAMPBELL_S_RED_WHITE_CHICK_VEG_SOUP_COND': {'Calories': 63.0,
#   'Protein': 2.38,
#   'TotalFat': 0.79,
#   'Carbohydrate': 11.9},
#  'CAMPBELL_SOUP_COMPANY_CAMPBELL_S_RED_WHITE_BF_BROTH_COND': {'Calories': 12.0,
#   'Protein': 2.42,
#   'TotalFat': 0.0,
#   'Carbohydrate': 0.81},
#  'SOUP_ONION_DRY_MIX': {'Calories': 293.0,
#   'Protein': 7.48,
#   'TotalFat': 0.34,
#   'Carbohydrate': 65.07},
#  'CAMPBELL_SOUP_COMPANY_CAMPBELLS_RED_WHITE_BF_CONSOMME_COND': {'Calories': 16.0,
#   'Protein': 3.23,
#   'TotalFat': 0.0,
#   'Carbohydrate': 0.81},
#  'SOUP_TOMATO_VEG_DRY_MIX': {'Calories': 325.0,
#   'Protein': 11.73,
#   'TotalFat': 5.09,
#   'Carbohydrate': 59.9},
#  'SOUP_CRM_OF_VEG_DRY_PDR': {'Calories': 446.0,
#   'Protein': 8.0,
#   'TotalFat': 24.1,
#   'Carbohydrate': 52.1},
#  'SAUCE_CHS_DRY_PDR': {'Calories': 448.0,
#   'Protein': 22.69,
#   'TotalFat': 25.44,
#   'Carbohydrate': 33.66},
#  'CAMPBELL_S_RED_WHITE_BATMAN_FUN_SHAPES_SOUP_COND': {'Calories': 56.0,
#   'Protein': 2.38,
#   'TotalFat': 1.59,
#   'Carbohydrate': 7.94},
#  'SAUCE_TERIYAKI_RTS': {'Calories': 89.0,
#   'Protein': 5.93,
#   'TotalFat': 0.02,
#   'Carbohydrate': 15.56},
#  'GRAVY_AU_JUS_CANNED': {'Calories': 16.0,
#   'Protein': 1.2,
#   'TotalFat': 0.2,
#   'Carbohydrate': 2.5},
#  'GRAVY_AU_JUS_DRY': {'Calories': 313.0,
#   'Protein': 9.2,
#   'TotalFat': 9.63,
#   'Carbohydrate': 47.49},
#  'GRAVY_BF_CND_RTS': {'Calories': 53.0,
#   'Protein': 3.75,
#   'TotalFat': 2.36,
#   'Carbohydrate': 4.81},
#  'CAMPBELL_SOUP_CAMPBELL_S_RED_WHITE_BEAN_W_BACON_SOUP_COND': {'Calories': 125.0,
#   'Protein': 6.25,
#   'TotalFat': 2.34,
#   'Carbohydrate': 19.53},
#  'GRAVY_BROWN_DRY': {'Calories': 367.0,
#   'Protein': 10.74,
#   'TotalFat': 9.61,
#   'Carbohydrate': 59.38},
#  'GRAVY_CHICK_CND_RTS': {'Calories': 79.0,
#   'Protein': 1.93,
#   'TotalFat': 5.71,
#   'Carbohydrate': 5.42},
#  'GRAVY_CHICKEN_DRY': {'Calories': 381.0,
#   'Protein': 11.27,
#   'TotalFat': 9.73,
#   'Carbohydrate': 62.09},
#  'GRAVY_MUSHROOM_CANNED': {'Calories': 50.0,
#   'Protein': 1.26,
#   'TotalFat': 2.71,
#   'Carbohydrate': 5.47},
#  'GRAVY_MUSHROOM_DRY_PDR': {'Calories': 328.0,
#   'Protein': 10.0,
#   'TotalFat': 4.0,
#   'Carbohydrate': 64.66},
#  'GRAVY_ONION_DRY_MIX': {'Calories': 322.0,
#   'Protein': 9.0,
#   'TotalFat': 3.0,
#   'Carbohydrate': 67.64},
#  'GRAVY_PORK_DRY_PDR': {'Calories': 367.0,
#   'Protein': 8.78,
#   'TotalFat': 8.63,
#   'Carbohydrate': 63.57},
#  'GRAVY_TURKEY_CND_RTS': {'Calories': 51.0,
#   'Protein': 2.6,
#   'TotalFat': 2.1,
#   'Carbohydrate': 5.1},
#  'GRAVY_TURKEY_DRY': {'Calories': 367.0,
#   'Protein': 10.42,
#   'TotalFat': 7.19,
#   'Carbohydrate': 65.12},
#  'GRAVY_UNSPEC_TYPE_DRY': {'Calories': 344.0,
#   'Protein': 13.0,
#   'TotalFat': 8.0,
#   'Carbohydrate': 58.0},
#  'SOUP_CHICK_NOODLE_DRY_MIX': {'Calories': 377.0,
#   'Protein': 15.42,
#   'TotalFat': 6.51,
#   'Carbohydrate': 62.32},
#  'SAUCE_MOLE_POBLANO_DRY_MIX_SINGLE_BRAND': {'Calories': 571.0,
#   'Protein': 7.48,
#   'TotalFat': 41.58,
#   'Carbohydrate': 41.7},
#  'SAUCE_SOFRITO_PREP_FROM_RECIPE': {'Calories': 237.0,
#   'Protein': 12.8,
#   'TotalFat': 18.2,
#   'Carbohydrate': 5.46},
#  'USDA_COMMODITY_SPAGHETTI_SAU_MEATLESS_CND': {'Calories': 48.0,
#   'Protein': 1.2,
#   'TotalFat': 0.9,
#   'Carbohydrate': 8.7},
#  'CAMPBELL_COMPANY_CAMPBELL_S_RED_WHITE_BF_NOODLE_SOUP_COND': {'Calories': 56.0,
#   'Protein': 3.17,
#   'TotalFat': 1.59,
#   'Carbohydrate': 6.35},
#  'CAMPBELL_CAMPBELL_S_RED_WHITE_BF_W_VEG_BARLEY_SOUP_COND': {'Calories': 71.0,
#   'Protein': 3.97,
#   'TotalFat': 1.19,
#   'Carbohydrate': 11.9},
#  'SOUP_BF_MUSHROOM_CND_COND': {'Calories': 61.0,
#   'Protein': 4.6,
#   'TotalFat': 2.4,
#   'Carbohydrate': 5.2},
#  'SOUP_CHICK_MUSHROOM_CND_COND': {'Calories': 109.0,
#   'Protein': 3.5,
#   'TotalFat': 7.3,
#   'Carbohydrate': 7.6},
#  'SAUCE_BARBECUE': {'Calories': 150.0,
#   'Protein': 0.0,
#   'TotalFat': 0.29,
#   'Carbohydrate': 36.25},
#  'SAUCE_PLUM_READY_TO_SERVE': {'Calories': 184.0,
#   'Protein': 0.89,
#   'TotalFat': 1.04,
#   'Carbohydrate': 42.81},
#  'SAUCE_PIZZA_CND_RTS': {'Calories': 54.0,
#   'Protein': 2.18,
#   'TotalFat': 1.15,
#   'Carbohydrate': 8.67},
#  'SOUP_TOMATO_BISQUE_CND_COND': {'Calories': 96.0,
#   'Protein': 1.76,
#   'TotalFat': 1.95,
#   'Carbohydrate': 18.47},
#  'SOUP_TOMATO_CND_COND': {'Calories': 66.0,
#   'Protein': 1.46,
#   'TotalFat': 0.44,
#   'Carbohydrate': 15.22},
#  'SAUCE_SALSA_RTS': {'Calories': 27.0,
#   'Protein': 1.54,
#   'TotalFat': 0.16,
#   'Carbohydrate': 6.26},
#  'SAUCE_HOMEMADE_WHITE_THIN': {'Calories': 105.0,
#   'Protein': 3.77,
#   'TotalFat': 6.73,
#   'Carbohydrate': 7.4},
#  'SAUCE_HOMEMADE_WHITE_MED': {'Calories': 147.0,
#   'Protein': 3.84,
#   'TotalFat': 10.63,
#   'Carbohydrate': 9.17},
#  'SAUCE_HOMEMADE_WHITE_THICK': {'Calories': 186.0,
#   'Protein': 3.99,
#   'TotalFat': 13.83,
#   'Carbohydrate': 11.61},
#  'SAUCE_RTS_PEPPER_OR_HOT': {'Calories': 11.0,
#   'Protein': 0.51,
#   'TotalFat': 0.37,
#   'Carbohydrate': 1.75},
#  'SAUCE_RTS_PEPPER_TABASCO': {'Calories': 12.0,
#   'Protein': 1.29,
#   'TotalFat': 0.76,
#   'Carbohydrate': 0.8},
#  'SOUP_STOCK_BEEF_HOME_PREPARED': {'Calories': 13.0,
#   'Protein': 1.97,
#   'TotalFat': 0.09,
#   'Carbohydrate': 1.2},
#  'SOUP_STOCK_CHICK_HOME_PREPARED': {'Calories': 36.0,
#   'Protein': 2.52,
#   'TotalFat': 1.2,
#   'Carbohydrate': 3.53},
#  'SOUP_STOCK_FISH_HOME_PREPARED': {'Calories': 17.0,
#   'Protein': 2.26,
#   'TotalFat': 0.81,
#   'Carbohydrate': 0.0},
#  'SAUCE_HOISIN_RTS': {'Calories': 220.0,
#   'Protein': 3.31,
#   'TotalFat': 3.39,
#   'Carbohydrate': 44.08},
#  'SAUCE_OYSTER_RTS': {'Calories': 51.0,
#   'Protein': 1.35,
#   'TotalFat': 0.25,
#   'Carbohydrate': 10.92},
#  'SOUP_MINESTRONE_CND_RED_NA_RTS': {'Calories': 50.0,
#   'Protein': 2.0,
#   'TotalFat': 0.8,
#   'Carbohydrate': 9.0},
#  'USDA_COMMODITY_SALSA': {'Calories': 36.0,
#   'Protein': 1.5,
#   'TotalFat': 0.2,
#   'Carbohydrate': 7.0},
#  'SAUCE_FISH_READY_TO_SERVE': {'Calories': 35.0,
#   'Protein': 5.06,
#   'TotalFat': 0.01,
#   'Carbohydrate': 3.64},
#  'SOUP_SHARK_FIN_REST_PREP': {'Calories': 46.0,
#   'Protein': 3.2,
#   'TotalFat': 2.0,
#   'Carbohydrate': 3.8},
#  'SOUP_CRM_OF_MUSHROOM_CND_COND_RED_NA': {'Calories': 52.0,
#   'Protein': 1.21,
#   'TotalFat': 1.69,
#   'Carbohydrate': 8.1},
#  'SOUP_CHICK_OR_BEEF_BROTH_CND_LESS_REDUCED_NA': {'Calories': 7.0,
#   'Protein': 1.36,
#   'TotalFat': 0.0,
#   'Carbohydrate': 0.38},
#  'SAUCE_TERIYAKI_RTS_RED_NA': {'Calories': 89.0,
#   'Protein': 5.93,
#   'TotalFat': 0.02,
#   'Carbohydrate': 15.58},
#  'SOUP_BEAN_HAM_CND_RED_NA_PREP_W_H2O_OR_RTS': {'Calories': 74.0,
#   'Protein': 4.19,
#   'TotalFat': 1.03,
#   'Carbohydrate': 13.66},
#  'SPLIT_PEA_SOUP_CND_RED_NA_PREP_W_H2O_OR_READY_TO_SERVE': {'Calories': 71.0,
#   'Protein': 3.85,
#   'TotalFat': 0.92,
#   'Carbohydrate': 11.83},
#  'SPLIT_PEA_W_HAM_SOUP_CND_RED_NA_PREP_W_H2O_OR_RTS': {'Calories': 68.0,
#   'Protein': 4.0,
#   'TotalFat': 0.7,
#   'Carbohydrate': 11.4},
#  'SOUP_CHICK_BROTH_CND_RTS': {'Calories': 5.0,
#   'Protein': 0.43,
#   'TotalFat': 0.21,
#   'Carbohydrate': 0.43},
#  'CAMPBELL_SOUP_COMPANY_HEALTHY_REQUEST_CRM_OF_CHICK_SOUP_COND': {'Calories': 65.0,
#   'Protein': 1.61,
#   'TotalFat': 2.02,
#   'Carbohydrate': 9.68},
#  'SOUP_CRM_OF_ASPARAGUS_CND_PREP_W_EQ_VOLUME_MILK': {'Calories': 65.0,
#   'Protein': 2.55,
#   'TotalFat': 3.3,
#   'Carbohydrate': 6.61},
#  'SOUP_CHICK_VEG_W_POTATO_CHS_CHUNKY_RTS': {'Calories': 65.0,
#   'Protein': 1.16,
#   'TotalFat': 4.46,
#   'Carbohydrate': 5.2},
#  'CAMPBELL_S_RED_WHITE_98_FAT_FREE_CRM_OF_BROCCOLI_SOUP_COND': {'Calories': 56.0,
#   'Protein': 1.61,
#   'TotalFat': 1.61,
#   'Carbohydrate': 8.06},
#  'SOUP_CRM_OF_CELERY_CND_PREP_W_EQ_VOLUME_MILK': {'Calories': 66.0,
#   'Protein': 2.29,
#   'TotalFat': 3.91,
#   'Carbohydrate': 5.86},
#  'SOUP_CHS_CND_PREP_W_EQ_VOLUME_MILK': {'Calories': 92.0,
#   'Protein': 3.77,
#   'TotalFat': 5.8,
#   'Carbohydrate': 6.47},
#  'CAMPBELL_SOUP_COMPANY_RED_WHITE_25_LESS_NA_CHIC_NOODL_COND': {'Calories': 48.0,
#   'Protein': 2.38,
#   'TotalFat': 1.59,
#   'Carbohydrate': 6.35},
#  'CAMPBELL_SOUP_COMPANY_RED_WHITE_25_LESS_NA_TOMATO_SOUP_COND': {'Calories': 73.0,
#   'Protein': 1.61,
#   'TotalFat': 0.0,
#   'Carbohydrate': 16.13},
#  'CAMPBELL_SOUP_COMPANY_RED_WHITE_25_LESS_NA_CRM_OF_MSHR_COND': {'Calories': 89.0,
#   'Protein': 1.61,
#   'TotalFat': 6.45,
#   'Carbohydrate': 6.45},
#  'CAMPBELL_SOUP_COMPANY_RED_WHITE_98_FAT_FR_BRCCLI_CHS_COND': {'Calories': 56.0,
#   'Protein': 1.61,
#   'TotalFat': 1.21,
#   'Carbohydrate': 9.68},
#  'SOUP_CRM_OF_CHICK_CND_PREP_W_EQ_VOLUME_MILK': {'Calories': 77.0,
#   'Protein': 3.01,
#   'TotalFat': 4.62,
#   'Carbohydrate': 6.04},
#  'SOUP_VEG_CND_LO_NA_COND': {'Calories': 65.0,
#   'Protein': 2.2,
#   'TotalFat': 0.9,
#   'Carbohydrate': 12.11},
#  'CAMPBELL_S_RED_WHITE_98_FAT_FREE_CRM_OF_CELERY_SOUP_COND': {'Calories': 56.0,
#   'Protein': 0.81,
#   'TotalFat': 2.42,
#   'Carbohydrate': 7.26},
#  'CAMPBELL_S_RED_WHITE_98_FAT_FREE_CRM_OF_CHICK_SOUP_COND': {'Calories': 56.0,
#   'Protein': 1.61,
#   'TotalFat': 2.02,
#   'Carbohydrate': 8.06},
#  'CAMPBELL_PREGO_PASTA_CHNKY_GRD_MSHRM_GRN_PPPR_ITAL_SAU_RTS': {'Calories': 69.0,
#   'Protein': 1.54,
#   'TotalFat': 2.31,
#   'Carbohydrate': 10.0},
#  'CAMPBELL_PREGO_PASTA_CHUNKY_GARDEN_MUSHROOM_ITALIAN_SAU_RTS': {'Calories': 69.0,
#   'Protein': 1.54,
#   'TotalFat': 2.31,
#   'Carbohydrate': 10.0},
#  ...}

# %%
from pulp import *

def generate_meal_plan(food_nutrients, nutrient_ranges, num_meals = 3, num_snacks = 2):
    # Create a list of food items
    food_items = list(food_nutrients.keys())
    # Create the LP problem
    problem = LpProblem("MealPlan", LpMinimize)

    # Create a dictionary of food variables
    food_vars = LpVariable.dicts("Food", food_items, lowBound=0, cat='Integer')

    # Add nutrient constraints
    for nutrient in nutrient_ranges:
        problem += lpSum([food_nutrients[food][nutrient] * food_vars[food] for food in food_items]) >= nutrient_ranges[nutrient][0], f"Min_{nutrient}"
        problem += lpSum([food_nutrients[food][nutrient] * food_vars[food] for food in food_items]) <= nutrient_ranges[nutrient][1], f"Max_{nutrient}"

    # Add the meal constraints
    problem += lpSum([food_vars[food] for food in food_items]) == num_meals, "Num_Meals"

    # Add the snack constraints
    problem += lpSum([food_vars[food] for food in food_items]) == num_snacks, "Num_Snacks"

    # Solve the problem
    problem.solve()

    # Print the status of the solution
    print("Status:", LpStatus[problem.status])

    # Print the recommended meal plan
    print("Recommended Meal Plan:")
    for food in food_items:
        if food_vars[food].value() > 0:
            print(food, ":", food_vars[food].value())

# %%
# It seems that solver has a problem in linux I checked my implementation many times
generate_meal_plan(food_nutrient, nutrient_ranges)

# %%
# Unfortunately solver has a problem with linux I checked the code extensively
