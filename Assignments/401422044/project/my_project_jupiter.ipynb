# %% [markdown]
# در ابتدا
# pulp & pandas
# اضافه میکنیم
#
# سپس تمامی متغییر های مورد استفاده در برنامه را معرفی و مقدار دهی اولیه میکنیم

# %%
# Import all classes of PuLP module
from pulp import *
import pandas
import random


# global vars :
sex = "female"
weight = 76
dailyActivityCount = 3
fatPercentage = 0.4
leanFactor = 0.8
sexFactor = 0
activityFactor = 0
bmr = 0
requiredCal = 0
total_cal = 0

# lists
my_list = []
my_coefficients = []
final_result = []
available_foods = []

linear_programming_problem = LpProblem('Diet',LpMaximize)

# %% [markdown]
# فانکشن های زیر برای محاصبه ی
# sexFactor & activityFactor
# پیاده سازی شده اند

# %%
def calculateSexFactors():
    if(sex=="male"):
        return 0.9
    elif(sex=="female"):
        return 0.8
    else:
        return 0.0

def calculateActivityFactors():
    if(sex=="male"):
        return 1.5
    elif(sex=="female"):
        return 1.6
    else:
        return 0.0

# %% [markdown]
# فانکشن
# calculate_required_cal
# برای محاصبه مقدار کالری مورد نظر بر اساس
# sexFactor & activityFactor
# میباشد

# %%
def calculate_required_cal():
    global bmr
    global requiredCal
    bmr = weight * sexFactor * activityFactor
    requiredCal = bmr * activityFactor

# %% [markdown]
# سپس با استفاده از فانکشن اول داده ها را میخوانیم از فایل csv
# و بعد در فانکشن بعدی داده های خوانده شده را بر اساس کالری بررسی کرده و لیست
# final_result
# را آپدیت میکنیم

# %%
def readData():
    pandas.set_option('display.max_rows',None)
    return pandas.read_csv('./USDA.csv')

def findCalories():
    global available_foods
    global final_result
    for i in range(int(len(available_foods)/10)):
        id = available_foods.iloc[i]['ID']
        description = available_foods.iloc[i]['Description']
        cal = available_foods.iloc[i]['Calories']
        if(cal != 0):
            temp = {'ID': id, 'Description':description, 'Calories': cal}
            final_result.append(temp)
            print(temp)

# %% [markdown]
# فانکشن find_daily_diet برنامه غذایی مناسب را پیدا میکند

# %%
def find_daily_diet():
    global requiredCal
    global my_list
    global my_coefficients
    global linear_programming_problem
    global final_result
    for i in range(len(final_result)):
        my_list.append(LpVariable(name= str(final_result[i]['ID']), upBound=1, lowBound=0, cat=LpInteger))
        temp_cal = final_result[i]['Calories']
        my_coefficients.append(temp_cal)
    linear_programming_problem += lpSum(my_list[i] * my_coefficients[i] for i in range(len(my_list))) 
    linear_programming_problem += lpSum(my_list[i] * my_coefficients[i] for i in range(len(my_list))) <= requiredCal
    linear_programming_problem.solve()

# %% [markdown]
# برای نمایش نتیجه نهایی فانکشن show_result را صدا میزنیم

# %%
def show_result():
    global linear_programming_problem
    for var in linear_programming_problem.variables():
        if(var.varValue == 1):
            food = available_foods.query(f'ID == {var.name}')
            amount = random.randint(1, 4) * 100
            print( str(amount) + "g of " + food['Description'].values + ' containing ' + str(food['Calories'].values * (amount/100)) + " calories")

# %% [markdown]
# فانکشن گرفتن اطلاعات کاربر که در تست این قسمت کامنت شده اما در فایل پاتون کامنت نیست و از کاربر ورودی دریافت میکند

# %%
def get_user_inputs():
    global sex
    global weight
    global dailyActivityCount
    sex = input('what is your sexuality?(type male or female)\n')
    weight = float(input('enter your weight:\n'))
    dailyActivityCount = float(input('enter your daily activity:\n'))

# %% [markdown]
# فانکشن اصلی برنامه که تمامی فانکشن های دیگر را صدا میزند

# %%
def main():
    global requiredCal
    global available_foods
    global sexFactor
    global activityFactor
    # get_user_inputs()
    sexFactor = calculateSexFactors()
    activityFactor = calculateActivityFactors()
    calculate_required_cal()
    available_foods = readData()
    findCalories()
    find_daily_diet()
    show_result()

# %%
main()
# Out:
# {'ID': 1001, 'Description': 'BUTTER,WITH SALT', 'Calories': 717.0}
# {'ID': 1002, 'Description': 'BUTTER,WHIPPED,WITH SALT', 'Calories': 717.0}
# {'ID': 1003, 'Description': 'BUTTER OIL,ANHYDROUS', 'Calories': 876.0}
# {'ID': 1004, 'Description': 'CHEESE,BLUE', 'Calories': 353.0}
# {'ID': 1005, 'Description': 'CHEESE,BRICK', 'Calories': 371.0}
# {'ID': 1006, 'Description': 'CHEESE,BRIE', 'Calories': 334.0}
# {'ID': 1007, 'Description': 'CHEESE,CAMEMBERT', 'Calories': 300.0}
# {'ID': 1008, 'Description': 'CHEESE,CARAWAY', 'Calories': 376.0}
# {'ID': 1009, 'Description': 'CHEESE,CHEDDAR', 'Calories': 403.0}
# {'ID': 1010, 'Description': 'CHEESE,CHESHIRE', 'Calories': 387.0}
# {'ID': 1011, 'Description': 'CHEESE,COLBY', 'Calories': 394.0}
# {'ID': 1012, 'Description': 'CHEESE,COTTAGE,CRMD,LRG OR SML CURD', 'Calories': 98.0}
# {'ID': 1013, 'Description': 'CHEESE,COTTAGE,CRMD,W/FRUIT', 'Calories': 97.0}
# {'ID': 1014, 'Description': 'CHEESE,COTTAGE,NONFAT,UNCRMD,DRY,LRG OR SML CURD', 'Calories': 72.0}
# {'ID': 1015, 'Description': 'CHEESE,COTTAGE,LOWFAT,2% MILKFAT', 'Calories': 86.0}
# {'ID': 1016, 'Description': 'CHEESE,COTTAGE,LOWFAT,1% MILKFAT', 'Calories': 72.0}
# {'ID': 1017, 'Description': 'CHEESE,CREAM', 'Calories': 342.0}
# {'ID': 1018, 'Description': 'CHEESE,EDAM', 'Calories': 357.0}
# {'ID': 1019, 'Description': 'CHEESE,FETA', 'Calories': 264.0}
# {'ID': 1020, 'Description': 'CHEESE,FONTINA', 'Calories': 389.0}
# {'ID': 1021, 'Description': 'CHEESE,GJETOST', 'Calories': 466.0}
# {'ID': 1022, 'Description': 'CHEESE,GOUDA', 'Calories': 356.0}
# {'ID': 1023, 'Description': 'CHEESE,GRUYERE', 'Calories': 413.0}
# {'ID': 1024, 'Description': 'CHEESE,LIMBURGER', 'Calories': 327.0}
# {'ID': 1025, 'Description': 'CHEESE,MONTEREY', 'Calories': 373.0}
# {'ID': 1026, 'Description': 'CHEESE,MOZZARELLA,WHL MILK', 'Calories': 300.0}
# {'ID': 1027, 'Description': 'CHEESE,MOZZARELLA,WHL MILK,LO MOIST', 'Calories': 318.0}
# {'ID': 1028, 'Description': 'CHEESE,MOZZARELLA,PART SKIM MILK', 'Calories': 254.0}
# {'ID': 1029, 'Description': 'CHEESE,MOZZARELLA,PART SKIM MILK,LO MOIST', 'Calories': 302.0}
# {'ID': 1030, 'Description': 'CHEESE,MUENSTER', 'Calories': 368.0}
# {'ID': 1031, 'Description': 'CHEESE,NEUFCHATEL', 'Calories': 253.0}
# {'ID': 1032, 'Description': 'CHEESE,PARMESAN,GRATED', 'Calories': 431.0}
# {'ID': 1033, 'Description': 'CHEESE,PARMESAN,HARD', 'Calories': 392.0}
# {'ID': 1034, 'Description': 'CHEESE,PORT DE SALUT', 'Calories': 352.0}
# {'ID': 1035, 'Description': 'CHEESE,PROVOLONE', 'Calories': 351.0}
# {'ID': 1036, 'Description': 'CHEESE,RICOTTA,WHOLE MILK', 'Calories': 174.0}
# {'ID': 1037, 'Description': 'CHEESE,RICOTTA,PART SKIM MILK', 'Calories': 138.0}
# {'ID': 1038, 'Description': 'CHEESE,ROMANO', 'Calories': 387.0}
# {'ID': 1039, 'Description': 'CHEESE,ROQUEFORT', 'Calories': 369.0}
# {'ID': 1040, 'Description': 'CHEESE,SWISS', 'Calories': 380.0}
# {'ID': 1041, 'Description': 'CHEESE,TILSIT', 'Calories': 340.0}
# {'ID': 1042, 'Description': 'CHEESE,PAST PROCESS,AMERICAN,FORT W/ VITAMIN D', 'Calories': 371.0}
# {'ID': 1043, 'Description': 'CHEESE,PAST PROCESS,PIMENTO', 'Calories': 375.0}
# {'ID': 1044, 'Description': 'CHEESE,PAST PROCESS,SWISS', 'Calories': 334.0}
# {'ID': 1045, 'Description': 'CHEESE FD,COLD PK,AMERICAN', 'Calories': 331.0}
# {'ID': 1046, 'Description': 'CHEESE FD,PAST PROCESS,AMERICAN,VITAMIN D FORT', 'Calories': 330.0}
# {'ID': 1047, 'Description': 'CHEESE FD,PAST PROCESS,SWISS', 'Calories': 323.0}
# {'ID': 1048, 'Description': 'CHEESE SPRD,PAST PROCESS,AMERICAN', 'Calories': 290.0}
# {'ID': 1049, 'Description': 'CREAM,FLUID,HALF AND HALF', 'Calories': 130.0}
# {'ID': 1050, 'Description': 'CREAM,FLUID,LT (COFFEE CRM OR TABLE CRM)', 'Calories': 195.0}
# {'ID': 1052, 'Description': 'CREAM,FLUID,LT WHIPPING', 'Calories': 292.0}
# {'ID': 1053, 'Description': 'CREAM,FLUID,HVY WHIPPING', 'Calories': 345.0}
# {'ID': 1054, 'Description': 'CREAM,WHIPPED,CRM TOPPING,PRESSURIZED', 'Calories': 257.0}
# {'ID': 1055, 'Description': 'CREAM,SOUR,RED FAT,CULTURED', 'Calories': 135.0}
# {'ID': 1056, 'Description': 'CREAM,SOUR,CULTURED', 'Calories': 193.0}
# {'ID': 1057, 'Description': 'EGGNOG', 'Calories': 88.0}
# {'ID': 1058, 'Description': 'SOUR DRSNG,NON-BUTTERFAT,CULTURED,FILLED CREAM-TYPE', 'Calories': 178.0}
# {'ID': 1059, 'Description': 'MILK,FILLED,FLUID,W/BLEND OF HYDR VEG OILS', 'Calories': 63.0}
# {'ID': 1060, 'Description': 'MILK,FILLED,FLUID,W/LAURIC ACID OIL', 'Calories': 63.0}
# {'ID': 1067, 'Description': 'CREAM SUB,LIQ,W/HYDR VEG OIL&SOY PROT', 'Calories': 136.0}
# {'ID': 1068, 'Description': 'CREAM SUB,LIQ,W/LAURIC ACID OIL&NA CASEINATE', 'Calories': 136.0}
# {'ID': 1069, 'Description': 'CREAM SUBSTITUTE,POWDERED', 'Calories': 545.0}
# {'ID': 1070, 'Description': 'DESSERT TOPPING,POWDERED', 'Calories': 577.0}
# {'ID': 1071, 'Description': 'DESSERT TOPPING,PDR,1.5 OZ PREP W/1/2 CUP MILK', 'Calories': 194.0}
# {'ID': 1072, 'Description': 'DESSERT TOPPING,PRESSURIZED', 'Calories': 264.0}
# {'ID': 1073, 'Description': 'DESSERT TOPPING,SEMI SOLID,FRZ', 'Calories': 318.0}
# {'ID': 1074, 'Description': 'SOUR CRM,IMITN,CULTURED', 'Calories': 208.0}
# {'ID': 1076, 'Description': 'MILK SUBSTITUTES,FLUID,W/LAURIC ACID OIL', 'Calories': 61.0}
# {'ID': 1077, 'Description': 'MILK,WHL,3.25% MILKFAT,W/ ADDED VITAMIN D', 'Calories': 61.0}
# {'ID': 1078, 'Description': 'MILK,PRODUCER,FLUID,3.7% MILKFAT', 'Calories': 64.0}
# {'ID': 1079, 'Description': 'MILK,RED FAT,FLUID,2% MILKFAT,W/ ADDED VIT A & VITAMIN D', 'Calories': 50.0}
# {'ID': 1080, 'Description': 'MILK,RED FAT,FLUID,2% MILKFAT,W/ ADDED NFMS, VIT A & VIT D', 'Calories': 51.0}
# {'ID': 1081, 'Description': 'MILK,RED FAT,FLUID,2% MILKFAT,PROT FORT,W/ ADDED VIT A & D', 'Calories': 56.0}
# {'ID': 1082, 'Description': 'MILK,LOWFAT,FLUID,1% MILKFAT,W/ ADDED VIT A & VITAMIN D', 'Calories': 42.0}
# {'ID': 1083, 'Description': 'MILK,LOWFAT,FLUID,1% MILKFAT,W/ ADD NONFAT MILK SOL,VIT A/ D', 'Calories': 43.0}
# {'ID': 1084, 'Description': 'MILK,LOWFAT,FLUID,1% MILKFAT,PROT FORT,W/ ADDED VIT A & D', 'Calories': 48.0}
# {'ID': 1085, 'Description': 'MILK,NONFAT,FLUID,W/ ADDED VIT A & VIT D (FAT FREE OR SKIM)', 'Calories': 34.0}
# {'ID': 1086, 'Description': 'MILK,NONFAT,FLUID,W/ ADDED NONFAT MILK SOL,VIT A & VIT D', 'Calories': 37.0}
# {'ID': 1087, 'Description': 'MILK,NONFAT,FLUID,PROT FORT,W/ ADD VIT A & D (FAT FREE/SKIM)', 'Calories': 41.0}
# {'ID': 1088, 'Description': 'MILK,BTTRMLK,FLUID,CULTURED,LOWFAT', 'Calories': 40.0}
# {'ID': 1089, 'Description': 'MILK,LO NA,FLUID', 'Calories': 61.0}
# {'ID': 1090, 'Description': 'MILK,DRY,WHL,W/ ADDED VITAMIN D', 'Calories': 496.0}
# {'ID': 1091, 'Description': 'MILK,DRY,NONFAT,REG,WO/ ADDED VIT A & VITAMIN D', 'Calories': 362.0}
# {'ID': 1092, 'Description': 'MILK,DRY,NONFAT,INST,W/ ADDED VIT A & VITAMIN D', 'Calories': 358.0}
# {'ID': 1093, 'Description': 'MILK,DRY,NONFAT,CA RED', 'Calories': 354.0}
# {'ID': 1094, 'Description': 'MILK,BUTTERMILK,DRIED', 'Calories': 387.0}
# {'ID': 1095, 'Description': 'MILK,CND,COND,SWTND', 'Calories': 321.0}
# {'ID': 1096, 'Description': 'MILK,CND,EVAP,W/ ADDED VITAMIN D & WO/ ADDED VIT A', 'Calories': 134.0}
# {'ID': 1097, 'Description': 'MILK,CND,EVAP,NONFAT,W/ ADDED VIT A & VITAMIN D', 'Calories': 78.0}
# {'ID': 1102, 'Description': 'MILK,CHOC,FLUID,COMM,WHL,W/ ADDED VIT A & VITAMIN D', 'Calories': 83.0}
# {'ID': 1103, 'Description': 'MILK,CHOC,FLUID,COMM,RED FAT', 'Calories': 76.0}
# {'ID': 1104, 'Description': 'MILK,CHOC,FLUID,COMM,LOWFAT,W/ ADDED VIT A & VITAMIN D', 'Calories': 63.0}
# {'ID': 1105, 'Description': 'MILK,CHOC BEV,HOT COCOA,HOMEMADE', 'Calories': 77.0}
# {'ID': 1106, 'Description': 'MILK,GOAT,FLUID,W/ ADDED VITAMIN D', 'Calories': 69.0}
# {'ID': 1107, 'Description': 'MILK,HUMAN,MATURE,FLUID', 'Calories': 70.0}
# {'ID': 1108, 'Description': 'MILK,INDIAN BUFFALO,FLUID', 'Calories': 97.0}
# {'ID': 1109, 'Description': 'MILK,SHEEP,FLUID', 'Calories': 108.0}
# {'ID': 1110, 'Description': 'MILK SHAKES,THICK CHOC', 'Calories': 119.0}
# {'ID': 1111, 'Description': 'MILK SHAKES,THICK VANILLA', 'Calories': 112.0}
# {'ID': 1112, 'Description': 'WHEY,ACID,FLUID', 'Calories': 24.0}
# {'ID': 1113, 'Description': 'WHEY,ACID,DRIED', 'Calories': 339.0}
# {'ID': 1114, 'Description': 'WHEY,SWEET,FLUID', 'Calories': 27.0}
# {'ID': 1115, 'Description': 'WHEY,SWEET,DRIED', 'Calories': 353.0}
# {'ID': 1116, 'Description': 'YOGURT,PLN,WHL MILK,8 GRAMS PROT PER 8 OZ', 'Calories': 61.0}
# {'ID': 1117, 'Description': 'YOGURT,PLN,LOFAT,12 GRAMS PROT PER 8 OZ', 'Calories': 63.0}
# {'ID': 1118, 'Description': 'YOGURT,PLN,SKIM MILK,13 GRAMS PROT PER 8 OZ', 'Calories': 56.0}
# {'ID': 1119, 'Description': 'YOGURT,VANILLA,LOFAT,11 GRAMS PROT PER 8 OZ', 'Calories': 85.0}
# {'ID': 1120, 'Description': 'YOGURT,FRUIT,LOFAT,9 GRAMS PROT PER 8 OZ', 'Calories': 99.0}
# {'ID': 1121, 'Description': 'YOGURT,FRUIT,LOFAT,10 GRAMS PROT PER 8 OZ', 'Calories': 102.0}
# {'ID': 1122, 'Description': 'YOGURT,FRUIT,LOFAT,11 GRAMS PROT PER 8 OZ', 'Calories': 105.0}
# {'ID': 1123, 'Description': 'EGG,WHL,RAW,FRSH', 'Calories': 143.0}
# {'ID': 1124, 'Description': 'EGG,WHITE,RAW,FRESH', 'Calories': 52.0}
# {'ID': 1125, 'Description': 'EGG,YOLK,RAW,FRSH', 'Calories': 322.0}
# {'ID': 1126, 'Description': 'EGG,YOLK,RAW,FROZEN', 'Calories': 303.0}
# {'ID': 1127, 'Description': 'EGG,YOLK,RAW,FRZ,SUGARED', 'Calories': 307.0}
# {'ID': 1128, 'Description': 'EGG,WHL,CKD,FRIED', 'Calories': 196.0}
# {'ID': 1129, 'Description': 'EGG,WHL,CKD,HARD-BOILED', 'Calories': 155.0}
# {'ID': 1130, 'Description': 'EGG,WHOLE,COOKED,OMELET', 'Calories': 154.0}
# {'ID': 1131, 'Description': 'EGG,WHL,CKD,POACHED', 'Calories': 143.0}
# {'ID': 1132, 'Description': 'EGG,WHL,CKD,SCRMBLD', 'Calories': 149.0}
# {'ID': 1133, 'Description': 'EGG,WHOLE,DRIED', 'Calories': 594.0}
# {'ID': 1134, 'Description': 'EGG,WHL,DRIED,STABILIZED,GLUCOSE RED', 'Calories': 615.0}
# {'ID': 1135, 'Description': 'EGG,WHITE,DRIED,FLAKES,GLUCOSE RED', 'Calories': 351.0}
# {'ID': 1136, 'Description': 'EGG,WHITE,DRIED,PDR,GLUCOSE RED', 'Calories': 376.0}
# {'ID': 1137, 'Description': 'EGG,YOLK,DRIED', 'Calories': 666.0}
# {'ID': 1138, 'Description': 'EGG,DUCK,WHOLE,FRESH,RAW', 'Calories': 185.0}
# {'ID': 1139, 'Description': 'EGG,GOOSE,WHOLE,FRESH,RAW', 'Calories': 185.0}
# {'ID': 1140, 'Description': 'EGG,QUAIL,WHOLE,FRESH,RAW', 'Calories': 158.0}
# {'ID': 1141, 'Description': 'EGG,TURKEY,WHL,FRSH,RAW', 'Calories': 171.0}
# {'ID': 1144, 'Description': 'EGG SUBSTITUTE,POWDER', 'Calories': 444.0}
# {'ID': 1145, 'Description': 'BUTTER,WITHOUT SALT', 'Calories': 717.0}
# {'ID': 1146, 'Description': 'CHEESE,PARMESAN,SHREDDED', 'Calories': 415.0}
# {'ID': 1151, 'Description': 'MILK,NONFAT,FLUID,WO/ ADDED VIT A & VIT D (FAT FREE OR SKIM)', 'Calories': 34.0}
# {'ID': 1152, 'Description': 'MILK,RED FAT,FLUID,2% MILKFAT,W/ NONFAT MILK SOL,WO/ VIT A', 'Calories': 56.0}
# {'ID': 1153, 'Description': 'MILK,CND,EVAP,W/ VIT A', 'Calories': 134.0}
# {'ID': 1154, 'Description': 'MILK,DRY,NONFAT,REG,W/ ADDED VIT A & VITAMIN D', 'Calories': 362.0}
# {'ID': 1155, 'Description': 'MILK,DRY,NONFAT,INST,WO/ ADDED VIT A & VITAMIN D', 'Calories': 358.0}
# {'ID': 1156, 'Description': 'CHEESE,GOAT,HARD TYPE', 'Calories': 452.0}
# {'ID': 1157, 'Description': 'CHEESE,GOAT,SEMISOFT TYPE', 'Calories': 364.0}
# {'ID': 1159, 'Description': 'CHEESE,GOAT,SOFT TYPE', 'Calories': 268.0}
# {'ID': 1160, 'Description': 'EGG,YOLK,RAW,FRZ,SALTED', 'Calories': 274.0}
# {'ID': 1161, 'Description': 'CHEESE SUB,MOZZARELLA', 'Calories': 248.0}
# {'ID': 1163, 'Description': 'CHEESE FONDUE', 'Calories': 229.0}
# {'ID': 1164, 'Description': 'CHEESE SAU,PREP FROM RECIPE', 'Calories': 197.0}
# {'ID': 1165, 'Description': 'CHEESE,MEXICAN,QUESO ANEJO', 'Calories': 373.0}
# {'ID': 1166, 'Description': 'CHEESE,MEXICAN,QUESO ASADERO', 'Calories': 356.0}
# {'ID': 1167, 'Description': 'CHEESE,MEXICAN,QUESO CHIHUAHUA', 'Calories': 374.0}
# {'ID': 1168, 'Description': 'CHEESE,LOFAT,CHEDDAR OR COLBY', 'Calories': 173.0}
# {'ID': 1169, 'Description': 'CHEESE,LOW-SODIUM,CHEDDAR OR COLBY', 'Calories': 398.0}
# {'ID': 1171, 'Description': 'EGG,WHOLE,RAW,FROZEN', 'Calories': 148.0}
# {'ID': 1172, 'Description': 'EGG,WHITE,RAW,FROZEN', 'Calories': 47.0}
# {'ID': 1173, 'Description': 'EGG,WHITE,DRIED', 'Calories': 382.0}
# {'ID': 1174, 'Description': 'MILK,RED FAT,FLUID,2% MILKFAT,WO/ ADDED VIT A & VIT D', 'Calories': 50.0}
# {'ID': 1175, 'Description': 'MILK,FLUID,1% FAT,WO/ ADDED VIT A & VIT D', 'Calories': 42.0}
# {'ID': 1178, 'Description': 'SOUR CREAM,REDUCED FAT', 'Calories': 181.0}
# {'ID': 1179, 'Description': 'SOUR CREAM,LIGHT', 'Calories': 138.0}
# {'ID': 1180, 'Description': 'SOUR CREAM,FAT FREE', 'Calories': 74.0}
# {'ID': 1182, 'Description': 'USDA COMMODITY,CHS,CHEDDAR,RED FAT', 'Calories': 282.0}
# {'ID': 1184, 'Description': 'YOGURT,VAN OR LEM FLAV,NONFAT MILK,SWTND W/LOW-CALORIE SWTNR', 'Calories': 43.0}
# {'ID': 1185, 'Description': 'PARMESAN CHS TOPPING,FAT FREE', 'Calories': 370.0}
# {'ID': 1186, 'Description': 'CHEESE,CREAM,FAT FREE', 'Calories': 105.0}
# {'ID': 1187, 'Description': 'YOGURT,CHOC,NONFAT MILK', 'Calories': 112.0}
# {'ID': 1188, 'Description': 'KRAFT CHEEZ WHIZ PAST PROCESS CHS SAU', 'Calories': 276.0}
# {'ID': 1189, 'Description': 'KRAFT CHEEZ WHIZ LT PAST PROCESS CHS PRODUCT', 'Calories': 215.0}
# {'ID': 1190, 'Description': 'KRAFT FREE SINGLES AMERICAN NONFAT PAST PROCESS CHS PRODUCT', 'Calories': 148.0}
# {'ID': 1191, 'Description': 'KRAFT VELVEETA PAST PROCESS CHS SPRD', 'Calories': 303.0}
# {'ID': 1192, 'Description': 'KRAFT VELVEETA LT RED FAT PAST PROCESS CHS PRODUCT', 'Calories': 222.0}
# {'ID': 1193, 'Description': "KRAFT BREAKSTONE'S RED FAT SOUR CRM", 'Calories': 152.0}
# {'ID': 1194, 'Description': "KRAFT BREAKSTONE'S FREE FAT FREE SOUR CRM", 'Calories': 91.0}
# {'ID': 1195, 'Description': 'KRAFT BREYERS LOWFAT STRAWBERRY YOGURT (1% MILKFAT)', 'Calories': 96.0}
# {'ID': 1196, 'Description': "KRAFT BREYERS LT N' LVLY LOWFAT STR'BERY YOGURT (1% MILKFAT)", 'Calories': 108.0}
# {'ID': 1197, 'Description': "KRAFT BREYERS SMOTH&CRMY LOWFAT STR'BERY YOGURT (1% MILKFAT)", 'Calories': 102.0}
# {'ID': 1198, 'Description': "KRAFT BREYERS LT NONFAT STR'BERY YOGURT (W/ASPRT&FRUCT SW'T)", 'Calories': 55.0}
# {'ID': 1199, 'Description': 'CREAM,HALF & HALF,FAT FREE', 'Calories': 59.0}
# {'ID': 1200, 'Description': 'REDDI WIP FAT FREE WHIPPED TOPPING', 'Calories': 149.0}
# {'ID': 1202, 'Description': 'MILK,CHOC,FLUID,COMM,RED FAT,W/ ADDED CA', 'Calories': 78.0}
# {'ID': 1203, 'Description': 'YOGURT,FRUIT,LOFAT,W/LO CAL SWEETENER', 'Calories': 105.0}
# {'ID': 1204, 'Description': 'CHEESE,PARMESAN,DRY GRATED,RED FAT', 'Calories': 265.0}
# {'ID': 1205, 'Description': 'CREAM SUB,FLAV,LIQ', 'Calories': 251.0}
# {'ID': 1206, 'Description': 'CREAM SUB,FLAV,PDR', 'Calories': 498.0}
# {'ID': 1208, 'Description': 'CHEESE,PROVOLONE,RED FAT', 'Calories': 274.0}
# {'ID': 1209, 'Description': 'CHEESE,MEXICAN,BLEND,RED FAT', 'Calories': 282.0}
# {'ID': 1210, 'Description': 'EGG MIX,USDA CMDTY', 'Calories': 555.0}
# {'ID': 1211, 'Description': 'MILK,WHL,3.25% MILKFAT,WO/ ADDED VIT A & VITAMIN D', 'Calories': 61.0}
# {'ID': 1212, 'Description': 'MILK,DRY,WHL,WO/ ADDED VITAMIN D', 'Calories': 496.0}
# {'ID': 1214, 'Description': 'MILK,CND,EVAP,WO/ ADDED VIT A & VITAMIN D', 'Calories': 135.0}
# {'ID': 1215, 'Description': 'CHEESE PRODUCT,PAST PROCESS,AMERICAN,RED FAT,FORT W/ VIT D', 'Calories': 240.0}
# {'ID': 1216, 'Description': 'YOGURT,FRUIT,LOFAT,9 GRAMS PROT PER 8 OZ,FORT W/ VITAMIN D', 'Calories': 99.0}
# {'ID': 1217, 'Description': 'YOGURT,FRUIT,LOFAT,10 GRAMS PROT PER 8 OZ,FORT W/ VITAMIN D', 'Calories': 102.0}
# {'ID': 1218, 'Description': 'YOGURT,FRUIT VAR,NONFAT,FORT W/ VITAMIN D', 'Calories': 95.0}
# {'ID': 1219, 'Description': 'YOGURT,FRUIT,LOWFAT,W/ LO CAL SWTNR,FORT W/ VITAMIN D', 'Calories': 105.0}
# {'ID': 1220, 'Description': 'YOGURT,VANILLA,LOFAT,11 GRAMS PROT PER 8 OZ,FORT W/ VIT D', 'Calories': 85.0}
# {'ID': 1221, 'Description': 'YOGURT,VAN/LEM FLAV,NONFAT MILK,W/ LO-CAL SWTNR,FORT W/VIT D', 'Calories': 43.0}
# {'ID': 1222, 'Description': 'YOGURT,CHOC,NONFAT MILK,FORT W/ VITAMIN D', 'Calories': 112.0}
# {'ID': 1223, 'Description': 'PROTEIN SUPP,MILK BSD,MUSCLE MILK,PDR', 'Calories': 411.0}
# {'ID': 1224, 'Description': 'PROTEIN SUPP,MILK BSD,MUSCLE MILK LT,PDR', 'Calories': 396.0}
# {'ID': 1225, 'Description': 'DULCE DE LECHE', 'Calories': 315.0}
# {'ID': 1226, 'Description': 'EGG SUB,LIQ OR FRZ,FAT FREE', 'Calories': 48.0}
# {'ID': 1227, 'Description': 'CHEESE,DRY WHITE,QUESO SECO', 'Calories': 325.0}
# {'ID': 1228, 'Description': 'CHEESE,FRSH,QUESO FRESCO', 'Calories': 299.0}
# {'ID': 1229, 'Description': 'CHEESE,WHITE,QUESO BLANCO', 'Calories': 310.0}
# {'ID': 1230, 'Description': 'MILK,BTTRMLK,FLUID,WHL', 'Calories': 62.0}
# {'ID': 1231, 'Description': 'YOGURT,VANILLA FLAVOR,LOWFAT MILK,SWTND W/ LO CAL SWTNR', 'Calories': 86.0}
# {'ID': 1235, 'Description': 'YOGURT,FRZ,FLAVORS NOT CHOC,NONFAT MILK,W/ LOW-CALORIE SWTNR', 'Calories': 104.0}
# {'ID': 1236, 'Description': 'ICE CRM,SOFT SERVE,CHOC', 'Calories': 222.0}
# {'ID': 1237, 'Description': 'ICE CRM,BAR OR STK,CHOC COVERED', 'Calories': 331.0}
# {'ID': 1238, 'Description': 'ICE CRM SNDWCH', 'Calories': 237.0}
# {'ID': 1239, 'Description': 'ICE CRM COOKIE SNDWCH', 'Calories': 240.0}
# {'ID': 1240, 'Description': 'ICE CRM CONE,CHOC COVERED,W/ NUTS,FLAVORS OTHER THAN CHOC', 'Calories': 354.0}
# {'ID': 1241, 'Description': 'ICE CRM SNDWCH,MADE W/ LT ICE CRM,VANILLA', 'Calories': 186.0}
# {'ID': 1242, 'Description': 'ICE CRM SNDWCH,VANILLA,LT,NO SUGAR ADDED', 'Calories': 200.0}
# {'ID': 1243, 'Description': 'FAT FREE ICE CRM,NO SUGAR ADDED,FLAVORS OTHER THAN CHOC', 'Calories': 129.0}
# {'ID': 1244, 'Description': 'MILK DSSRT BAR,FRZ,MADE FROM LOWFAT MILK', 'Calories': 147.0}
# {'ID': 1250, 'Description': 'NUTRITIONAL SUPP FOR PEOPLE W/ DIABETES,LIQ', 'Calories': 88.0}
# {'ID': 1251, 'Description': 'CHEESE,MEXICAN BLEND', 'Calories': 358.0}
# {'ID': 1252, 'Description': 'CHEESE PRODUCT,PAST PROCESS,AMERICAN,VITAMIN D FORT', 'Calories': 310.0}
# {'ID': 1253, 'Description': 'CHEESE,PAST PROCESS,AMERICAN,WO/ ADDED VITAMIN D', 'Calories': 371.0}
# {'ID': 1254, 'Description': 'CHEESE FD,PAST PROCESS,AMERICAN,WO/ ADDED VITAMIN D', 'Calories': 330.0}
# {'ID': 1255, 'Description': 'EGG,WHL,RAW,FRZ,SALTED', 'Calories': 138.0}
# {'ID': 2001, 'Description': 'ALLSPICE,GROUND', 'Calories': 263.0}
# {'ID': 2002, 'Description': 'ANISE SEED', 'Calories': 337.0}
# {'ID': 2003, 'Description': 'SPICES,BASIL,DRIED', 'Calories': 233.0}
# {'ID': 2004, 'Description': 'SPICES,BAY LEAF', 'Calories': 313.0}
# {'ID': 2005, 'Description': 'CARAWAY SEED', 'Calories': 333.0}
# {'ID': 2006, 'Description': 'SPICES,CARDAMOM', 'Calories': 311.0}
# {'ID': 2007, 'Description': 'CELERY SEED', 'Calories': 392.0}
# {'ID': 2008, 'Description': 'CHERVIL,DRIED', 'Calories': 237.0}
# {'ID': 2009, 'Description': 'CHILI POWDER', 'Calories': 282.0}
# {'ID': 2010, 'Description': 'CINNAMON,GROUND', 'Calories': 247.0}
# {'ID': 2011, 'Description': 'CLOVES,GROUND', 'Calories': 274.0}
# {'ID': 2012, 'Description': 'CORIANDER LEAF,DRIED', 'Calories': 279.0}
# {'ID': 2013, 'Description': 'CORIANDER SEED', 'Calories': 298.0}
# {'ID': 2014, 'Description': 'CUMIN SEED', 'Calories': 375.0}
# {'ID': 2015, 'Description': 'CURRY POWDER', 'Calories': 325.0}
# {'ID': 2016, 'Description': 'DILL SEED', 'Calories': 305.0}
# {'ID': 2017, 'Description': 'DILL WEED,DRIED', 'Calories': 253.0}
# {'ID': 2018, 'Description': 'FENNEL SEED', 'Calories': 345.0}
# {'ID': 2019, 'Description': 'FENUGREEK SEED', 'Calories': 323.0}
# {'ID': 2020, 'Description': 'GARLIC POWDER', 'Calories': 331.0}
# {'ID': 2021, 'Description': 'GINGER,GROUND', 'Calories': 335.0}
# {'ID': 2022, 'Description': 'MACE,GROUND', 'Calories': 475.0}
# {'ID': 2023, 'Description': 'MARJORAM,DRIED', 'Calories': 271.0}
# {'ID': 2024, 'Description': 'SPICES,MUSTARD SD,GROUND', 'Calories': 508.0}
# {'ID': 2025, 'Description': 'NUTMEG,GROUND', 'Calories': 525.0}
# {'ID': 2026, 'Description': 'ONION POWDER', 'Calories': 341.0}
# {'ID': 2027, 'Description': 'SPICES,OREGANO,DRIED', 'Calories': 265.0}
# {'ID': 2028, 'Description': 'PAPRIKA', 'Calories': 282.0}
# {'ID': 2029, 'Description': 'PARSLEY,DRIED', 'Calories': 292.0}
# {'ID': 2030, 'Description': 'PEPPER,BLACK', 'Calories': 251.0}
# {'ID': 2031, 'Description': 'PEPPER,RED OR CAYENNE', 'Calories': 318.0}
# {'ID': 2032, 'Description': 'PEPPER,WHITE', 'Calories': 296.0}
# {'ID': 2033, 'Description': 'POPPY SEED', 'Calories': 525.0}
# {'ID': 2034, 'Description': 'POULTRY SEASONING', 'Calories': 307.0}
# {'ID': 2035, 'Description': 'PUMPKIN PIE SPICE', 'Calories': 342.0}
# {'ID': 2036, 'Description': 'ROSEMARY,DRIED', 'Calories': 331.0}
# {'ID': 2037, 'Description': 'SAFFRON', 'Calories': 310.0}
# {'ID': 2038, 'Description': 'SAGE,GROUND', 'Calories': 315.0}
# {'ID': 2039, 'Description': 'SAVORY,GROUND', 'Calories': 272.0}
# {'ID': 2041, 'Description': 'SPICES,TARRAGON,DRIED', 'Calories': 295.0}
# {'ID': 2042, 'Description': 'SPICES,THYME,DRIED', 'Calories': 276.0}
# {'ID': 2043, 'Description': 'TURMERIC,GROUND', 'Calories': 354.0}
# {'ID': 2044, 'Description': 'BASIL,FRESH', 'Calories': 23.0}
# {'ID': 2045, 'Description': 'DILL WEED,FRSH', 'Calories': 43.0}
# {'ID': 2046, 'Description': 'MUSTARD,PREPARED,YELLOW', 'Calories': 67.0}
# {'ID': 2048, 'Description': 'VINEGAR,CIDER', 'Calories': 21.0}
# {'ID': 2049, 'Description': 'THYME,FRSH', 'Calories': 101.0}
# {'ID': 2050, 'Description': 'VANILLA EXTRACT', 'Calories': 288.0}
# {'ID': 2051, 'Description': 'VANILLA EXTRACT,IMITN,ALCOHOL', 'Calories': 237.0}
# {'ID': 2052, 'Description': 'VANILLA EXTRACT,IMITN,NO ALCOHOL', 'Calories': 56.0}
# {'ID': 2053, 'Description': 'VINEGAR,DISTILLED', 'Calories': 18.0}
# {'ID': 2054, 'Description': 'CAPERS,CANNED', 'Calories': 23.0}
# {'ID': 2055, 'Description': 'HORSERADISH,PREPARED', 'Calories': 48.0}
# {'ID': 2063, 'Description': 'ROSEMARY,FRESH', 'Calories': 131.0}
# {'ID': 2064, 'Description': 'PEPPERMINT,FRESH', 'Calories': 70.0}
# {'ID': 2065, 'Description': 'SPEARMINT,FRESH', 'Calories': 44.0}
# {'ID': 2066, 'Description': 'SPEARMINT,DRIED', 'Calories': 285.0}
# {'ID': 2068, 'Description': 'VINEGAR,RED WINE', 'Calories': 19.0}
# {'ID': 2069, 'Description': 'VINEGAR,BALSAMIC', 'Calories': 88.0}
# {'ID': 2073, 'Description': 'CAMPBELL SOUP CO,PACE,DRY TACO SEAS MIX', 'Calories': 188.0}
# {'ID': 3019, 'Description': 'GERBER GRADUATES FRUIT STRIPS REAL FRUIT BARS', 'Calories': 330.0}
# {'ID': 3217, 'Description': 'ZWIEBACK', 'Calories': 426.0}
# {'ID': 3819, 'Description': 'CHILD FORMULA,MEAD JOHNSON,PORTAGEN,W/ IRON,PDR,NOT RECON', 'Calories': 483.0}
# {'ID': 3820, 'Description': 'CHILD FORMULA,MEAD JOHNSON,PORTAGEN,W/ IRON,PREP FROM PDR', 'Calories': 88.0}
# {'ID': 3849, 'Description': 'In for, M JOHN, ENF, ENFAC LIP, with ir, po, wi ARA and DH', 'Calories': 514.0}
# {'ID': 3860, 'Description': 'CHILD FORMULA,ABBOTT NUTR,PEDIASURE,RTF (FORMERLY ROSS)', 'Calories': 99.0}
# {'ID': 3870, 'Description': 'CHI FORMU,ABBT NUTR,PEDIASU,RTF,W/ IRON & FIB (FORMER ROSS)', 'Calories': 99.0}
# {'ID': 3968, 'Description': 'TODDLER FORMULA, MEAD JOHNSON, ENFAGROW PREMIUM, RTF', 'Calories': 64.0}
# {'ID': 4001, 'Description': 'FAT,BEEF TALLOW', 'Calories': 902.0}
# {'ID': 4002, 'Description': 'LARD', 'Calories': 902.0}
# {'ID': 4011, 'Description': 'SALAD DRSNG,KRAFT MAYO LT MAYO', 'Calories': 334.0}
# {'ID': 4013, 'Description': 'SALAD DRSNG,KRAFT MAYO FAT FREE MAYO DRSNG', 'Calories': 70.0}
# {'ID': 4014, 'Description': 'SALAD DRSNG,KRAFT MIRACLE WHIP FREE NONFAT DRSNG', 'Calories': 84.0}
# {'ID': 4015, 'Description': 'SALAD DRSNG,RUSSIAN DRSNG', 'Calories': 355.0}
# {'ID': 4016, 'Description': 'SALAD DRSNG,SESAME SD DRSNG,REG', 'Calories': 443.0}
# {'ID': 4017, 'Description': 'SALAD DRSNG,1000 ISLAND,COMM,REG', 'Calories': 370.0}
# {'ID': 4018, 'Description': 'SALAD DRSNG,MAYO TYPE,REG,W/SALT', 'Calories': 390.0}
# {'ID': 4020, 'Description': 'SALAD DRSNG,FRENCH DRSNG,RED FAT', 'Calories': 222.0}
# {'ID': 4021, 'Description': 'SALAD DRSNG,ITALIAN DRSNG,RED FAT', 'Calories': 75.0}
# {'ID': 4022, 'Description': 'SALAD DRSNG,RUSSIAN DRSNG,LO CAL', 'Calories': 141.0}
# {'ID': 4023, 'Description': 'SALAD DRSNG,1000 ISLAND DRSNG,RED FAT', 'Calories': 195.0}
# {'ID': 4025, 'Description': 'SALAD DRSNG,MAYO,SOYBN OIL,W/SALT', 'Calories': 718.0}
# {'ID': 4026, 'Description': 'SALAD DRSNG,MAYO,SOYBN&SAFFLOWER OIL,W/SALT', 'Calories': 717.0}
# {'ID': 4027, 'Description': 'SALAD DRSNG,MAYO,IMITN,SOYBN', 'Calories': 232.0}
# {'ID': 4028, 'Description': 'SALAD DRSNG,MAYO,IMITN,MILK CRM', 'Calories': 97.0}
# {'ID': 4029, 'Description': 'SALAD DRSNG,MAYO,IMITN,SOYBN WO/CHOL', 'Calories': 482.0}
# {'ID': 4030, 'Description': 'SANDWICH SPRD,W/CHOPD PICKLE,REG,UNSPEC OILS', 'Calories': 389.0}
# {'ID': 4031, 'Description': 'SHORTENING,HOUSEHOLD,PARTIALLY HYDROG SOYBN -COTTONSEED', 'Calories': 884.0}
# {'ID': 4034, 'Description': 'OIL,SOYBN,SALAD OR COOKING,(PARTIALLY HYDROGENATED)', 'Calories': 884.0}
# {'ID': 4037, 'Description': 'OIL,RICE BRAN', 'Calories': 884.0}
# {'ID': 4038, 'Description': 'OIL,WHEAT GERM', 'Calories': 884.0}
# {'ID': 4042, 'Description': 'OIL,PNUT,SALAD OR COOKING', 'Calories': 884.0}
# {'ID': 4044, 'Description': 'OIL,SOYBN,SALAD OR COOKING', 'Calories': 884.0}
# {'ID': 4047, 'Description': 'OIL,COCNT', 'Calories': 862.0}
# {'ID': 4053, 'Description': 'OIL,OLIVE,SALAD OR COOKING', 'Calories': 884.0}
# {'ID': 4055, 'Description': 'OIL,PALM', 'Calories': 884.0}
# {'ID': 4058, 'Description': 'OIL,SESAME,SALAD OR COOKING', 'Calories': 884.0}
# {'ID': 4060, 'Description': 'OIL,SUNFLOWER,LINOLEIC (LESS THAN 60%)', 'Calories': 884.0}
# {'ID': 4073, 'Description': 'MARGARINE,REG,HARD,SOYBN (HYDR)', 'Calories': 719.0}
# {'ID': 4114, 'Description': 'SALAD DRSNG,ITALIAN DRSNG,COMM,REG', 'Calories': 291.0}
# {'ID': 4120, 'Description': 'SALAD DRSNG,FRENCH DRSNG,COMM,REG', 'Calories': 457.0}
# {'ID': 4128, 'Description': 'VEG OIL SPRD,UNSPEC OILS,APPROX 37% FAT,W/ SALT', 'Calories': 339.0}
# {'ID': 4133, 'Description': 'SALAD DRSNG,FRENCH,HOME RECIPE', 'Calories': 631.0}
# {'ID': 4134, 'Description': 'SALAD DRSNG,HOME RECIPE,CKD', 'Calories': 157.0}
# {'ID': 4135, 'Description': 'SALAD DRSNG,HOME RECIPE,VINEGAR&OIL', 'Calories': 449.0}
# {'ID': 4141, 'Description': 'SALAD DRSNG,FRENCH DRSNG,COMM,REG,WO/ SALT', 'Calories': 459.0}
# {'ID': 4142, 'Description': 'SALAD DRSNG,FRENCH DRSNG,RED FAT,WO/ SALT', 'Calories': 233.0}
# {'ID': 4143, 'Description': 'SALAD DRSNG,ITALIAN DRSNG,COMM,REG,WO/ SALT', 'Calories': 292.0}
# {'ID': 4144, 'Description': 'SALAD DRSNG,ITALIAN DRSNG,RED FAT,WO/ SALT', 'Calories': 76.0}
# {'ID': 4145, 'Description': 'SALAD DRSNG,MAYO,SOYBN OIL,WO/SALT', 'Calories': 717.0}
# {'ID': 4146, 'Description': 'SALAD DRSNG,FRENCH,CTTNSD,OIL,HOME RECIPE', 'Calories': 631.0}
# {'ID': 4367, 'Description': 'SALAD DRSNG,FRENCH DRSNG,FAT-FREE', 'Calories': 132.0}
# {'ID': 4501, 'Description': 'OIL,COCOA BUTTER', 'Calories': 884.0}
# {'ID': 4502, 'Description': 'OIL,CTTNSD,SALAD OR COOKING', 'Calories': 884.0}
# {'ID': 4506, 'Description': 'OIL,SUNFLOWER,LINOLEIC,(APPROX. 65%)', 'Calories': 884.0}
# {'ID': 4510, 'Description': 'OIL,SAFFLOWER,SALAD OR COOKING,LINOLEIC,(OVER 70%)', 'Calories': 884.0}
# {'ID': 4511, 'Description': 'OIL,SAFFLOWER,SALAD OR COOKING,HI OLEIC', 'Calories': 884.0}
# {'ID': 4513, 'Description': 'VEGETABLE OIL,PALM KERNEL', 'Calories': 862.0}
# {'ID': 4514, 'Description': 'OIL,POPPYSEED', 'Calories': 884.0}
# {'ID': 4515, 'Description': 'OIL,TOMATOSEED', 'Calories': 884.0}
# {'ID': 4516, 'Description': 'OIL,TEASEED', 'Calories': 884.0}
# {'ID': 4517, 'Description': 'OIL,GRAPESEED', 'Calories': 884.0}
# {'ID': 4518, 'Description': 'OIL,CORN,INDUSTRIAL & RTL,ALLPURP SALAD OR COOKING', 'Calories': 884.0}
# {'ID': 4520, 'Description': 'FAT,MUTTON TALLOW', 'Calories': 902.0}
# {'ID': 4528, 'Description': 'OIL,WALNUT', 'Calories': 884.0}
# {'ID': 4529, 'Description': 'OIL,ALMOND', 'Calories': 884.0}
# {'ID': 4530, 'Description': 'OIL,APRICOT KERNEL', 'Calories': 884.0}
# {'ID': 4531, 'Description': 'OIL,SOYBN LECITHIN', 'Calories': 763.0}
# {'ID': 4532, 'Description': 'OIL,HAZELNUT', 'Calories': 884.0}
# {'ID': 4534, 'Description': 'OIL,BABASSU', 'Calories': 884.0}
# {'ID': 4536, 'Description': 'OIL,SHEANUT', 'Calories': 884.0}
# {'ID': 4539, 'Description': 'SALAD DRSNG,BLUE OR ROQUEFORT CHS DRSNG,COMM,REG', 'Calories': 476.0}
# {'ID': 4541, 'Description': 'OIL,CUPU ASSU', 'Calories': 884.0}
# {'ID': 4542, 'Description': 'FAT,CHICKEN', 'Calories': 900.0}
# {'ID': 4543, 'Description': 'OIL,SOYBN,SALAD OR COOKING,(PARTIALLY HYDROGENATED) & CTTNSD', 'Calories': 884.0}
# {'ID': 4544, 'Description': 'SHORTENING,HOUSEHOLD,LARD&VEG OIL', 'Calories': 900.0}
# {'ID': 4545, 'Description': 'OIL,SUNFLOWER,LINOLEIC,(PARTIALLY HYDROGENATED)', 'Calories': 884.0}
# {'ID': 4546, 'Description': 'SHORTENING BREAD,SOYBN (HYDR)&CTTNSD', 'Calories': 884.0}
# {'ID': 4548, 'Description': 'SHORTENING CAKE MIX,SOYBN (HYDR)&CTTNSD (HYDR)', 'Calories': 884.0}
# {'ID': 4549, 'Description': 'SHORTENING INDUSTRIAL,LARD&VEG OIL', 'Calories': 900.0}
# {'ID': 4550, 'Description': 'SHORTENING FRYING (HVY DUTY),BF TALLOW&CTTNSD', 'Calories': 900.0}
# {'ID': 4551, 'Description': 'SHORTENING CONFECTIONERY,COCNT (HYDR)&OR PALM KERNEL (HYDR)', 'Calories': 884.0}
# {'ID': 4554, 'Description': 'SHORTENING INDUSTRIAL,SOYBN (HYDR)&CTTNSD', 'Calories': 884.0}
# {'ID': 4556, 'Description': 'SHORTENING FRYING (HVY DUTY),PALM (HYDR)', 'Calories': 884.0}
# {'ID': 4559, 'Description': 'SHORTENING HOUSEHOLD SOYBN (HYDR)&PALM', 'Calories': 884.0}
# {'ID': 4560, 'Description': 'SHORTENING FRYING HVY DUTY,SOYBN HYDR,LINOLEIC (LESS THAN 1%', 'Calories': 884.0}
# {'ID': 4570, 'Description': 'SHORTENING,CONFECTIONERY,FRACTIONATED PALM', 'Calories': 884.0}
# {'ID': 4572, 'Description': 'OIL,NUTMEG BUTTER', 'Calories': 884.0}
# {'ID': 4573, 'Description': 'OIL,UCUHUBA BUTTER', 'Calories': 884.0}
# {'ID': 4574, 'Description': 'FAT,DUCK', 'Calories': 882.0}
# {'ID': 4575, 'Description': 'FAT,TURKEY', 'Calories': 900.0}
# {'ID': 4576, 'Description': 'FAT,GOOSE', 'Calories': 900.0}
# {'ID': 4581, 'Description': 'OIL,AVOCADO', 'Calories': 884.0}
# {'ID': 4582, 'Description': 'OIL,CANOLA', 'Calories': 884.0}
# {'ID': 4583, 'Description': 'OIL,MUSTARD', 'Calories': 884.0}
# {'ID': 4584, 'Description': 'OIL,SUNFLOWER,HI OLEIC (70% & OVER)', 'Calories': 884.0}
# {'ID': 4585, 'Description': 'MARGARINE-LIKE,MARGARINE-BUTTER BLEND,SOYBN OIL & BUTTER', 'Calories': 714.0}
# {'ID': 4586, 'Description': 'SHORTENING,SPL PURPOSE FOR CAKES&FROSTINGS,SOYBN (HYDR)', 'Calories': 884.0}
# {'ID': 4587, 'Description': 'SHORTENING,SPL PURPOSE FOR BAKING,SOYBN (HYDR) PALM&CTTNSD', 'Calories': 884.0}
# {'ID': 4588, 'Description': 'OIL,OAT', 'Calories': 884.0}
# {'ID': 4589, 'Description': 'FISH OIL,COD LIVER', 'Calories': 902.0}
# {'ID': 4590, 'Description': 'FISH OIL,HERRING', 'Calories': 902.0}
# {'ID': 4591, 'Description': 'FISH OIL,MENHADEN', 'Calories': 902.0}
# {'ID': 4592, 'Description': 'FISH OIL,MENHADEN,FULLY HYDR', 'Calories': 902.0}
# {'ID': 4593, 'Description': 'FISH OIL,SALMON', 'Calories': 902.0}
# {'ID': 4594, 'Description': 'FISH OIL,SARDINE', 'Calories': 902.0}
# {'ID': 4595, 'Description': 'SHORTENING,MULTIPURPOSE,SOYBN (HYDR)&PALM (HYDR)', 'Calories': 884.0}
# {'ID': 4600, 'Description': 'MARGARINE-LIKE,VEG OIL-BUTTER SPRD,TUB,W/ SALT', 'Calories': 362.0}
# {'ID': 4601, 'Description': 'BUTTER,LT,STK,W/SALT', 'Calories': 509.0}
# {'ID': 4602, 'Description': 'BUTTER,LT,STK,WO/SALT', 'Calories': 499.0}
# {'ID': 4606, 'Description': 'MEAT DRIPPINGS (LARD,BF TALLOW,MUTTON TALLOW)', 'Calories': 889.0}
# {'ID': 4609, 'Description': 'ANIMAL FAT,BACON GREASE', 'Calories': 897.0}
# {'ID': 4610, 'Description': 'MARGARINE,REG,80% FAT,COMP,STK,W/ SALT', 'Calories': 717.0}
# {'ID': 4611, 'Description': 'MARGARINE,REG,80% FAT,COMP,TUB,W/ SALT', 'Calories': 713.0}
# {'ID': 4612, 'Description': 'MARGARINE-LIKE,VEG OIL SPRD,60% FAT,STK,W/ SALT', 'Calories': 537.0}
# {'ID': 4613, 'Description': 'MARGARINE-LIKE,VEG OIL SPRD,60% FAT,TUB,W/ SALT', 'Calories': 533.0}
# {'ID': 4614, 'Description': 'MARGARINE-LIKE,VEG OIL SPRD,60% FAT,STICK/TUB/BOTTLE,W/ SALT', 'Calories': 526.0}
# {'ID': 4615, 'Description': 'SHORTENING,VEG,HOUSEHOLD,COMP', 'Calories': 884.0}
# {'ID': 4617, 'Description': 'MARGARINE,REG,80% FAT,COMP,STK,WO/ SALT', 'Calories': 717.0}
# {'ID': 4618, 'Description': 'MARGARINE,REG,80% FAT,COMP,TUB,WO/ SALT', 'Calories': 713.0}
# {'ID': 4620, 'Description': 'VEG OIL SPRD,60% FAT,STICK/TUB/BOTTLE,WO/ SALT', 'Calories': 533.0}
# {'ID': 4624, 'Description': 'MARGARINE-LIKE,VEG OIL SPRD,FAT FREE,LIQ,W/ SALT', 'Calories': 43.0}
# {'ID': 4626, 'Description': 'MARGARINE-LIKE SPRD W/ YOGURT,70% FAT,STK,W/ SALT', 'Calories': 630.0}
# {'ID': 4627, 'Description': 'MARGARINE-LIKE SPRD W/ YOGURT,APPROX 40% FAT,TUB,W/ SALT', 'Calories': 330.0}
# {'ID': 4628, 'Description': 'MARGARINE,80% FAT,STK,INCL REG & HYDR CORN & SOYBN OILS', 'Calories': 717.0}
# {'ID': 4629, 'Description': 'MARGARINE, VEG OIL SPRD,70% FAT,SOYBN & PART HYDR SOYBN,STK', 'Calories': 628.0}
# {'ID': 4630, 'Description': 'MARGARINE SPRD,APPROX 48% FAT,TUB', 'Calories': 424.0}
# {'ID': 4631, 'Description': 'MARGARINE-LIKE,VEG OIL SPRD,FAT-FREE,TUB', 'Calories': 44.0}
# {'ID': 4633, 'Description': 'MARGARINE-LIKE,VEG OIL SPRD,20% FAT,W/ SALT', 'Calories': 175.0}
# {'ID': 4634, 'Description': 'MARGARINE-LIKE,VEG OIL SPRD,20% FAT,WO/ SALT', 'Calories': 175.0}
# {'ID': 4635, 'Description': 'SALAD DRSNG,1000 ISLAND DRSNG,FAT-FREE', 'Calories': 132.0}
# {'ID': 4636, 'Description': 'SALAD DRSNG,ITALIAN DRSNG,FAT-FREE', 'Calories': 47.0}
# {'ID': 4638, 'Description': 'SALAD DRSNG,RANCH DRSNG,FAT-FREE', 'Calories': 119.0}
# {'ID': 4639, 'Description': 'SALAD DRSNG,RANCH DRSNG,COMM,REG', 'Calories': 484.0}
# {'ID': 4640, 'Description': 'SALAD DRSNG,RANCH DRSNG,RED FAT', 'Calories': 196.0}
# {'ID': 4641, 'Description': 'SALAD DRSNG,MAYO,LT', 'Calories': 324.0}
# {'ID': 4642, 'Description': 'OIL,INDUSTRIAL,MID-OLEIC,SUNFLOWER', 'Calories': 884.0}
# {'ID': 4643, 'Description': 'OIL,INDUSTRIAL,CANOLA W/ ANTIFOAMING AGENT', 'Calories': 884.0}
# {'ID': 4644, 'Description': 'OIL,INDUSTRIAL,CANOLA FOR SALADS,WOKS & LT FRYING', 'Calories': 884.0}
# {'ID': 4645, 'Description': 'OIL,INDUS,CANOLA (PART HYDROG) OIL FOR DEEP FAT FRYING', 'Calories': 884.0}
# {'ID': 4646, 'Description': 'OIL,INDUSTRIAL,COCNT', 'Calories': 884.0}
# {'ID': 4648, 'Description': 'OIL,INDUSTRIAL,SOY (PART HYDR),FOR POPCORN & FLAVORING VEG', 'Calories': 884.0}
# {'ID': 4649, 'Description': 'SHORTENING,INDUS,SOY (PART HYDROG),POURABLE LIQ FRY', 'Calories': 884.0}
# {'ID': 4650, 'Description': 'OIL,INDUSTRIAL,SOY,REFINED,FOR WOKS & LT FRYING', 'Calories': 884.0}
# {'ID': 4651, 'Description': 'OIL,INDUSTRIAL,SOY (PART HYDR),FOR NON-DAIRY BUTTER FLAVOR', 'Calories': 884.0}
# {'ID': 4652, 'Description': 'OIL,INDUSTRIAL,SOY ( PART HYDROGENATED),ALLPURP', 'Calories': 884.0}
# {'ID': 4653, 'Description': 'OIL,INDUSTRIAL,SOY (PART HYDR ) & SOY,POURABLE FRY', 'Calories': 884.0}
# {'ID': 4654, 'Description': 'OIL,INDUS,SOY (PART HYDROG) & CTTNSD,TORTILLA SHORTENING', 'Calories': 884.0}
# {'ID': 4655, 'Description': 'MARGARINE-LIKE SHORTENING,INDUS,SOY(PART  HYDR),CTTNSD,& SOY', 'Calories': 628.0}
# {'ID': 4656, 'Description': 'OIL,INDUSTRIAL,PALM KERNEL,CONFECTION FAT', 'Calories': 884.0}
# {'ID': 4657, 'Description': 'OIL,INDUSTRIAL,PALM KERNEL (HYDROGENATED),CONFECTION FAT', 'Calories': 884.0}
# {'ID': 4658, 'Description': 'OIL,INDUSTRIAL,PALM KERNEL (HYDROGENATED),CONFECTION FAT', 'Calories': 884.0}
# {'ID': 4659, 'Description': 'OIL,INDUSTRIAL,COCNT,CONFECTION FAT,ICE CRM COATINGS', 'Calories': 884.0}
# {'ID': 4660, 'Description': 'OIL,INDUSTRIAL,PALM KERNEL (HYDROG) FOR WHIPPED TOPPINGS', 'Calories': 884.0}
# {'ID': 4661, 'Description': 'OIL,INDUSTRIAL,COCNT (HYDROGENATED),FOR TOPPINGS & WHITENERS', 'Calories': 880.0}
# {'ID': 4662, 'Description': 'OIL,INDUSTRIAL,PALM & PALM KERNEL,FILLING FAT (NON-HYDROG)', 'Calories': 880.0}
# {'ID': 4663, 'Description': 'OIL,INDUSTRIAL,PALM KERNEL (HYDROGENATED),FILLING FAT', 'Calories': 884.0}
# {'ID': 4664, 'Description': 'OIL,INDUSTRIAL,SOY (PARTHYDR ),PALM, ICINGS & FILLINGS', 'Calories': 884.0}
# {'ID': 4665, 'Description': 'MARGARINE,INDUS,NON-DAIRY,CTTNSD,SOY OIL (PART HYDR )', 'Calories': 714.0}
# {'ID': 4666, 'Description': 'SHORTENING,INDUSTRIAL,SOY (PARTIALLY HYDR )&CORN FOR FRYING', 'Calories': 884.0}
# {'ID': 4667, 'Description': 'SHORTENING,INDUS,SOY (PART HYDR ) FOR BAKING & CONFECTIONS', 'Calories': 884.0}
# {'ID': 4668, 'Description': 'MARGARINE,INDUS,SOY & PART HYDR SOY OIL,BAKING,SAUCES,CANDY', 'Calories': 714.0}
# {'ID': 4669, 'Description': 'USDA CMDTY FD,OIL,VEG,SOYBN,REFINED', 'Calories': 884.0}
# {'ID': 4670, 'Description': 'USDA CMDTY FD,OIL,VEG,LO SATURATED FAT', 'Calories': 884.0}
# {'ID': 4673, 'Description': 'MARGARINE-LIKE SPRD,SMART BALANCE REG BUTTERY SPRD', 'Calories': 583.0}
# {'ID': 4674, 'Description': 'MARGARINE-LIKE SPRD,SMART BALANCE LT BUTTERY SPRD', 'Calories': 337.0}
# {'ID': 4675, 'Description': 'MARGARINE-LIKE SPRD,SMART BEAT SUPER LT WO/ SATURATED FAT', 'Calories': 158.0}
# {'ID': 4676, 'Description': 'MARGARINE-LIKE SPRD,SMART BEAT SMART SQUEEZE', 'Calories': 47.0}
# {'ID': 4677, 'Description': 'MARGARINE-LIKE SPRD,SMART BALANCE OMEGA PLUS SPRD', 'Calories': 605.0}
# {'ID': 4678, 'Description': 'OIL,VEG,NATREON CANOLA,HI STABILITY,NON TRANS,HI OLEIC (70%)', 'Calories': 884.0}
# {'ID': 4679, 'Description': 'OIL,PAM COOKING SPRAY,ORIGINAL', 'Calories': 792.0}
# {'ID': 4683, 'Description': 'MARGARINE,MARGARINE-LIKE VEG OIL SPRD,67-70% FAT,TUB', 'Calories': 606.0}
# {'ID': 4684, 'Description': 'MARGARINE,80% FAT,TUB,CANOLA HARVEST SOFT SPRD', 'Calories': 730.0}
# {'ID': 4685, 'Description': 'OIL,COOKING & SALAD,ENOVA,80% DIGLYCERIDES', 'Calories': 884.0}
# {'ID': 4686, 'Description': 'SALAD DRSNG,HONEY MUSTARD DRSNG,RED CAL', 'Calories': 207.0}
# {'ID': 4687, 'Description': 'MARGARINE-LIKE SPRD,BENECOL LT SPRD', 'Calories': 357.0}
# {'ID': 4688, 'Description': 'SALAD DRSNG,SPRAY-STYLE DRSNG,ASSORTED FLAVORS', 'Calories': 165.0}
# {'ID': 4689, 'Description': 'SALAD DRSNG,MAYO,LT,SMART BALANCE,OMEGA PLUS LT', 'Calories': 333.0}
# {'ID': 4690, 'Description': 'VEG OIL SPRD,37% FAT,UNSPEC OILS,W/ SALT,W/ ADDED VITAMIN D', 'Calories': 339.0}
# {'ID': 4691, 'Description': 'MARGARINE,REG,80% FAT,COMP,STK,W/ SALT,W/ ADDED VITAMIN D', 'Calories': 717.0}
# {'ID': 4692, 'Description': 'MARGARINE,REG,80% FAT,COMP,TUB,W/ SALT,W/ ADDED VITAMIN D', 'Calories': 713.0}
# {'ID': 4693, 'Description': 'VEG OIL SPRD,60% FAT,STK,W/ SALT,W/ ADDED VITAMIN D', 'Calories': 537.0}
# {'ID': 4694, 'Description': 'VEG OIL SPRD,60% FAT,TUB,W/ SALT,W/ ADDED VITAMIN D', 'Calories': 533.0}
# {'ID': 4695, 'Description': 'VEG-OIL SPRD,STICK/TUB/BOTTLE,60% FAT,W/ ADDED VITAMIN D', 'Calories': 535.0}
# {'ID': 4696, 'Description': 'MARGARINE,REG,80% FAT,COMP,STK,WO/ SALT,W/ ADDED VITAMIN D', 'Calories': 717.0}
# {'ID': 4697, 'Description': 'VEG OIL SPRD,60% FAT,STICK/TUB/BOTTLE,WO/ SALT,W/VIT D', 'Calories': 542.0}
# {'ID': 4698, 'Description': 'OIL,INDUSTRIAL,CANOLA,HI OLEIC', 'Calories': 900.0}
# {'ID': 4699, 'Description': 'OIL,INDUSTRIAL,SOY,LO LINOLENIC', 'Calories': 900.0}
# {'ID': 4700, 'Description': 'OIL,INDUSTRIAL,SOY,ULTRA LO LINOLENIC', 'Calories': 884.0}
# {'ID': 4701, 'Description': 'OIL,INDUSTRIAL,SOY,FULLY HYDR', 'Calories': 884.0}
# {'ID': 4702, 'Description': 'OIL,INDUSTRIAL,CTTNSD,FULLY HYDR', 'Calories': 884.0}
# {'ID': 4703, 'Description': 'SALAD DRSNG,HONEY MUSTARD,REG', 'Calories': 464.0}
# {'ID': 4704, 'Description': 'SALAD DRSNG,POPPYSEED,CREAMY', 'Calories': 399.0}
# {'ID': 4705, 'Description': 'SALAD DRSNG,CAESAR,FAT-FREE', 'Calories': 131.0}
# {'ID': 4706, 'Description': 'DRESSING,HONEY MUSTARD,FAT-FREE', 'Calories': 169.0}
# {'ID': 4707, 'Description': 'OIL,FLAXSEED,CONTAINS ADDED SLICED FLAXSEED', 'Calories': 878.0}
# {'ID': 5001, 'Description': 'CHICKEN,BROILERS OR FRYERS,MEAT&SKN&GIBLETS&NECK,RAW', 'Calories': 213.0}
# {'ID': 5002, 'Description': 'CHICKEN,BROILER OR FRYER,MEAT&SKN&GIBLETS&NECK,FRIED,BATTER', 'Calories': 291.0}
# {'ID': 5003, 'Description': 'CHICKEN,BROILERS OR FRYERS,MEAT&SKN&GIBLETS&NECK,FRIED,FLR', 'Calories': 272.0}
# {'ID': 5004, 'Description': 'CHICKEN,BROILERS OR FRYERS,MEAT&SKN&GIBLETS&NECK,RSTD', 'Calories': 234.0}
# {'ID': 5005, 'Description': 'CHICKEN,BROILERS OR FRYERS,MEAT&SKN&GIBLETS&NECK,STWD', 'Calories': 216.0}
# {'ID': 5006, 'Description': 'CHICKEN,BROILERS OR FRYERS,MEAT & SKN,RAW', 'Calories': 215.0}
# {'ID': 5007, 'Description': 'CHICKEN,BROILERS OR FRYERS,MEAT&SKN,CKD,FRIED,BATTER', 'Calories': 289.0}
# {'ID': 5008, 'Description': 'CHICKEN,BROILERS OR FRYERS,MEAT&SKN,CKD,FRIED,FLR', 'Calories': 269.0}
# {'ID': 5009, 'Description': 'CHICKEN,BROILERS OR FRYERS,MEAT&SKN,CKD,RSTD', 'Calories': 239.0}
# {'ID': 5010, 'Description': 'CHICKEN,BROILERS OR FRYERS,MEAT&SKN,CKD,STWD', 'Calories': 219.0}
# {'ID': 5011, 'Description': 'CHICKEN,BROILERS OR FRYERS,MEAT ONLY,RAW', 'Calories': 119.0}
# {'ID': 5012, 'Description': 'CHICKEN,BROILERS OR FRYERS,MEAT ONLY,CKD,FRIED', 'Calories': 219.0}
# {'ID': 5013, 'Description': 'CHICKEN,BROILERS OR FRYERS,MEAT ONLY,RSTD', 'Calories': 190.0}
# {'ID': 5014, 'Description': 'CHICKEN,BROILERS OR FRYERS,MEAT ONLY,STWD', 'Calories': 177.0}
# {'ID': 5015, 'Description': 'CHICKEN,BROILERS OR FRYERS,SKN ONLY,RAW', 'Calories': 349.0}
# {'ID': 5016, 'Description': 'CHICKEN,BROILERS OR FRYERS,SKN ONLY,CKD,FRIED,BATTER', 'Calories': 394.0}
# {'ID': 5017, 'Description': 'CHICKEN,BROILERS OR FRYERS,SKN ONLY,CKD,FRIED,FLR', 'Calories': 502.0}
# {'ID': 5018, 'Description': 'CHICKEN,BROILERS OR FRYERS,SKN ONLY,CKD,RSTD', 'Calories': 454.0}
# {'ID': 5019, 'Description': 'CHICKEN,BROILERS OR FRYERS,SKN ONLY,CKD,STWD', 'Calories': 363.0}
# {'ID': 5020, 'Description': 'CHICKEN,BROILERS OR FRYERS,GIBLETS,RAW', 'Calories': 124.0}
# {'ID': 5021, 'Description': 'CHICKEN,BROILERS OR FRYERS,GIBLETS,CKD,FRIED', 'Calories': 277.0}
# {'ID': 5022, 'Description': 'CHICKEN,BROILERS OR FRYERS,GIBLETS,CKD,SIMMRD', 'Calories': 157.0}
# {'ID': 5023, 'Description': 'CHICKEN,GIZZARD,ALL CLASSES,RAW', 'Calories': 94.0}
# {'ID': 5024, 'Description': 'CHICKEN,GIZZARD,ALL CLASSES,CKD,SIMMRD', 'Calories': 154.0}
# {'ID': 5025, 'Description': 'CHICKEN,HEART,ALL CLASSES,RAW', 'Calories': 153.0}
# {'ID': 5026, 'Description': 'CHICKEN,HEART,ALL CLASSES,CKD,SIMMRD', 'Calories': 185.0}
# {'ID': 5027, 'Description': 'CHICKEN,LIVER,ALL CLASSES,RAW', 'Calories': 119.0}
# {'ID': 5028, 'Description': 'CHICKEN,LIVER,ALL CLASSES,CKD,SIMMRD', 'Calories': 167.0}
# {'ID': 5029, 'Description': 'CHICKEN,BROILERS OR FRYERS,LT MEAT,MEAT & SKN,RAW', 'Calories': 186.0}
# {'ID': 5030, 'Description': 'CHICKEN,BROILERS OR FRYERS,LT MEAT,MEAT&SKN,CKD,FRIED,BATTER', 'Calories': 277.0}
# {'ID': 5031, 'Description': 'CHICKEN,BROILERS OR FRYERS,LT MEAT,MEAT&SKN,CKD,FRIED,FLR', 'Calories': 246.0}
# {'ID': 5032, 'Description': 'CHICKEN,BROILERS OR FRYERS,LT MEAT,MEAT&SKN,CKD,RSTD', 'Calories': 222.0}
# {'ID': 5033, 'Description': 'CHICKEN,BROILERS OR FRYERS,LT MEAT,MEAT&SKN,CKD,STWD', 'Calories': 201.0}
# {'ID': 5034, 'Description': 'CHICKEN,BROILERS OR FRYERS,DK MEAT,MEAT & SKN,RAW', 'Calories': 237.0}
# {'ID': 5035, 'Description': 'CHICKEN,BROILERS OR FRYERS,DK MEAT,MEAT&SKN,CKD,FRIED,BATTER', 'Calories': 298.0}
# {'ID': 5036, 'Description': 'CHICKEN,BROILERS OR FRYERS,DK MEAT,MEAT&SKN,CKD,FRIED,FLR', 'Calories': 285.0}
# {'ID': 5037, 'Description': 'CHICKEN,BROILERS OR FRYERS,DK MEAT,MEAT&SKN,CKD,RSTD', 'Calories': 253.0}
# {'ID': 5038, 'Description': 'CHICKEN,BROILERS OR FRYERS,DK MEAT,MEAT&SKN,CKD,STWD', 'Calories': 233.0}
# {'ID': 5039, 'Description': 'CHICKEN,BROILERS OR FRYERS,LT MEAT,MEAT ONLY,RAW', 'Calories': 114.0}
# {'ID': 5040, 'Description': 'CHICKEN,BROILERS OR FRYERS,LT MEAT,MEAT ONLY,CKD,FRIED', 'Calories': 192.0}
# {'ID': 5041, 'Description': 'CHICKEN,BROILERS OR FRYERS,LT MEAT,MEAT ONLY,CKD,RSTD', 'Calories': 173.0}
# {'ID': 5042, 'Description': 'CHICKEN,BROILERS OR FRYERS,LT MEAT,MEAT ONLY,CKD,STWD', 'Calories': 159.0}
# {'ID': 5043, 'Description': 'CHICKEN,BROILERS OR FRYERS,DK MEAT,MEAT ONLY,RAW', 'Calories': 125.0}
# {'ID': 5044, 'Description': 'CHICKEN,BROILERS OR FRYERS,DK MEAT,MEAT ONLY,CKD,FRIED', 'Calories': 239.0}
# {'ID': 5045, 'Description': 'CHICKEN,BROILERS OR FRYERS,DK MEAT,MEAT ONLY,CKD,RSTD', 'Calories': 205.0}
# {'ID': 5046, 'Description': 'CHICKEN,BROILERS OR FRYERS,DK MEAT,MEAT ONLY,CKD,STWD', 'Calories': 192.0}
# {'ID': 5047, 'Description': 'CHICKEN,BROILERS OR FRYERS,FAT,RAW', 'Calories': 629.0}
# {'ID': 5048, 'Description': 'CHICKEN,BROILERS OR FRYERS,BACK,MEAT&SKN,RAW', 'Calories': 319.0}
# {'ID': 5049, 'Description': 'CHICKEN,BROILERS OR FRYERS,BACK,MEAT&SKN,CKD,FRIED,BATTER', 'Calories': 331.0}
# {'ID': 5050, 'Description': 'CHICKEN,BROILERS OR FRYERS,BACK,MEAT&SKN,CKD,FRIED,FLR', 'Calories': 331.0}
# {'ID': 5051, 'Description': 'CHICKEN,BROILERS OR FRYERS,BACK,MEAT&SKN,CKD,RSTD', 'Calories': 300.0}
# {'ID': 5052, 'Description': 'CHICKEN,BROILERS OR FRYERS,BACK,MEAT&SKN,CKD,STWD', 'Calories': 258.0}
# {'ID': 5053, 'Description': 'CHICKEN,BROILERS OR FRYERS,BACK,MEAT ONLY,RAW', 'Calories': 137.0}
# {'ID': 5054, 'Description': 'CHICKEN,BROILERS OR FRYERS,BACK,MEAT ONLY,CKD,FRIED', 'Calories': 288.0}
# {'ID': 5055, 'Description': 'CHICKEN,BROILERS OR FRYERS,BACK,MEAT ONLY,CKD,RSTD', 'Calories': 239.0}
# {'ID': 5056, 'Description': 'CHICKEN,BROILERS OR FRYERS,BACK,MEAT ONLY,CKD,STWD', 'Calories': 209.0}
# {'ID': 5057, 'Description': 'CHICKEN,BROILERS OR FRYERS,BREAST,MEAT&SKN,RAW', 'Calories': 172.0}
# {'ID': 5058, 'Description': 'CHICKEN,BROILERS OR FRYERS,BREAST,MEAT&SKN,CKD,FRIED,BATTER', 'Calories': 260.0}
# {'ID': 5059, 'Description': 'CHICKEN,BROILERS OR FRYERS,BREAST,MEAT&SKN,CKD,FRIED,FLR', 'Calories': 222.0}
# {'ID': 5060, 'Description': 'CHICKEN,BROILERS OR FRYERS,BREAST,MEAT&SKN,CKD,RSTD', 'Calories': 197.0}
# {'ID': 5061, 'Description': 'CHICKEN,BROILERS OR FRYERS,BREAST,MEAT&SKN,CKD,STWD', 'Calories': 184.0}
# {'ID': 5062, 'Description': 'CHICKEN,BROILERS OR FRYERS,BREAST,MEAT ONLY,RAW', 'Calories': 114.0}
# {'ID': 5063, 'Description': 'CHICKEN,BROILERS OR FRYERS,BREAST,MEAT ONLY,CKD,FRIED', 'Calories': 187.0}
# {'ID': 5064, 'Description': 'CHICKEN,BROILERS OR FRYERS,BREAST,MEAT ONLY,CKD,RSTD', 'Calories': 165.0}
# {'ID': 5065, 'Description': 'CHICKEN,BROILERS OR FRYERS,BREAST,MEAT ONLY,CKD,STWD', 'Calories': 151.0}
# {'ID': 5066, 'Description': 'CHICKEN,BROILERS OR FRYERS,DRUMSTK,MEAT&SKN,RAW', 'Calories': 159.0}
# {'ID': 5067, 'Description': 'CHICKEN,BROILERS OR FRYERS,DRUMSTK,MEAT&SKN,CKD,FRIED,BATTER', 'Calories': 268.0}
# {'ID': 5068, 'Description': 'CHICKEN,BROILERS OR FRYERS,DRUMSTK,MEAT&SKN,CKD,FRIED,FLR', 'Calories': 245.0}
# {'ID': 5069, 'Description': 'CHICKEN,BROILERS OR FRYERS,DRUMSTK,MEAT&SKN,CKD,RSTD', 'Calories': 186.0}
# {'ID': 5070, 'Description': 'CHICKEN,BROILERS OR FRYERS,DRUMSTK,MEAT&SKN,CKD,STWD', 'Calories': 204.0}
# {'ID': 5071, 'Description': 'CHICKEN,BROILERS OR FRYERS,DK MEAT,DRUMSTK,MEAT ONLY,RAW', 'Calories': 115.0}
# {'ID': 5072, 'Description': 'CHICKEN,BROILERS OR FRYERS,DRUMSTK,MEAT ONLY,CKD,FRIED', 'Calories': 195.0}
# {'ID': 5073, 'Description': 'CHICKEN,BROILERS OR FRYERS,DK MEAT,DRUMSTK,MEAT ONLY,CKD,RST', 'Calories': 149.0}
# {'ID': 5074, 'Description': 'CHICKEN,BROILERS OR FRYERS,DRUMSTK,MEAT ONLY,CKD,STWD', 'Calories': 169.0}
# {'ID': 5075, 'Description': 'CHICKEN,BROILERS OR FRYERS,LEG,MEAT&SKN,RAW', 'Calories': 214.0}
# {'ID': 5076, 'Description': 'CHICKEN,BROILERS OR FRYERS,LEG,MEAT&SKN,CKD,FRIED,BATTER', 'Calories': 273.0}
# {'ID': 5077, 'Description': 'CHICKEN,BROILERS OR FRYERS,LEG,MEAT&SKN,CKD,FRIED,FLR', 'Calories': 254.0}
# {'ID': 5078, 'Description': 'CHICKEN,BROILERS OR FRYERS,LEG,MEAT&SKN,CKD,RSTD', 'Calories': 184.0}
# {'ID': 5079, 'Description': 'CHICKEN,BROILERS OR FRYERS,LEG,MEAT&SKN,CKD,STWD', 'Calories': 220.0}
# {'ID': 5080, 'Description': 'CHICKEN,BROILERS OR FRYERS,LEG,MEAT ONLY,RAW', 'Calories': 120.0}
# {'ID': 5081, 'Description': 'CHICKEN,BROILERS OR FRYERS,LEG,MEAT ONLY,CKD,FRIED', 'Calories': 208.0}
# {'ID': 5082, 'Description': 'CHICKEN,BROILERS OR FRYERS,LEG,MEAT ONLY,CKD,RSTD', 'Calories': 174.0}
# {'ID': 5083, 'Description': 'CHICKEN,BROILERS OR FRYERS,LEG,MEAT ONLY,CKD,STWD', 'Calories': 185.0}
# {'ID': 5084, 'Description': 'CHICKEN,BROILERS OR FRYERS,NECK,MEAT&SKN,RAW', 'Calories': 297.0}
# {'ID': 5085, 'Description': 'CHICKEN,BROILERS OR FRYERS,NECK,MEAT&SKN,CKD,FRIED,BATTER', 'Calories': 330.0}
# {'ID': 5086, 'Description': 'CHICKEN,BROILERS OR FRYERS,NECK,MEAT&SKN,CKD,FRIED,FLR', 'Calories': 332.0}
# {'ID': 5087, 'Description': 'CHICKEN,BROILERS OR FRYERS,NECK,MEAT&SKN,CKD SIMMRD', 'Calories': 247.0}
# ...
# {'ID': 5106, 'Description': 'CHICKEN,BROILERS OR FRYERS,WING,MEAT ONLY,CKD,FRIED', 'Calories': 211.0}
# {'ID': 5107, 'Description': 'CHICKEN,BROILERS OR FRYERS,WING,MEAT ONLY,CKD,RSTD', 'Calories': 203.0}
# {'ID': 5108, 'Description': 'CHICKEN,BROILERS OR FRYERS,WING,MEAT ONLY,CKD,STWD', 'Calories': 181.0}
# {'ID': 5109, 'Description': 'CHICKEN,ROASTING,MEAT&SKN&GIBLETS&NECK,RAW', 'Calories': 213.0}
# {'ID': 5110, 'Description': 'CHICKEN,ROASTING,MEAT&SKN&GIBLETS&NECK,CKD,RSTD', 'Calories': 220.0}
# {'ID': 5111, 'Description': 'CHICKEN,ROASTING,MEAT&SKN,RAW', 'Calories': 216.0}
# {'ID': 5112, 'Description': 'CHICKEN,ROASTING,MEAT&SKN,CKD,RSTD', 'Calories': 223.0}
# {'ID': 5113, 'Description': 'CHICKEN,ROASTING,MEAT ONLY,RAW', 'Calories': 111.0}
# {'ID': 5114, 'Description': 'CHICKEN,ROASTING,MEAT ONLY,CKD,RSTD', 'Calories': 167.0}
# {'ID': 5115, 'Description': 'CHICKEN,ROASTING,GIBLETS,RAW', 'Calories': 127.0}
# {'ID': 5116, 'Description': 'CHICKEN,ROASTING,GIBLETS,CKD,SIMMRD', 'Calories': 165.0}
# {'ID': 5117, 'Description': 'CHICKEN,ROASTING,LT MEAT,MEAT ONLY,RAW', 'Calories': 109.0}
# {'ID': 5118, 'Description': 'CHICKEN,ROASTING,LT MEAT,MEAT ONLY,CKD,RSTD', 'Calories': 153.0}
# {'ID': 5119, 'Description': 'CHICKEN,ROASTING,DK MEAT,MEAT ONLY,RAW', 'Calories': 113.0}
# {'ID': 5120, 'Description': 'CHICKEN,ROASTING,DK MEAT,MEAT ONLY,CKD,RSTD', 'Calories': 178.0}
# {'ID': 5121, 'Description': 'CHICKEN,STEWING,MEAT&SKN,&GIBLETS&NECK,RAW', 'Calories': 251.0}
# {'ID': 5122, 'Description': 'CHICKEN,STEWING,MEAT & SKN,& GIBLETS & NECK,CKD,STWD', 'Calories': 214.0}
# {'ID': 5123, 'Description': 'CHICKEN,STEWING,MEAT&SKN,RAW', 'Calories': 258.0}
# {'ID': 5124, 'Description': 'CHICKEN,STEWING,MEAT&SKN,CKD,STWD', 'Calories': 285.0}
# {'ID': 5125, 'Description': 'CHICKEN,STEWING,MEAT ONLY,RAW', 'Calories': 148.0}
# {'ID': 5126, 'Description': 'CHICKEN,STEWING,MEAT ONLY,CKD,STWD', 'Calories': 237.0}
# {'ID': 5127, 'Description': 'CHICKEN,STEWING,GIBLETS,RAW', 'Calories': 168.0}
# {'ID': 5128, 'Description': 'CHICKEN,STEWING,GIBLETS,CKD,SIMMRD', 'Calories': 194.0}
# {'ID': 5129, 'Description': 'CHICKEN,STEWING,LT MEAT,MEAT ONLY,RAW', 'Calories': 137.0}
# {'ID': 5130, 'Description': 'CHICKEN,STEWING,LT MEAT,MEAT ONLY,CKD,STWD', 'Calories': 213.0}
# {'ID': 5131, 'Description': 'CHICKEN,STEWING,DK MEAT,MEAT ONLY,RAW', 'Calories': 157.0}
# {'ID': 5132, 'Description': 'CHICKEN,STEWING,DK MEAT,MEAT ONLY,CKD,STWD', 'Calories': 258.0}
# {'ID': 5133, 'Description': 'CHICKEN,CAPONS,MEAT&SKN&GIBLETS&NECK,RAW', 'Calories': 232.0}
# {'ID': 5134, 'Description': 'CHICKEN,CAPONS,MEAT&SKN&GIBLETS&NECK,CKD,RSTD', 'Calories': 226.0}
# {'ID': 5135, 'Description': 'CHICKEN,CAPONS,MEAT&SKN,RAW', 'Calories': 234.0}
# {'ID': 5136, 'Description': 'CHICKEN,CAPONS,MEAT&SKN,CKD,RSTD', 'Calories': 229.0}
# {'ID': 5137, 'Description': 'CHICKEN,CAPONS,GIBLETS,RAW', 'Calories': 130.0}
# {'ID': 5138, 'Description': 'CHICKEN,CAPONS,GIBLETS,CKD,SIMMRD', 'Calories': 164.0}
# {'ID': 5139, 'Description': 'DUCK,DOMESTICATED,MEAT&SKN,RAW', 'Calories': 404.0}
# {'ID': 5140, 'Description': 'DUCK,DOMESTICATED,MEAT&SKN,CKD,RSTD', 'Calories': 337.0}
# {'ID': 5141, 'Description': 'DUCK,DOMESTICATED,MEAT ONLY,RAW', 'Calories': 135.0}
# {'ID': 5142, 'Description': 'DUCK,DOMESTICATED,MEAT ONLY,CKD,RSTD', 'Calories': 201.0}
# {'ID': 5143, 'Description': 'DUCK,DOMESTICATED,LIVER,RAW', 'Calories': 136.0}
# {'ID': 5144, 'Description': 'DUCK,WILD,MEAT&SKN,RAW', 'Calories': 211.0}
# {'ID': 5145, 'Description': 'DUCK,WILD,BREAST,MEAT ONLY,RAW', 'Calories': 123.0}
# {'ID': 5146, 'Description': 'GOOSE,DOMESTICATED,MEAT&SKN,RAW', 'Calories': 371.0}
# {'ID': 5147, 'Description': 'GOOSE,DOMESTICATED,MEAT&SKN,CKD,RSTD', 'Calories': 305.0}
# {'ID': 5148, 'Description': 'GOOSE,DOMESTICATED,MEAT ONLY,RAW', 'Calories': 161.0}
# {'ID': 5149, 'Description': 'GOOSE,DOMESTICATED,MEAT ONLY,CKD,RSTD', 'Calories': 238.0}
# {'ID': 5150, 'Description': 'GOOSE,LIVER,RAW', 'Calories': 133.0}
# {'ID': 5151, 'Description': 'GUINEA HEN,MEAT&SKN,RAW', 'Calories': 158.0}
# {'ID': 5152, 'Description': 'GUINEA HEN,MEAT ONLY,RAW', 'Calories': 110.0}
# {'ID': 5153, 'Description': 'PHEASANT,RAW,MEAT&SKN', 'Calories': 181.0}
# {'ID': 5154, 'Description': 'PHEASANT,RAW,MEAT ONLY', 'Calories': 133.0}
# {'ID': 5155, 'Description': 'PHEASANT,BREAST,MEAT ONLY,RAW', 'Calories': 133.0}
# {'ID': 5156, 'Description': 'PHEASANT,LEG,MEAT ONLY,RAW', 'Calories': 134.0}
# {'ID': 5157, 'Description': 'QUAIL,MEAT AND SKIN,RAW', 'Calories': 192.0}
# {'ID': 5158, 'Description': 'QUAIL,MEAT ONLY,RAW', 'Calories': 134.0}
# {'ID': 5159, 'Description': 'QUAIL,BREAST,MEAT ONLY,RAW', 'Calories': 123.0}
# {'ID': 5160, 'Description': 'SQUAB,(PIGEON),MEAT&SKN,RAW', 'Calories': 294.0}
# {'ID': 5161, 'Description': 'SQUAB,(PIGEON),MEAT ONLY,RAW', 'Calories': 142.0}
# {'ID': 5162, 'Description': 'SQUAB,(PIGEON),LT MEAT WO/SKN,RAW', 'Calories': 134.0}
# {'ID': 5163, 'Description': 'TURKEY,ALL CLASSES,MEAT&SKN&GIBLETS&NECK,RAW', 'Calories': 157.0}
# {'ID': 5164, 'Description': 'TURKEY,ALL CLASSES,MEAT&SKN&GIBLETS&NECK,CKD,RSTD', 'Calories': 205.0}
# {'ID': 5165, 'Description': 'TURKEY,ALL CLASSES,MEAT&SKN,RAW', 'Calories': 160.0}
# {'ID': 5166, 'Description': 'TURKEY,ALL CLASSES,MEAT&SKN,CKD,RSTD', 'Calories': 208.0}
# {'ID': 5167, 'Description': 'TURKEY,ALL CLASSES,MEAT ONLY,RAW', 'Calories': 120.0}
# {'ID': 5168, 'Description': 'TURKEY,ALL CLASSES,MEAT ONLY,CKD,RSTD', 'Calories': 170.0}
# {'ID': 5169, 'Description': 'TURKEY,ALL CLASSES,SKN ONLY,RAW', 'Calories': 389.0}
# {'ID': 5170, 'Description': 'TURKEY,ALL CLASSES,SKN ONLY,CKD,RSTD', 'Calories': 443.0}
# {'ID': 5171, 'Description': 'TURKEY,ALL CLASSES,GIBLETS,RAW', 'Calories': 129.0}
# {'ID': 5172, 'Description': 'TURKEY,ALL CLASSES,GIBLETS,CKD,SIMMRD,SOME GIBLET FAT', 'Calories': 199.0}
# {'ID': 5173, 'Description': 'TURKEY,GIZZARD,ALL CLASSES,RAW', 'Calories': 118.0}
# {'ID': 5174, 'Description': 'TURKEY,GIZZARD,ALL CLASSES,CKD,SIMMRD', 'Calories': 129.0}
# {'ID': 5175, 'Description': 'TURKEY,HEART,ALL CLASSES,RAW', 'Calories': 113.0}
# {'ID': 5176, 'Description': 'TURKEY,HEART,ALL CLASSES,CKD,SIMMRD', 'Calories': 136.0}
# {'ID': 5177, 'Description': 'TURKEY,LIVER,ALL CLASSES,RAW', 'Calories': 228.0}
# {'ID': 5178, 'Description': 'TURKEY,LIVER,ALL CLASSES,CKD,SIMMRD', 'Calories': 273.0}
# {'ID': 5179, 'Description': 'TURKEY,ALL CLASSES,NECK,MEAT ONLY,RAW', 'Calories': 135.0}
# {'ID': 5180, 'Description': 'TURKEY,ALL CLASSES,NECK,MEAT ONLY,CKD,SIMMRD', 'Calories': 180.0}
# {'ID': 5181, 'Description': 'TURKEY,ALL CLASSES,LT MEAT,MEAT&SKN,RAW', 'Calories': 159.0}
# {'ID': 5182, 'Description': 'TURKEY,ALL CLASSES,LT MEAT,MEAT&SKN,CKD,RSTD', 'Calories': 197.0}
# {'ID': 5183, 'Description': 'TURKEY,ALL CLASSES,DK MEAT,MEAT&SKN,RAW', 'Calories': 160.0}
# {'ID': 5184, 'Description': 'TURKEY,ALL CLASSES,DK MEAT,MEAT&SKN,CKD,RSTD', 'Calories': 221.0}
# {'ID': 5185, 'Description': 'TURKEY,ALL CLASSES,LT MEAT,RAW', 'Calories': 115.0}
# {'ID': 5186, 'Description': 'TURKEY,ALL CLASSES,LT MEAT,CKD,RSTD', 'Calories': 157.0}
# {'ID': 5187, 'Description': 'TURKEY,ALL CLASSES,DK MEAT,RAW', 'Calories': 125.0}
# {'ID': 5188, 'Description': 'TURKEY,ALL CLASSES,DK MEAT,CKD,RSTD', 'Calories': 188.0}
# {'ID': 5189, 'Description': 'TURKEY,ALL CLASSES,BACK,MEAT&SKN,RAW', 'Calories': 196.0}
# {'ID': 5190, 'Description': 'TURKEY,ALL CLASSES,BACK,MEAT&SKN,CKD,RSTD', 'Calories': 244.0}
# {'ID': 5191, 'Description': 'TURKEY,ALL CLASSES,BREAST,MEAT&SKN,RAW', 'Calories': 157.0}
# {'ID': 5192, 'Description': 'TURKEY,ALL CLASSES,BREAST,MEAT&SKN,CKD,RSTD', 'Calories': 189.0}
# {'ID': 5193, 'Description': 'TURKEY,ALL CLASSES,LEG,MEAT&SKN,RAW', 'Calories': 144.0}
# {'ID': 5194, 'Description': 'TURKEY,ALL CLASSES,LEG,MEAT&SKN,CKD,RSTD', 'Calories': 208.0}
# {'ID': 5195, 'Description': 'TURKEY,ALL CLASSES,WING,MEAT&SKN,RAW', 'Calories': 197.0}
# {'ID': 5196, 'Description': 'TURKEY,ALL CLASSES,WING,MEAT&SKN,CKD,RSTD', 'Calories': 229.0}
# {'ID': 5197, 'Description': 'TURKEY,FRYER-ROASTERS,MEAT&SKN&GIBLETS&NECK,RAW', 'Calories': 133.0}
# {'ID': 5198, 'Description': 'TURKEY,FRYER-ROASTERS,MEAT&SKN&GIBLETS&NECK,CKD,RSTD', 'Calories': 171.0}
# {'ID': 5199, 'Description': 'TURKEY,FRYER-ROASTERS,MEAT&SKN,RAW', 'Calories': 134.0}
# {'ID': 5200, 'Description': 'TURKEY,FRYER-ROASTERS,MEAT&SKN,CKD,RSTD', 'Calories': 172.0}
# {'ID': 5201, 'Description': 'TURKEY,FRYER-ROASTERS,MEAT ONLY,RAW', 'Calories': 110.0}
# {'ID': 5202, 'Description': 'TURKEY,FRYER-ROASTERS,MEAT ONLY,CKD,RSTD', 'Calories': 150.0}
# {'ID': 5203, 'Description': 'TURKEY,FRYER-ROASTERS,SKN ONLY,RAW', 'Calories': 283.0}
# {'ID': 5204, 'Description': 'TURKEY,FRYER-ROASTERS,SKN ONLY,CKD,RSTD', 'Calories': 299.0}
# {'ID': 5205, 'Description': 'TURKEY,FRYER-ROASTERS,LT MEAT,MEAT&SKN,RAW', 'Calories': 133.0}
# {'ID': 5206, 'Description': 'TURKEY,FRYER-ROASTERS,LT MEAT,MEAT&SKN,CKD,RSTD', 'Calories': 164.0}
# {'ID': 5207, 'Description': 'TURKEY,FRYER-ROASTERS,DK MEAT,MEAT&SKN,RAW', 'Calories': 129.0}
# {'ID': 5208, 'Description': 'TURKEY,FRYER-ROASTERS,DK MEAT,MEAT&SKN,CKD,RSTD', 'Calories': 182.0}
# {'ID': 5209, 'Description': 'TURKEY,FRYER-ROASTERS,LT MEAT,MEAT ONLY,RAW', 'Calories': 108.0}
# {'ID': 5210, 'Description': 'TURKEY,FRYER-ROASTERS,LT MEAT,MEAT ONLY,CKD,RSTD', 'Calories': 140.0}
# {'ID': 5211, 'Description': 'TURKEY,FRYER-ROASTERS,DK MEAT,MEAT ONLY,RAW', 'Calories': 111.0}
# {'ID': 5212, 'Description': 'TURKEY,FRYER-ROASTERS,DK MEAT,MEAT ONLY,CKD,RSTD', 'Calories': 162.0}
# {'ID': 5213, 'Description': 'TURKEY,FRYER-ROASTERS,BACK,MEAT&SKN,RAW', 'Calories': 151.0}
# {'ID': 5214, 'Description': 'TURKEY,FRYER-ROASTERS,BACK,MEAT&SKN,CKD,RSTD', 'Calories': 204.0}
# {'ID': 5215, 'Description': 'TURKEY,FRYER-ROASTERS,BACK,MEAT ONLY,RAW', 'Calories': 120.0}
# {'ID': 5216, 'Description': 'TURKEY,FRYER-ROASTERS,BACK,MEAT ONLY,CKD,RSTD', 'Calories': 170.0}
# {'ID': 5217, 'Description': 'TURKEY,FRYER-ROASTERS,BREAST,MEAT&SKN,RAW', 'Calories': 125.0}
# {'ID': 5218, 'Description': 'TURKEY,FRYER-ROASTERS,BREAST,MEAT&SKN,CKD,RSTD', 'Calories': 153.0}
# {'ID': 5219, 'Description': 'TURKEY,FRYER-ROASTERS,BREAST,MEAT ONLY,RAW', 'Calories': 111.0}
# {'ID': 5220, 'Description': 'TURKEY,FRYER-ROASTERS,BREAST,MEAT ONLY,CKD,RSTD', 'Calories': 135.0}
# {'ID': 5221, 'Description': 'TURKEY,FRYER-ROASTERS,LEG,MEAT&SKN,RAW', 'Calories': 118.0}
# {'ID': 5222, 'Description': 'TURKEY,FRYER-ROASTERS,LEG,MEAT&SKN,CKD,RSTD', 'Calories': 170.0}
# {'ID': 5223, 'Description': 'TURKEY,FRYER-ROASTERS,LEG,MEAT ONLY,RAW', 'Calories': 108.0}
# {'ID': 5224, 'Description': 'TURKEY,FRYER-ROASTERS,LEG,MEAT ONLY,CKD,RSTD', 'Calories': 159.0}
# {'ID': 5225, 'Description': 'TURKEY,FRYER-ROASTERS,WING,MEAT&SKN,RAW', 'Calories': 159.0}
# {'ID': 5226, 'Description': 'TURKEY,FRYER-ROASTERS,WING,MEAT&SKN,CKD,RSTD', 'Calories': 207.0}
# {'ID': 5227, 'Description': 'TURKEY,FRYER-ROASTERS,WING,MEAT ONLY,RAW', 'Calories': 106.0}
# {'ID': 5228, 'Description': 'TURKEY,FRYER-ROASTERS,WING,MEAT ONLY,CKD,RSTD', 'Calories': 163.0}
# {'ID': 5229, 'Description': 'TURKEY,YOUNG HEN,MEAT&SKN&GIBLETS&NECK,RAW', 'Calories': 166.0}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/12/yh_z1p852cs806jbvl1zp6d00000gn/T/5dea5da1d6e64827ab15776c076a5451-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/12/yh_z1p852cs806jbvl1zp6d00000gn/T/5dea5da1d6e64827ab15776c076a5451-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6 COLUMNS
# At line 2823 RHS
# At line 2825 BOUNDS
# At line 3530 ENDATA
# Problem MODEL has 1 rows, 704 columns and 704 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 155.648 - 0.00 seconds
# Cgl0004I processed model has 1 rows, 91 columns (91 integer (76 of which binary)) and 91 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 1 integers unsatisfied sum - 0.368714
# Cbc0038I Solution found of -155.648
# Cbc0038I Branch and bound needed to clear up 1 general integers
# Cbc0038I Full problem 1 rows 91 columns, reduced to 0 rows 0 columns
# Cbc0038I Cleaned solution of -135
# Cbc0038I Before mini branch and bound, 90 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1 rows 91 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I Round again with cutoff of -137.965
# Cbc0038I Solution found of -155.648
# Cbc0038I Branch and bound needed to clear up 1 general integers
# Cbc0038I Mini branch and bound could not fix general integers
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 90 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of -135 - took 0.00 seconds
# Cbc0012I Integer solution of -135 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0012I Integer solution of -155 found by DiveCoefficient after 187 iterations and 0 nodes (0.07 seconds)
# Cbc0031I 3 added rows had average density of 33.333333
# Cbc0013I At root node, 3 cuts changed objective from -155.648 to -155.648 in 65 passes
# Cbc0014I Cut generator 0 (Probing) - 2 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 86 row cuts average 90.9 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 31 row cuts average 4.3 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 10 row cuts average 87.3 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -155, took 187 iterations and 0 nodes (0.07 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -155.648 to -155.648
# Probing was tried 65 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.017 seconds)
# Gomory was tried 65 times and created 86 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Knapsack was tried 65 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 65 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 65 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 65 times and created 31 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 65 times and created 10 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                155.00000000
# Enumerated nodes:               0
# Total iterations:               187
# Time (CPU seconds):             0.05
# Time (Wallclock seconds):       0.07
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.06   (Wallclock seconds):       0.08
#
# ['300g of MILK,BTTRMLK,FLUID,CULTURED,LOWFAT containing [120.] calories']
# ['300g of WHEY,SWEET,FLUID containing [81.] calories']
# ['300g of MILK,FLUID,1% FAT,WO/ ADDED VIT A & VIT D containing [126.] calories']
# ['400g of BASIL,FRESH containing [92.] calories']
# ['200g of CAPERS,CANNED containing [46.] calories']
